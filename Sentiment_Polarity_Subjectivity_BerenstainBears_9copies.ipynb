# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/BerenstainBears_4Research/blob/main/Sentiment_Polarity_Subjectivity_BerenstainBears_9copies.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##🐹 🐾 🐟 This script is based on [**Prof. Hosung Nam's github (hsnam95)**](https://github.com/hsnam95)

# %% [markdown]
# ### 🐣 🐥 **Tokenization**

# %%
#!pip install nltk is a command to install the NLTK library. The installation is a one-time process.
# !pip install nltk

#'import nltk' is a statement to make the NLTK library available for use in your Python code. The import statement is used in each script or notebook where you want to utilize NLTK functionality.
import nltk
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)

# %%
! git clone https://github.com/ms624atyale/Ref_Scripts4Research
# Out:
# Cloning into 'Ref_Scripts4Research'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 48 (delta 26), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 2.38 MiB | 4.73 MiB/s, done.
# Resolving deltas: 100% (26/26), done.

# %%
file = open("/content/Ref_Scripts4Research/BerenstainBears/BerenstainBears_First9Copies_BodyOnly.csv")
text = file.read().replace("\n", " ")
file.close()

# %%
file = open("tmp.txt", "w")
file.write(text)
file.close()

# %% [markdown]
# 🆘 _Refresh the directory to confirm <temp.txt>_

# %%
#text.lower() #PB. When I applied this codeline (text.lower()), it does not work with the written text.
#Using porterstemmer down in the script, we have small letters. So don't worry about the lower() function here.
words_split = text.split()

# %%
' '.join(text.split()) #uses a single space (' ') to join the words back together.
# Out:
# '\ufeff"Down a sunny dirt road, over a log bridge, up a grassy hill, deep in Bear Country, lived a family of bears—Papa Bear, Mama Bear and Small Bear. They lived in a large tree which Papa Bear had hollowed out and made into a house. It was a very fine house. This is what it looked like inside. It was fun growing up in Bear Country...helping Papa get honey from the old bee tree...helping Mama bring the vegetables in from the garden. There were all sorts of interesting things for a small bear to do and see in Bear-Country. Small Bear felt good growing up in a tree...in his own room...in the snug little bed that Papa Bear had made for him when he was a baby. But one morning, it did not feel so good. Small Bear woke up with pains in his knees and aches in his legs. “Small Bear, you have outgrown your little bed,” said Papa Bear, as he hitched up his overalls and buttoned his shoulder straps. “Today, we shall go out into the woods and make you a bigger one!” With that, he ate his breakfast of piping-hot porridge...washed it down with a gulp of honey from the family pot...took up his ax and was out the door. “But, Papa,” called Small Bear, following after him. “What will happen to my little bed?” “Don’t worry about that, Small Bear,” said Mama Bear as she closed the door after him. She smiled and patted her front, which had lately grown very big and round. “You’ve outgrown that snug little bed just in time!” He tested the ax to see if it was sharp, then headed off into the woods. “What will happen to my little bed?” Small Bear asked again as he caught up with Papa Bear in the woods. Papa had chopped down a tree and was splitting it into boards. “We will have a new baby soon who will need that little bed,” said papa Bear as he whacked off another board. “A ne baby?” asked Small Bear. (He hadn’t noticed that Mama Bear had grown very round lately, although he had noticed it was harder and harder to sit on her lap.) “And it’s coming soon?” “Yes, very soon!” said Papa Bear. With a final whack he split off the last board, which gave him enough wood to make a bigger bed for Small Bear. They made the bed a good size and took the rest of the day to chip and shave it smooth and neat. Then they carried it back to the tree and up to Small Bear’s room. When they got there, Small Bear noticed right away that his old bed wasn’t there any more. “My little bed!” said Small Bear. “It’s already gone!” “You outgrew it just in time,” called Mama Bear from the next room. “Come and see.” It was true! There was his snug little bed with a new little baby in it. Small Bear had outgrown his snug little bed just in time for his new baby sister. And now he was a big brother! She was very little but very lively. As Small Bear learned over for a closer look, she popped him on the nose with a tiny fist. “Hmm,” said Small Bear. “She has a pretty good punch for a little baby.” That night he stretched out proudly in his bigger bed. “Aah!” he said. “Being a big brother is going to be fun.” The next morning he woke up feeling fine, with no pains in his knees or aches in his legs. His nose was a little tender, though." "The Bear family didn’t always live in the big tree house down a sunny dirt road deep in Bear Country. Years ago, when Brother Bear was an only cub, they lived in a hillside cave halfway up Great Bear Mountain at the far edge of Bear Country. It was a comfortable cave, cool in summer and cozy in winter. And while it wasn’t perfect—it tended to be dark and it dripped and trickled a bit—it was home, and the Bear family was quite happy there. Happy and busy. Mama Bear kept busy managing things and tending the vegetable patch. Papa Bear had plenty to do with his wood cutting and furniture making. And Brother Bear kept busy climbing, collecting rocks, and playing with his friends. But living on the mountainside wasn’t perfect—it wasn’t easy growing vegetables in the thin, rocky soil, and the trees Papa needed were getting fewer and farther between. But the s ...

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.text import Text

nltk.download('punkt') # Download the punkt tokenizer data

#Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase

# Step 2: Create an NLTK Text object from the list of words.
text_object = nltk.Text(tokens)
print('\n')
print(text_object)

# Count subject pronoun limited to 'he' and 'they' (due to overlap between paradigm for femine and neuter)
print('\n')
#Subject
# Define the specific words you want to count
specific_words_allcasepronouns = ['i', 'you', 'he', 'she', 'it', 'they','my', 'your', 'his', 'her', 'its', 'their', 'me', 'you', 'him', 'her', 'it', 'them', 'myself', 'yourself', 'himself', 'herself', 'itself', 'ourselves', 'yourselves', 'ourselves', 'themselves']

# Filter the tokens to include only the specific words
filtered_tokens_allcasepronouns = [word for word in tokens if word in specific_words_allcasepronouns]

# Count the number of occurrences of the specific words
count_specific_words_allcasepronouns = len(filtered_tokens_allcasepronouns)
# Output the count
print(f"Count of specific words_allcasepronouns: {count_specific_words_allcasepronouns}")

# Define the specific words you want to count
specific_words_1stpersonpronouns = ['i', 'my', 'me', 'myself' ]

# Filter the tokens to include only the specific words
filtered_tokens_1stpersonpronouns = [word for word in tokens if word in specific_words_1stpersonpronouns ]

# Count the number of occurrences of the specific words
count_specific_words_1stpersonpronouns = len(filtered_tokens_1stpersonpronouns)
# Output the count
print(f"Count of specific words_1stpersonpronouns: {count_specific_words_1stpersonpronouns}")

# Define the specific words you want to count
specific_words_2ndpersonpronouns = ['you', 'your', 'you', 'yourself']

# Filter the tokens to include only the specific words
filtered_tokens_2ndpersonpronouns = [word for word in tokens if word in specific_words_2ndpersonpronouns]

# Count the number of occurrences of the specific words
count_specific_words_2ndpersonpronouns = len(filtered_tokens_2ndpersonpronouns)
# Output the count
print(f"Count of specific words_2ndpersonpronouns: {count_specific_words_2ndpersonpronouns}")

# Define the specific words you want to count
specific_words_malepronouns = ['he', 'his', 'him', 'himself' ]

# Filter the tokens to include only the specific words
filtered_tokens_malepronouns = [word for word in tokens if word in specific_words_malepronouns]

# Count the number of occurrences of the specific words
count_specific_words_malepronouns = len(filtered_tokens_malepronouns)
# Output the count
print(f"Count of specific words_malepronouns: {count_specific_words_malepronouns}")

# Define the specific words you want to count
specific_words_femalepronouns = ['she', 'her', 'her', 'herself' ]

# Filter the tokens to include only the specific words
filtered_tokens_femalepronouns = [word for word in tokens if word in specific_words_femalepronouns]

# Count the number of occurrences of the specific words
count_specific_words_femalepronouns = len(filtered_tokens_femalepronouns)
# Output the count
print(f"Count of specific words_femalepronouns: {count_specific_words_femalepronouns}")

# Define the specific words you want to count
specific_words_neuterpronouns = ['it', 'its', 'it', 'itself' ]

# Filter the tokens to include only the specific words
filtered_tokens_neuterpronouns = [word for word in tokens if word in specific_words_neuterpronouns]

# Count the number of occurrences of the specific words
count_specific_words_neuterpronouns = len(filtered_tokens_neuterpronouns)
# Output the count
print(f"Count of specific words_neuterpronouns: {count_specific_words_neuterpronouns}")

# Define the specific words you want to count
specific_words_1stpluralpronouns = ['we', 'our', 'us', 'ourselves']

# Filter the tokens to include only the specific words
filtered_tokens_1stpluralpronouns = [word for word in tokens if word in specific_words_1stpluralpronouns]

# Count the number of occurrences of the specific words
count_specific_words_1stpluralpronouns = len(filtered_tokens_1stpluralpronouns)
# Output the count
print(f"Count of specific words_1stpluralpronouns: {count_specific_words_1stpluralpronouns}")

# Define the specific words you want to count
specific_words_3rdpluralpronouns = ['they', 'their', 'them', 'themselves']

# Filter the tokens to include only the specific words
filtered_tokens_3rdpluralpronouns = [word for word in tokens if word in specific_words_3rdpluralpronouns]

# Count the number of occurrences of the specific words
count_specific_words_3rdpluralpronouns = len(filtered_tokens_3rdpluralpronouns)
# Output the count
print(f"Count of specific words_3rdpluralpronouns: {count_specific_words_3rdpluralpronouns}")


# Count subject pronoun limited to 'he' and 'they' (due to overlap between paradigm for femine and neuter)
print('\n')
#Subject
# Define the specific words you want to count
specific_words_he_they = ['he', 'they']

# Filter the tokens to include only the specific words
filtered_tokens_he_they = [word for word in tokens if word in specific_words_he_they]

# Count the number of occurrences of the specific words
count_specific_words_he_they = len(filtered_tokens_he_they)

# Output the count
print(f"Count of specific words_he_they: {count_specific_words_he_they}")

print('\n')
#Possessive
# Define the specific words you want to count
specific_words_his_their = ['his', 'their']

# Filter the tokens to include only the specific words
filtered_tokens_his_their = [word for word in tokens if word in specific_words_his_their]

# Count the number of occurrences of the specific words
count_specific_words_his_their = len(filtered_tokens_his_their)

# Output the count
print(f"Count of specific words_his_their: {count_specific_words_his_their}")

print('\n')
#Object

# Define the specific words you want to count
specific_words_him_them = ['him', 'them']

# Filter the tokens to include only the specific words
filtered_tokens_him_them = [word for word in tokens if word in specific_words_him_them]

# Count the number of occurrences of the specific words
count_specific_words_him_them = len(filtered_tokens_him_them)

# Output the count
print(f"Count of specific words_him_them: {count_specific_words_him_them}")

# Define the specific words you want to count
specific_words_3rdplreflexivepronouns = ['himself', 'themselves']

# Filter the tokens to include only the specific words
filtered_tokens_3rdplreflexivepronouns = [word for word in tokens if word in specific_words_3rdplreflexivepronouns]

# Count the number of occurrences of the specific words
count_specific_words_3rdplreflexivepronouns = len(filtered_tokens_3rdplreflexivepronouns)

# Output the count
print(f"Count of specific words_3rdplreflexivepronouns: {count_specific_words_3rdplreflexivepronouns}")
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# <Text: ﻿ '' down a sunny dirt road ,...>
#
#
# Count of specific words_allcasepronouns: 821
# Count of specific words_1stpersonpronouns: 113
# Count of specific words_2ndpersonpronouns: 132
# Count of specific words_malepronouns: 135
# Count of specific words_femalepronouns: 153
# Count of specific words_neuterpronouns: 157
# Count of specific words_1stpluralpronouns: 49
# Count of specific words_3rdpluralpronouns: 130
#
#
# Count of specific words_he_they: 150
#
#
# Count of specific words_his_their: 76
#
#
# Count of specific words_him_them: 39
# Count of specific words_3rdplreflexivepronouns: 0

# %%
# Define the specific words you want to count
specific_words_femprosubj = ['she']

# Filter the tokens to include only the specific words
filtered_tokens_femprosubj = [word for word in tokens if word in specific_words_femprosubj ]

# Count the number of occurrences of the specific words
count_specific_words_femprosubj = len(filtered_tokens_femprosubj)
# Output the count
print(f"Count of specific words_femprosubj: {count_specific_words_femprosubj}")

# Define the specific words you want to count
specific_words_femsubj = ['mama', 'sister']

# Filter the tokens to include only the specific words
filtered_tokens_femsubj = [word for word in tokens if word in specific_words_femsubj ]

# Count the number of occurrences of the specific words
count_specific_words_femsubj = len(filtered_tokens_femsubj)
# Output the count
print(f"Count of specific words_femsubj: {count_specific_words_femsubj}")

# Define the specific words you want to count
specific_words_maleprosubj = ['he']

# Filter the tokens to include only the specific words
filtered_tokens_maleprosubj = [word for word in tokens if word in specific_words_maleprosubj ]

# Count the number of occurrences of the specific words
count_specific_words_maleprosubj = len(filtered_tokens_maleprosubj)
# Output the count
print(f"Count of specific words_maleprosubj: {count_specific_words_maleprosubj}")

# Define the specific words you want to count
specific_words_malesubj = ['papa','brother']

# Filter the tokens to include only the specific words
filtered_tokens_malesubj = [word for word in tokens if word in specific_words_malesubj ]

# Count the number of occurrences of the specific words
count_specific_words_malesubj = len(filtered_tokens_malesubj)
# Output the count
print(f"Count of specific words_malesubj: {count_specific_words_malesubj}")
# Out:
# Count of specific words_femprosubj: 94
# Count of specific words_femsubj: 235
# Count of specific words_maleprosubj: 67
# Count of specific words_malesubj: 225

# %%
#Subject
# Define the specific words you want to count
specific_words_I_we = ['i', 'we']

# Filter the tokens to include only the specific words
filtered_tokens_I_we = [word for word in tokens if word in specific_words_I_we]

# Count the number of occurrences of the specific words
count_specific_words_I_we = len(filtered_tokens_I_we)

# Output the count
print(f"Count of specific words_I_we: {count_specific_words_I_we}")

print('\n')
#Possessive
# Define the specific words you want to count
specific_words_my_our = ['my', 'our']

# Filter the tokens to include only the specific words
filtered_tokens_my_our = [word for word in tokens if word in specific_words_my_our]

# Count the number of occurrences of the specific words
count_specific_words_my_our = len(filtered_tokens_my_our)

# Output the count
print(f"Count of specific words_my_our: {count_specific_words_my_our}")

print('\n')
#Object

# Define the specific words you want to count
specific_words_me_us = ['me', 'us']

# Filter the tokens to include only the specific words
filtered_tokens_me_us = [word for word in tokens if word in specific_words_me_us]

# Count the number of occurrences of the specific words
count_specific_words_me_us = len(filtered_tokens_me_us)

# Output the count
print(f"Count of specific words_me_us: {count_specific_words_me_us}")

# Define the specific words you want to count
specific_words_myself_ourselves = ['myself', 'ourselves']

# Filter the tokens to include only the specific words
filtered_tokens_myself_ourselves = [word for word in tokens if word in specific_words_myself_ourselves]

# Count the number of occurrences of the specific words
count_specific_words_myself_ourselves = len(filtered_tokens_myself_ourselves)

# Output the count
print(f"Count of specific words_myself_ourselves: {count_specific_words_myself_ourselves}")
# Out:
# Count of specific words_I_we: 98
#
#
# Count of specific words_my_our: 38
#
#
# Count of specific words_me_us: 26
# Count of specific words_myself_ourselves: 0

# %%
# Define the specific words you want to count
specific_words_allreflexive = ['myself', 'yourself', 'himself', 'herself', 'itself', 'ourselves', 'yourselves', 'ourselves', 'themselves']

# Filter the tokens to include only the specific words
filtered_tokens_allreflexive = [word for word in tokens if word in specific_words_allreflexive]

# Count the number of occurrences of the specific words
count_specific_words_allreflexive = len(filtered_tokens_allreflexive)

# Output the count
print(f"Count of specific words_allreflexive: {count_specific_words_allreflexive}")
# Out:
# Count of specific words_allreflexive: 2

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.text import Text

nltk.download('punkt') # Download the punkt tokenizer data

#Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase

# Step 2: Create an NLTK Text object from the list of words.
text_object = nltk.Text(tokens)
print('\n')
print(text_object)

# Step 3: Find and print collocations (this automatically finds frequent word pairs)
#print(text_object.collocations()) #not working as of 24SEP24
#print('\n')

# Step 4: Display a concordance for the word 'Emma'
text_object.concordance('she', width=100, lines=20)
print('\n')

# Step 5: Plotting
text_object.dispersion_plot(['papa', 'mama', 'brother', 'sister'])

print('\n')
text_object.dispersion_plot(['he', 'she'])
print('\n')
text_object.dispersion_plot(['he', 'papa', 'brother', 'she', 'mama', 'sister'])
print('\n')
text_object.dispersion_plot(['he', 'him', 'papa', 'brother', 'she', 'her', 'mama', 'sister'])
print('\n')
text_object.dispersion_plot(['he', 'him', 'papa', 'brother', 'she', 'her', 'mama', 'sister', 'bear', 'they', 'them'])
print('\n')
text_object.dispersion_plot(['he', 'she', 'it', 'they', 'his', 'her', 'its', 'their', 'him', 'her', 'it', 'them'])
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <Text: ﻿ '' down a sunny dirt road ,...>
# Displaying 20 of 94 matches:
# y about that , small bear , ” said mama bear as she closed the door after him . she smiled and patt
# id mama bear as she closed the door after him . she smiled and patted her front , which had lately
# ew baby sister . and now he was a big brother ! she was very little but very lively . as small bear
#  as small bear learned over for a closer look , she popped him on the nose with a tiny fist . “ hmm
# ith a tiny fist . “ hmm , ” said small bear . “ she has a pretty good punch for a little baby. ” th
# sed brother . “ of course not , ” said sister . she left her book on the floor and climbed onto the
# fingers in her ears . “ that ’ s enough ! ” and she went back to her storybook . “ scaredy bear ! s
# e—it gave her quite a scare . “ mama ! papa ! ” she cried . “ hurry ! come quick ! ” and come quick
# tubbed . and mama was looking for the night cap she had lost in the confusion . all three of them w
#  with me , ” he said . “ where are we going ? ” she wanted to know . “ up to the attic. ” “ the att
# ? ” “ sure ! i want to see how it turns out ! ” she insisted . when it turned out that there was no
# s a little disappointed . and that night , when she and brother were all settled down in the cozy g
#  in the cozy glow of papa ’ s old night light , she said so . “ i was pretty disappointed by the wa
# nded. ” “ why ? ” asked brother . “ because , ” she said , “ i was hoping the wailing would be a re
# ould be a really spooky , scary monster ! ” and she leaned down from her bunk over brother ’ s and
# ister bear opened her eyes and stretched . then she sat up and let her legs dangle over the edge of
# dge of her bed—right in brother bear ’ s face . she didn ’ t do it to be rude . it was just one of
#  ’ t dopey , and they ’ re not in your face ! ” she shouted back . “ get your dopey face out of my
# ed sister ... and before brother could answer , she skipped into the bathroom ahead of him . she to
#  , she skipped into the bathroom ahead of him . she took a very long time ... brushing her teeth ,

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.text import Text

nltk.download('punkt') # Download the punkt tokenizer data

stopwords =  [ 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",'wouldn', "wouldn't" ]

#Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase
words = [word for word in tokens if word not in stopwords]

# Step 2: Create an NLTK Text object from the list of words.
text_object = nltk.Text(words)
print('\n')
print(text_object)

# Step 3: Find and print collocations (this automatically finds frequent word pairs)
#print(text_object.collocations()) #not working as of 24SEP24
#print('\n')

# Step 4: Display a concordance for the word 'Emma'
text_object.concordance('bear', width=100, lines=20)
print('\n')

# Step 5: Plotting
text_object.dispersion_plot(['papa', 'mama', 'brother', 'sister'])
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <Text: ﻿ '' sunny dirt road , log bridge...>
# Displaying 20 of 121 matches:
# nny dirt road , log bridge , grassy hill , deep bear country , lived family bears—papa bear , mama b
# l , deep bear country , lived family bears—papa bear , mama bear small bear . lived large tree papa
# r country , lived family bears—papa bear , mama bear small bear . lived large tree papa bear hollowe
#  lived family bears—papa bear , mama bear small bear . lived large tree papa bear hollowed made hous
#  , mama bear small bear . lived large tree papa bear hollowed made house . fine house . looked like
# . fine house . looked like inside . fun growing bear country ... helping papa get honey old bee tree
# etables garden . sorts interesting things small bear see bear-country . small bear felt good growing
# ting things small bear see bear-country . small bear felt good growing tree ... room ... snug little
#  growing tree ... room ... snug little bed papa bear made baby . one morning , feel good . small bea
# ear made baby . one morning , feel good . small bear woke pains knees aches legs . “ small bear , ou
# mall bear woke pains knees aches legs . “ small bear , outgrown little bed , ” said papa bear , hitc
#  small bear , outgrown little bed , ” said papa bear , hitched overalls buttoned shoulder straps . “
# ot ... took ax door . “ , papa , ” called small bear , following . “ happen little bed ? ” “ ’ worry
# ing . “ happen little bed ? ” “ ’ worry , small bear , ” said mama bear closed door . smiled patted
# le bed ? ” “ ’ worry , small bear , ” said mama bear closed door . smiled patted front , lately grow
#  , headed woods . “ happen little bed ? ” small bear asked caught papa bear woods . papa chopped tre
# pen little bed ? ” small bear asked caught papa bear woods . papa chopped tree splitting boards . “
# . “ new baby soon need little bed , ” said papa bear whacked another board . “ ne baby ? ” asked sma
# acked another board . “ ne baby ? ” asked small bear . ( ’ noticed mama bear grown round lately , al
# ne baby ? ” asked small bear . ( ’ noticed mama bear grown round lately , although noticed harder ha

# %%
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.text import Text

nltk.download('punkt') # Download the punkt tokenizer data

stopwords =  [ 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",'wouldn', "wouldn't" ]

#Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase
words = [word for word in tokens if word not in stopwords]

# Step 2: Create an NLTK Text object from the list of words.
text_object = nltk.Text(words)
print('\n')
print(text_object)

# Step 3: Find and print collocations (this automatically finds frequent word pairs)
print(text_object.collocations())
print('\n')

# Step 4: Display a concordance for the word 'Emma'
text_object.concordance('brother', width=100, lines=20)
print('\n')

# Step 5: Plotting
text_object.dispersion_plot(['papa', 'mama', 'brother', 'sister'])
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# <Text: ﻿ '' sunny dirt road , log bridge...>
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __load(self)
#      83                 try:
# ---> 84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-16-e5aa6c946911> in <cell line: 20>()
#      18
#      19 # Step 3: Find and print collocations (this automatically finds frequent word pairs)
# ---> 20 print(text_object.collocations())
#      21 print('\n')
#      22
#
# /usr/local/lib/python3.10/dist-packages/nltk/text.py in collocations(self, num, window_size)
#     461
#     462         collocation_strings = [
# --> 463             w1 + " " + w2 for w1, w2 in self.collocation_list(num, window_size)
#     464         ]
#     465         print(tokenwrap(collocation_strings, separator="; "))
#
# /usr/local/lib/python3.10/dist-packages/nltk/text.py in collocation_list(self, num, window_size)
#     431             from nltk.corpus import stopwords
#     432
# --> 433             ignored_words = stopwords.words("english")
#     434             finder = BigramCollocationFinder.from_words(self.tokens, window_size)
#     435             finder.apply_freq_filter(2)
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __getattr__(self, attr)
#     119             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     120
# --> 121         self.__load()
#     122         # This looks circular, but its not, since __load() changes our
#     123         # __class__ to something new:
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __load(self)
#      84                     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85                 except LookupError:
# ---> 86                     raise e
#      87
#      88         # Load the corpus.
#
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/util.py in __load(self)
#      79         else:
#      80             try:
# ---> 81                 root = nltk.data.find(f"{self.subdir}/{self.__name}")
#      82             except LookupError as e:
#      83                 try:
#
# /usr/local/lib/python3.10/dist-packages/nltk/data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - '/root/nltk_data'
#     - '/usr/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/share/nltk_data'
#     - '/usr/local/share/nltk_data'
#     - '/usr/lib/nltk_data'
#     - '/usr/local/lib/nltk_data'
# **********************************************************************

# %% [markdown]
# Polarity and Subjectivity (from ChatGPT)
# Interpretation
#
# Polarity: 0.131
# >
# Interpretation: The polarity score of 0.136 suggests that the text has a slightly positive sentiment, but it's not strongly positive. This means the emotions expressed in the text lean toward the positive side, but the overall tone is fairly neutral with just a mild positive inclination.
# Range Context:
# Polarity scores close to 1 would indicate very positive sentiment.
# Scores close to -1 would indicate strong negative sentiment.
# A score around 0 would indicate neutral sentiment.
# In this case, 0.136 shows a moderately positive sentiment, perhaps expressing mild approval or contentment.
# >
#
# Subjectivity: 0.515
# >
# Interpretation: The subjectivity score of 0.518 indicates that the text is slightly more subjective than objective. This suggests that the text contains a balance between personal opinions, emotions, or beliefs and factual or objective statements, but it leans a little toward subjective (opinion-based) content.
# Range Context:
# Scores closer to 1 suggest the text is highly subjective (mainly personal opinions or emotions).
# Scores closer to 0 suggest the text is highly objective (based on facts or verifiable information).
# A score of 0.518 suggests that the text likely contains a mix of subjective opinions and factual information but is more on the subjective side.
# Overall Interpretation:
# The text analyzed is slightly positive in tone (mild positive sentiment) and contains a balance of opinions and facts, but with a small tilt toward subjectivity. It likely expresses some personal feelings or opinions, though not overwhelmingly so, and doesn't contain strong emotional language.
#
# Would you like to analyze more texts, or need clarification on these concepts?

# %%
# Install TextBlob if not already installed
# !pip install textblob
from textblob import TextBlob

# Perform sentiment analysis
blob = TextBlob(text)
sentiment = blob.sentiment

# Print sentiment polarity and subjectivity
print(f"Polarity: {sentiment.polarity}, Subjectivity: {sentiment.subjectivity}")

#극성과 주관성
#positive emotions (e.g., happiness, excitement); negative emotions (e.g., sadness, anger); emotional neutral
#personal opinions, feelings, or subjective judgments; objective, based on facts or verifiable information.
# Out:
# Requirement already satisfied: textblob in /usr/local/lib/python3.10/dist-packages (0.17.1)
# Requirement already satisfied: nltk>=3.1 in /usr/local/lib/python3.10/dist-packages (from textblob) (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk>=3.1->textblob) (4.66.5)
# Polarity: 0.13106612614353377, Subjectivity: 0.5150985481080272

# %% [markdown]
# 1. Named Entity Recognition (NER)
# Identify and categorize entities such as characters, locations, and organizations. For children's books like The Berenstain Bears, NER can help recognize characters and places.
#
# Python Code for NER (using spaCy):
#
# -> This need restarting colab and I did not follow its alert message. The results seem not very helpful

# %%
#BOMB
# !pip install spacy
# !python -m spacy download en_core_web_sm  # Download a small English model
import spacy

# Load the pre-trained spaCy model
nlp = spacy.load("en_core_web_sm")


# Apply the spaCy NLP pipeline to the text
doc = nlp(text)

# Print named entities found in the text
for entity in doc.ents:
    print(entity.text, entity.label_)
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 63.4 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.7.1) (3.7.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.9.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (71.0.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.23.4)
# Requirement already satisfied: typing-extensions>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.8.30)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.19.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (7.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.16.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Bear Country ORG
# Papa Bear ORG
# Bear Country ORG
# Papa ORG
# Bear-Country ORG
# Papa Bear ORG
# one morning TIME
# Papa Bear PERSON
# Today DATE
# Papa PERSON
# Small Bear ORG
# Small Bear PERSON
# Mama Bear PERSON
# Papa Bear ORG
# Papa ORG
# Bear ORG
# Small Bear PERSON
# Mama Bear PERSON
# Papa Bear PERSON
# the day DATE
# Small Bear ORG
# Small Bear PERSON
# Mama Bear PERSON
# Small Bear PERSON
# Hmm PERSON
# Small Bear PERSON
# That night TIME
# The next morning TIME
# The Bear WORK_OF_ART
# Bear Country ORG
# Years ago DATE
# Brother Bear ORG
# Great Bear Mountain FAC
# Bear Country ORG
# summer DATE
# winter DATE
# Bear PERSON
# Papa Bear ORG
# Brother Bear ORG
# Papa ORG
# Bear PERSON
# Great Bear Mountain FAC
# Bear Country ORG
# one day DATE
# Papa Bear ORG
# Brother Bear ORG
# Papa PERSON
# Mama PERSON
# Papa PERSON
# Papa ORG
# Papa ORG
# Mama PERSON
# Tomorrow DATE
# first ORDINAL
# That night TIME
# The next morning TIME
# Bear PERSON
# Papa PERSON
# Bear ORG
# Papa PERSON
# Papa ORG
# Papa PERSON
# Mama PERSON
# Papa PERSON
# Bear PERSON
# That night TIME
# “Brother Bear WORK_OF_ART
# Sister ORG
# all day DATE
# the Bear Country Library ORG
# Sister ORG
# Sister Bear ORG
# one CARDINAL
# ’s NORP
# Hmmm ORG
# Sister PERSON
# The Case of the Crying Cave WORK_OF_ART
# later that evening TIME
# Bear PERSON
# Sister PERSON
# Sister PERSON
# about three CARDINAL
# Sister PERSON
# overnight TIME
# Sister PERSON
# Scaredy PERSON
# Papa Bear ORG
# Papa PERSON
# Mama PERSON
# Sister Bear ORG
# That night TIME
# Papa ORG
# Papa ORG
# Sister GPE
# Papa ORG
# three CARDINAL
# Brother Bear ORG
# a very long night TIME
# Bear ORG
# Mama PERSON
# The next morning TIME
# Bear PERSON
# another night TIME
# Papa PERSON
# Papa PERSON
# Sister PERSON
# Sister PERSON
# Papa PERSON
# Papa ORG
# Sister PERSON
# Papa ORG
# Papa PERSON
# night TIME
# Sister PERSON
# Papa PERSON
# one CARDINAL
# The Case of the Crying Cave WORK_OF_ART
# later that day DATE
# Sister PERSON
# that night TIME
# Papa ORG
# The Case of the Crying Cave WORK_OF_ART
# Most morning TIME
# Bear Country ORG
# the day DATE
# Brother Bear and Sister Bear ORG
# Sister PERSON
# one CARDINAL
# Sister PERSON
# Sister Bear ORG
# Sister Bear ORG
# Brother Bear’s ORG
# that morning TIME
# Sister PERSON
# Brother Bear ORG
# Papa ORG
# Sister ORG
# Papa ORG
# Sister PERSON
# that morning TIME
# That afternoon TIME
# half CARDINAL
# Sister PERSON
# Brother ORG
# one CARDINAL
# Sister GPE
# Papa ORG
# two CARDINAL
# Mama PERSON
# Sister PERSON
# two CARDINAL
# Papa PERSON
# Mama PERSON
# Papa ORG
# Mama PERSON
# Papa ORG
# one CARDINAL
# Sister PERSON
# Mama PERSON
# Papa PERSON
# Mama PERSON
# Sister Bear ORG
# the last day DATE
# Bear ORG
# Sister Bear ORG
# Jane PERSON
# Mama Bear PERSON
# Sister PERSON
# Sister PERSON
# Mama PERSON
# DON’T FORGET PERSON
# POWWOW ORG
# Sister GPE
# overnight TIME
# Sister PERSON
# Grizzly Bob’s PERSON
# Mama PERSON
# A couple of mornings later TIME
# Sister PERSON
# Grizzly Bob PERSON
# Jane PERSON
# Grizzly Bob PERSON
# Bod PERSON
# first ORDINAL
# a Rec Hall PERSON
# Bob PERSON
# Spook Hill LOC
# Skull Rock GPE
# Papa Bear PERSON
# Sister PERSON
# The second day DATE
# Sister GPE
# The third day DATE
# The fourth day DATE
# every day DATE
# Skull Rock ORG
# Mama PERSON
# the morning TIME
# the big night TIME
# Sister PERSON
# Spooky Hill ORG
# n’t GPE
# their summer DATE
# Tomorrow DATE
# the last day DATE
# Skull Rock LOC
# Grizzly Bob PERSON
# Indian NORP
# Bob PERSON
# Indian NORP
# the Great Grizzly as Big as a Mountain EVENT
# the Soaring Eagle Who Filled ORG
# Sky ORG
# the Mighty Salmon Whose Colors Made the Rainbow ORG
# Bob PERSON
# the night TIME
# The next day DATE
# Sister PERSON
# second ORDINAL
# Sister ORG
# almost the end of summer DATE
# a couple of weeks DATE
# Papa PERSON
# Sister PERSON
# Grizzly Bob’s PERSON
# Bear Country ORG
# Bear PERSON
# Sister Bear ORG
# Sister PERSON
# Mama Bear PERSON
# Mama PERSON
# Sister PERSON
# ’s GPE
# Sister PERSON
# ’s GPE
# yesterday DATE
# Sister PERSON
# Sister PERSON
# First ORDINAL
# Sister PERSON
# Mama Bear PERSON
# Bear PERSON
# Sister GPE
# Papa ORG
# Mama PERSON
# Bear Country ORG
# Brother PRODUCT
# Sister PERSON
# Sister PERSON
# Mama Bear PERSON
# Papa Bear PERSON
# second ORDINAL
# one CARDINAL
# first ORDINAL
# Papa PERSON
# second ORDINAL
# Sister PERSON
# Mama PERSON
# Sister PERSON
# Grizzly Gran PERSON
# Bear PERSON
# Sunday DATE
# Gran PERSON
# Mama PERSON
# Sister PERSON
# Gran PERSON
# two CARDINAL
# Papa PERSON
# Sister Bear ORG
# One CARDINAL
# Sister PERSON
# The Bear WORK_OF_ART
# Bear Country ORG
# One CARDINAL
# Papa Bear ORG
# Mama Bear PERSON
# Sister Bear ORG
# Bear PERSON
# Papa ORG
# Sister PERSON
# Sister PERSON
# thousand CARDINAL
# one CARDINAL
# Bear Country ORG
# Sister Bear ORG
# Papa PERSON
# Bear PERSON
# Bear PERSON
# Look, Mama WORK_OF_ART
# a thousand CARDINAL
# Sister PERSON
# one day DATE
# Bear PERSON
# two CARDINAL
# two CARDINAL
# Papa ORG
# the same day DATE
# Papa ORG
# Papa PERSON
# One CARDINAL
# the Bear Country Quilting Club ORG
# Papa PERSON
# Mama PERSON
# all evening TIME
# The next day DATE
# years DATE
# Papa PERSON
# Sister PERSON
# Grizzle PERSON
# Honeybear PERSON
# Gert PERSON
# Mama PERSON
# Sister PERSON
# Papa PERSON
# Mama PERSON
# a little late tonight TIME
# Papa PERSON
# late that night TIME
# Papa PERSON
# Sister PERSON
# thousand CARDINAL
# today DATE
# Papa ORG
# Mama PERSON
# about two weeks DATE
# the Bear Country Quilt Shop ORG
# Honeypot PERSON
# one CARDINAL
# three CARDINAL
# Mama PERSON
# the Burger Bear ORG
# Bear PERSON
# Burger Bear ORG
# Brother and Sister Bear WORK_OF_ART
# Bear Country ORG
# Sister PERSON
# Sister ORG
# Frisbee PRODUCT
# Sister PERSON
# Bear PERSON
# Sister GPE
# Truck Driver PERSON
# Shopper PERSON
# Hmm PERSON
# Papa Bear PERSON
# Papa PERSON
# Sister PERSON
# Papa PERSON
# Papa ORG
# Sister PERSON
# that evening TIME
# Papa ORG
# Papa ORG
# Silly Goose WORK_OF_ART
# Wily Fox PERSON
# Silly Goose PERSON
# Wily Fox PERSON
# Silly PERSON
# Wily PERSON
# Silly Goose PERSON
# Wily Fox PERSON
# Sister PERSON
# SILLY GPE
# WILY FOX PERSON
# Brother Bear’s ORG
# The next day DATE
# Sister PERSON
# a restless night TIME
# ’s GPE
# Sister PERSON
# Frisbee PRODUCT
# Mama PERSON
# Farmer Ben’s PERSON
# Sister PERSON
# Today DATE
# Sister GPE
# a mile QUANTITY
# Mama PERSON
# Sister PERSON
# Mama PERSON
# Mama PERSON
# Papa PERSON
# Cubs ORG
# Sister PERSON
# Mama PERSON
# half CARDINAL
# Sister PERSON
# Sister PERSON
# Sister PERSON
# Sister GPE
# Sister ORG
# Papa PERSON
# Sister GPE
# Sister GPE
# Sister PERSON
# Mama PERSON
# Sister PERSON
# Mama PERSON
# Sister PERSON
# that day DATE
# Cubs ORG
# SISTER BEAR’S ORG
# 1 CARDINAL
# 2 CARDINAL
# 3 CARDINAL
# 4. CARDINAL
# 5. CARDINAL
# Papa ORG
# 6 CARDINAL
# Bear Country ORG
# Bear PERSON
# one CARDINAL
# Bear PERSON
# Mama Bear PERSON
# Sister Bear’s ORG
# Papa ORG
# Bear PERSON
# Mama PERSON
# two CARDINAL
# Papa PERSON
# Papa PERSON
# three CARDINAL
# Rude List ORG
# Mama PERSON
# Hmm PERSON
# Sister PERSON
# Sister PERSON
# Sister PERSON
# Papa ORG
# Papa ORG
# Papa ORG
# Papa ORG
# Papa Bear ORG
# Papa PERSON
# Sister PERSON
# Sister Bear ORG

# %% [markdown]
# Bigram/Trigram Analysis

# %%
# !pip install nltk
import nltk
nltk.download('punkt') # Download the punkt tokenizer data
from nltk.tokenize import word_tokenize
from nltk.text import Text
from collections import Counter

stopwords =  [ 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",'wouldn', "wouldn't" ]

#Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase
words = [word for word in tokens if word not in stopwords]

# Step 2: Create an NLTK Text object from the list of words.
text_object = nltk.Text(words)

# Count word frequencies
word_freq = Counter(text_object)

# Print the most common words
print(word_freq.most_common(50))  # Top 50 most common words
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('.', 583), (',', 480), ('“', 350), ('”', 345), ('’', 242), ('!', 170), ('brother', 127), ('said', 125), ('sister', 125), ('bear', 121), ('mama', 110), ('papa', 98), ('?', 64), ('cubs', 37), ('one', 34), ('family', 33), ('little', 33), ('...', 32), ('big', 30), ('tree', 29), ('like', 29), ('day', 27), ('house', 26), ('time', 25), ('asked', 25), ('got', 23), ('good', 22), ('would', 20), ('night', 18), ('small', 17), ('get', 17), ('things', 17), ('bed', 17), ('even', 17), ('made', 16), ('going', 16), ('cave', 16), ('quite', 16), ('looked', 15), ('old', 15), ('look', 15), ('``', 15), ('began', 15), ('know', 15), ('well', 15), ('country', 14), ('fine', 14), ('back', 14), ('right', 14), ('camp', 14)]

# %%
# !pip install nltk
import nltk
from nltk import ngrams
from nltk.tokenize import word_tokenize

# Tokenize the text
tokens = word_tokenize(text.lower())

# Generate bigrams (two-word combinations)
bigrams = list(ngrams(tokens, 2))

# Generate trigrams (three-word combinations)
trigrams = list(ngrams(tokens, 3))

# Print bigrams
print("Bigrams:")
for bigram in bigrams:
    print(bigram)

# Print trigrams
print("\nTrigrams:")
for trigram in trigrams:
    print(trigram)
# Out:
# Streaming output truncated to the last 5000 lines.
# ('just', 'maybe', ',')
# ('maybe', ',', 'my')
# (',', 'my', 'cubs')
# ('my', 'cubs', ',')
# ('cubs', ',', 'whom')
# (',', 'whom', 'i')
# ('whom', 'i', '’')
# ('i', '’', 've')
# ('’', 've', 'always')
# ('ve', 'always', 'trusted')
# ('always', 'trusted', ',')
# ('trusted', ',', 'aren')
# (',', 'aren', '’')
# ('aren', '’', 't')
# ('’', 't', 'telling')
# ('t', 'telling', 'me')
# ('telling', 'me', 'the')
# ('me', 'the', 'truth')
# ('the', 'truth', '.')
# ('truth', '.', 'and')
# ('.', 'and', 'trust')
# ('and', 'trust', 'is')
# ('trust', 'is', 'not')
# ('is', 'not', 'something')
# ('not', 'something', 'you')
# ('something', 'you', 'can')
# ('you', 'can', 'put')
# ('can', 'put', 'back')
# ('put', 'back', 'together')
# ('back', 'together', 'again.')
# ('together', 'again.', '”')
# ('again.', '”', 'both')
# ('”', 'both', 'cubs')
# ('both', 'cubs', 'started')
# ('cubs', 'started', 'to')
# ('started', 'to', 'talk')
# ('to', 'talk', 'at')
# ('talk', 'at', 'once')
# ('at', 'once', '.')
# ('once', '.', '“')
# ('.', '“', 'it')
# ('“', 'it', 'wasn')
# ('it', 'wasn', '’')
# ('wasn', '’', 't')
# ('’', 't', 'a')
# ('t', 'a', 'bird')
# ('a', 'bird', '!')
# ('bird', '!', '”')
# ('!', '”', 'said')
# ('”', 'said', 'sister')
# ('said', 'sister', '.')
# ('sister', '.', '“')
# ('.', '“', 'it')
# ('“', 'it', 'was')
# ('it', 'was', 'a')
# ('was', 'a', 'soccer')
# ('a', 'soccer', 'ball.')
# ('soccer', 'ball.', '”')
# ('ball.', '”', '“')
# ('”', '“', 'and')
# ('“', 'and', 'it')
# ('and', 'it', 'was')
# ('it', 'was', 'all')
# ('was', 'all', 'my')
# ('all', 'my', 'fault')
# ('my', 'fault', '!')
# ('fault', '!', '”')
# ('!', '”', 'shouted')
# ('”', 'shouted', 'brother')
# ('shouted', 'brother', '.')
# ('brother', '.', '“')
# ('.', '“', 'it')
# ('“', 'it', 'was')
# ('it', 'was', 'just')
# ('was', 'just', 'as')
# ('just', 'as', 'much')
# ('as', 'much', 'my')
# ('much', 'my', 'fault')
# ('my', 'fault', '!')
# ('fault', '!', '”')
# ('!', '”', 'shouted')
# ('”', 'shouted', 'sister')
# ('shouted', 'sister', '.')
# ('sister', '.', 'but')
# ('.', 'but', 'they')
# ('but', 'they', 'were')
# ('they', 'were', 'both')
# ('were', 'both', 'shouted')
# ('both', 'shouted', 'down')
# ('shouted', 'down', 'by')
# ('down', 'by', 'the')
# ('by', 'the', 'phone')
# ('the', 'phone', ',')
# ('phone', ',', 'which')
# (',', 'which', 'rang')
# ('which', 'rang', 'loudly')
# ('rang', 'loudly', '.')
# ('loudly', '.', 'it')
# ('.', 'it', 'was')
# ('it', 'was', 'grizzly')
# ('was', 'grizzly', 'gran')
# ('grizzly', 'gran', 'inviting')
# ('gran', 'inviting', 'the')
# ('inviting', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', 'for')
# ('family', 'for', 'a')
# ('for', 'a', 'sunday')
# ('a', 'sunday', 'visit')
# ('sunday', 'visit', '.')
# ('visit', '.', '“')
# ('.', '“', 'hello')
# ('“', 'hello', ',')
# ('hello', ',', 'gran')
# (',', 'gran', '!')
# ('gran', '!', '”')
# ('!', '”', 'said')
# ('”', 'said', 'mama')
# ('said', 'mama', '.')
# ('mama', '.', '“')
# ('.', '“', 'oh')
# ('“', 'oh', ',')
# ('oh', ',', 'everything')
# (',', 'everything', 'is')
# ('everything', 'is', 'just')
# ('is', 'just', 'fine')
# ('just', 'fine', 'here')
# ('fine', 'here', 'in')
# ('here', 'in', 'the')
# ('in', 'the', 'tree')
# ('the', 'tree', 'house')
# ('tree', 'house', '.')
# ('house', '.', 'how')
# ('.', 'how', 'is')
# ('how', 'is', 'everything')
# ('is', 'everything', 'with')
# ('everything', 'with', 'you')
# ('with', 'you', '?')
# ('you', '?', '”')
# ('?', '”', '“')
# ('”', '“', 'but')
# ('“', 'but', ',')
# ('but', ',', 'mama')
# (',', 'mama', '!')
# ('mama', '!', '”')
# ('!', '”', 'protested')
# ('”', 'protested', 'sister')
# ('protested', 'sister', 'after')
# ('sister', 'after', 'mama')
# ('after', 'mama', 'hung')
# ('mama', 'hung', 'up')
# ('hung', 'up', 'the')
# ('up', 'the', 'phone')
# ('the', 'phone', '.')
# ('phone', '.', '“')
# ('.', '“', 'you')
# ('“', 'you', 'told')
# ('you', 'told', 'gran')
# ('told', 'gran', 'that')
# ('gran', 'that', 'everything')
# ('that', 'everything', 'is')
# ('everything', 'is', 'fine')
# ('is', 'fine', 'here')
# ('fine', 'here', ',')
# ('here', ',', 'and')
# (',', 'and', 'that')
# ('and', 'that', 'isn')
# ('that', 'isn', '’')
# ('isn', '’', 't')
# ('’', 't', 'really')
# ('t', 'really', 'the')
# ('really', 'the', 'truth.')
# ('the', 'truth.', '”')
# ('truth.', '”', '“')
# ('”', '“', 'oh')
# ('“', 'oh', ',')
# ('oh', ',', 'but')
# (',', 'but', 'it')
# ('but', 'it', 'is')
# ('it', 'is', ',')
# ('is', ',', '”')
# (',', '”', 'answered')
# ('”', 'answered', 'mama')
# ('answered', 'mama', '.')
# ('mama', '.', '“')
# ('.', '“', 'we')
# ('“', 'we', '’')
# ('we', '’', 've')
# ('’', 've', 'got')
# ('ve', 'got', 'two')
# ('got', 'two', 'fine')
# ('two', 'fine', 'cubs')
# ('fine', 'cubs', 'who')
# ('cubs', 'who', 'have')
# ('who', 'have', 'just')
# ('have', 'just', 'learned')
# ('just', 'learned', 'a')
# ('learned', 'a', 'very')
# ('a', 'very', 'important')
# ('very', 'important', 'lesson')
# ('important', 'lesson', 'about')
# ('lesson', 'about', 'telling')
# ('about', 'telling', 'the')
# ('telling', 'the', 'truth')
# ('the', 'truth', '.')
# ('truth', '.', 'and')
# ('.', 'and', 'what')
# ('and', 'what', 'could')
# ('what', 'could', 'be')
# ('could', 'be', 'finer')
# ('be', 'finer', 'than')
# ('finer', 'than', 'that')
# ('than', 'that', '?')
# ('that', '?', 'now')
# ('?', 'now', ',')
# ('now', ',', 'let')
# (',', 'let', '’')
# ('let', '’', 's')
# ('’', 's', 'help')
# ('s', 'help', 'papa')
# ('help', 'papa', 'glue')
# ('papa', 'glue', 'the')
# ('glue', 'the', 'lamp')
# ('the', 'lamp', 'back')
# ('lamp', 'back', 'together.')
# ('back', 'together.', '”')
# ('together.', '”', 'nobody')
# ('”', 'nobody', 'really')
# ('nobody', 'really', 'expects')
# ('really', 'expects', 'cubs')
# ('expects', 'cubs', 'to')
# ('cubs', 'to', 'be')
# ('to', 'be', 'perfect')
# ('be', 'perfect', ',')
# ('perfect', ',', 'and')
# (',', 'and', 'from')
# ('and', 'from', 'time')
# ('from', 'time', 'to')
# ('time', 'to', 'time')
# ('to', 'time', 'brother')
# ('time', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'bear')
# ('sister', 'bear', 'did')
# ('bear', 'did', 'forget')
# ('did', 'forget', 'the')
# ('forget', 'the', 'rules')
# ('the', 'rules', '.')
# ('rules', '.', 'brother')
# ('.', 'brother', 'ate')
# ('brother', 'ate', 'honey')
# ('ate', 'honey', 'in')
# ('honey', 'in', 'bed')
# ('in', 'bed', 'a')
# ('bed', 'a', 'couple')
# ('a', 'couple', 'of')
# ('couple', 'of', 'times')
# ('of', 'times', '.')
# ('times', '.', 'one')
# ('.', 'one', 'time')
# ('one', 'time', 'sister')
# ('time', 'sister', 'tracked')
# ('sister', 'tracked', 'a')
# ('tracked', 'a', 'little')
# ('a', 'little', 'mud')
# ('little', 'mud', 'on')
# ('mud', 'on', 'the')
# ('on', 'the', 'clean')
# ('the', 'clean', 'floor')
# ('clean', 'floor', '.')
# ('floor', '.', 'and')
# ('.', 'and', 'once')
# ('and', 'once', 'or')
# ('once', 'or', 'twice')
# ('or', 'twice', 'brother')
# ('twice', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'started')
# ('sister', 'started', 'to')
# ('started', 'to', 'play')
# ('to', 'play', 'ball')
# ('play', 'ball', 'in')
# ('ball', 'in', 'the')
# ('in', 'the', 'hose')
# ('the', 'hose', 'before')
# ('hose', 'before', 'they')
# ('before', 'they', 'remembered')
# ('they', 'remembered', 'not')
# ('remembered', 'not', 'to')
# ('not', 'to', '.')
# ('to', '.', 'but')
# ('.', 'but', 'they')
# ('but', 'they', 'never')
# ('they', 'never', ',')
# ('never', ',', 'ever')
# (',', 'ever', 'again')
# ('ever', 'again', 'told')
# ('again', 'told', 'a')
# ('told', 'a', 'whopper')
# ('a', 'whopper', '...')
# ('whopper', '...', 'because')
# ('...', 'because', 'trust')
# ('because', 'trust', 'is')
# ('trust', 'is', 'one')
# ('is', 'one', 'thing')
# ('one', 'thing', 'you')
# ('thing', 'you', 'can')
# ('you', 'can', '’')
# ('can', '’', 't')
# ('’', 't', 'put')
# ('t', 'put', 'back')
# ('put', 'back', 'together')
# ('back', 'together', 'once')
# ('together', 'once', 'it')
# ('once', 'it', '’')
# ('it', '’', 's')
# ('’', 's', 'broken.')
# ('s', 'broken.', '``')
# ('broken.', '``', '``')
# ('``', '``', 'the')
# ('``', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', ',')
# ('family', ',', 'who')
# (',', 'who', 'lived')
# ('who', 'lived', 'in')
# ('lived', 'in', 'the')
# ('in', 'the', 'big')
# ('the', 'big', 'tree')
# ('big', 'tree', 'house')
# ('tree', 'house', 'down')
# ('house', 'down', 'a')
# ('down', 'a', 'sunny')
# ('a', 'sunny', 'dirt')
# ('sunny', 'dirt', 'road')
# ('dirt', 'road', 'deep')
# ('road', 'deep', 'in')
# ('deep', 'in', 'bear')
# ('in', 'bear', 'country')
# ('bear', 'country', ',')
# ('country', ',', 'was')
# (',', 'was', 'a')
# ('was', 'a', 'very')
# ('a', 'very', 'happy')
# ('very', 'happy', 'family')
# ('happy', 'family', '.')
# ('family', '.', 'one')
# ('.', 'one', 'of')
# ('one', 'of', 'the')
# ('of', 'the', 'reasons')
# ('the', 'reasons', 'was')
# ('reasons', 'was', 'that')
# ('was', 'that', 'they')
# ('that', 'they', 'were')
# ('they', 'were', 'all')
# ('were', 'all', 'very')
# ('all', 'very', 'busy')
# ('very', 'busy', '.')
# ('busy', '.', 'each')
# ('.', 'each', 'member')
# ('each', 'member', 'of')
# ('member', 'of', 'the')
# ('of', 'the', 'family')
# ('the', 'family', 'had')
# ('family', 'had', 'work')
# ('had', 'work', 'to')
# ('work', 'to', 'do')
# ('to', 'do', '.')
# ('do', '.', 'papa')
# ('.', 'papa', 'bear')
# ('papa', 'bear', 'cut')
# ('bear', 'cut', 'and')
# ('cut', 'and', 'split')
# ('and', 'split', 'logs')
# ('split', 'logs', 'and')
# ('logs', 'and', 'made')
# ('and', 'made', 'the')
# ('made', 'the', 'wood')
# ('the', 'wood', 'into')
# ('wood', 'into', 'handsome')
# ('into', 'handsome', 'furniture')
# ('handsome', 'furniture', 'which')
# ('furniture', 'which', 'he')
# ('which', 'he', 'was')
# ('he', 'was', 'proud')
# ('was', 'proud', 'to')
# ('proud', 'to', 'sell')
# ('to', 'sell', '.')
# ('sell', '.', 'mama')
# ('.', 'mama', 'bear')
# ('mama', 'bear', 'not')
# ('bear', 'not', 'only')
# ('not', 'only', 'took')
# ('only', 'took', 'care')
# ('took', 'care', 'of')
# ('care', 'of', 'her')
# ('of', 'her', 'family')
# ('her', 'family', ',')
# ('family', ',', 'but')
# (',', 'but', 'she')
# ('but', 'she', 'managed')
# ('she', 'managed', 'the')
# ('managed', 'the', 'whole')
# ('the', 'whole', 'tree')
# ('whole', 'tree', 'house')
# ('tree', 'house', 'and')
# ('house', 'and', 'tended')
# ('and', 'tended', 'the')
# ('tended', 'the', 'vegetable')
# ('the', 'vegetable', 'patch')
# ('vegetable', 'patch', 'as')
# ('patch', 'as', 'well')
# ('as', 'well', '.')
# ('well', '.', 'and')
# ('.', 'and', ',')
# ('and', ',', 'of')
# (',', 'of', 'course')
# ('of', 'course', ',')
# ('course', ',', 'brother')
# (',', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'bear')
# ('sister', 'bear', 'had')
# ('bear', 'had', 'important')
# ('had', 'important', 'jobs')
# ('important', 'jobs', 'too')
# ('jobs', 'too', ':')
# ('too', ':', 'going')
# (':', 'going', 'to')
# ('going', 'to', 'school')
# ('to', 'school', 'and')
# ('school', 'and', 'keeping')
# ('and', 'keeping', 'up')
# ('keeping', 'up', 'with')
# ('up', 'with', 'their')
# ('with', 'their', 'schoolwork')
# ('their', 'schoolwork', '.')
# ('schoolwork', '.', 'the')
# ('.', 'the', 'members')
# ('the', 'members', 'of')
# ('members', 'of', 'the')
# ('of', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', 'had')
# ('family', 'had', 'hobbies')
# ('had', 'hobbies', ',')
# ('hobbies', ',', 'too')
# (',', 'too', '.')
# ('too', '.', 'papa')
# ('.', 'papa', '’')
# ('papa', '’', 's')
# ('’', 's', 'favorite')
# ('s', 'favorite', 'hobbies')
# ('favorite', 'hobbies', 'were')
# ('hobbies', 'were', 'fishing')
# ('were', 'fishing', 'and')
# ('fishing', 'and', 'napping')
# ('and', 'napping', '.')
# ('napping', '.', 'he')
# ('.', 'he', 'caught')
# ('he', 'caught', 'almost')
# ('caught', 'almost', 'as')
# ('almost', 'as', 'many')
# ('as', 'many', 'naps')
# ('many', 'naps', 'as')
# ('naps', 'as', 'he')
# ('as', 'he', 'caught')
# ('he', 'caught', 'fish')
# ('caught', 'fish', '.')
# ('fish', '.', 'brother')
# ('.', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'also')
# ('sister', 'also', 'had')
# ('also', 'had', 'many')
# ('had', 'many', 'hobbies')
# ('many', 'hobbies', '.')
# ('hobbies', '.', 'brother')
# ('.', 'brother', 'was')
# ('brother', 'was', 'especially')
# ('was', 'especially', 'proud')
# ('especially', 'proud', 'of')
# ('proud', 'of', 'his')
# ('of', 'his', 'model')
# ('his', 'model', 'airplanes')
# ('model', 'airplanes', '.')
# ('airplanes', '.', 'he')
# ('.', 'he', 'liked')
# ('he', 'liked', 'to')
# ('liked', 'to', 'have')
# ('to', 'have', 'mama')
# ('have', 'mama', 'watch')
# ('mama', 'watch', 'him')
# ('watch', 'him', 'fly')
# ('him', 'fly', 'his')
# ('fly', 'his', 'models')
# ('his', 'models', ',')
# ('models', ',', 'and')
# (',', 'and', 'sometimes')
# ('and', 'sometimes', 'she')
# ('sometimes', 'she', 'helped')
# ('she', 'helped', 'him')
# ('helped', 'him', 'fly')
# ('him', 'fly', 'his')
# ('fly', 'his', 'tether')
# ('his', 'tether', 'plane')
# ('tether', 'plane', '.')
# ('plane', '.', 'sister')
# ('.', 'sister', 'was')
# ('sister', 'was', 'a')
# ('was', 'a', 'super')
# ('a', 'super', 'rope-jumper')
# ('super', 'rope-jumper', 'and')
# ('rope-jumper', 'and', 'her')
# ('and', 'her', 'goal')
# ('her', 'goal', 'was')
# ('goal', 'was', 'to')
# ('was', 'to', 'jump')
# ('to', 'jump', 'a')
# ('jump', 'a', 'thousand')
# ('a', 'thousand', 'times')
# ('thousand', 'times', 'without')
# ('times', 'without', 'a')
# ('without', 'a', 'miss')
# ('a', 'miss', '.')
# ('miss', '.', 'she')
# ('.', 'she', 'liked')
# ('she', 'liked', 'to')
# ('liked', 'to', 'have')
# ('to', 'have', 'mama')
# ('have', 'mama', 'count')
# ('mama', 'count', 'for')
# ('count', 'for', 'her')
# ('for', 'her', 'because')
# ('her', 'because', 'sister')
# ('because', 'sister', 'could')
# ('sister', 'could', 'jump')
# ('could', 'jump', 'faster')
# ('jump', 'faster', 'than')
# ('faster', 'than', 'she')
# ('than', 'she', 'could')
# ('she', 'could', 'count')
# ('could', 'count', '.')
# ('count', '.', 'since')
# ('.', 'since', 'mama')
# ('since', 'mama', 'was')
# ('mama', 'was', 'so')
# ('was', 'so', 'busy')
# ('so', 'busy', 'with')
# ('busy', 'with', 'her')
# ('with', 'her', 'household')
# ('her', 'household', 'duties')
# ('household', 'duties', ',')
# ('duties', ',', 'she')
# (',', 'she', 'had')
# ('she', 'had', 'time')
# ('had', 'time', 'for')
# ('time', 'for', 'just')
# ('for', 'just', 'one')
# ('just', 'one', 'hobby—but')
# ('one', 'hobby—but', 'what')
# ('hobby—but', 'what', 'a')
# ('what', 'a', 'hobby')
# ('a', 'hobby', '!')
# ('hobby', '!', 'mama')
# ('!', 'mama', 'was')
# ('mama', 'was', 'the')
# ('was', 'the', 'best')
# ('the', 'best', 'quilt')
# ('best', 'quilt', 'maker')
# ('quilt', 'maker', 'in')
# ('maker', 'in', 'all')
# ('in', 'all', 'of')
# ('all', 'of', 'bear')
# ('of', 'bear', 'country')
# ('bear', 'country', '!')
# ('country', '!', 'her')
# ('!', 'her', 'quilts')
# ('her', 'quilts', 'were')
# ('quilts', 'were', 'light')
# ('were', 'light', 'and')
# ('light', 'and', 'fluffy')
# ('and', 'fluffy', ',')
# ('fluffy', ',', 'but')
# (',', 'but', 'very')
# ('but', 'very', 'warm')
# ('very', 'warm', '.')
# ('warm', '.', 'her')
# ('.', 'her', 'stitchery')
# ('her', 'stitchery', 'was')
# ('stitchery', 'was', 'fine')
# ('was', 'fine', 'and')
# ('fine', 'and', 'even')
# ('and', 'even', '.')
# ('even', '.', 'and')
# ('.', 'and', 'her')
# ('and', 'her', 'designs')
# ('her', 'designs', 'were')
# ('designs', 'were', 'original')
# ('were', 'original', 'and')
# ('original', 'and', 'exciting')
# ('and', 'exciting', '.')
# ('exciting', '.', 'sister')
# ('.', 'sister', 'bear')
# ('sister', 'bear', 'slept')
# ('bear', 'slept', 'cozy')
# ('slept', 'cozy', 'and')
# ('cozy', 'and', 'warm')
# ('and', 'warm', 'under')
# ('warm', 'under', 'a')
# ('under', 'a', 'quilt')
# ('a', 'quilt', 'that')
# ('quilt', 'that', 'showed')
# ('that', 'showed', 'her')
# ('showed', 'her', 'jumping')
# ('her', 'jumping', 'rope')
# ('jumping', 'rope', '.')
# ('rope', '.', 'brother')
# ('.', 'brother', 'went')
# ('brother', 'went', 'to')
# ('went', 'to', 'sleep')
# ('to', 'sleep', 'under')
# ('sleep', 'under', 'a')
# ('under', 'a', 'handsome')
# ('a', 'handsome', 'airplane')
# ('handsome', 'airplane', 'design')
# ('airplane', 'design', '.')
# ('design', '.', 'and')
# ('.', 'and', 'the')
# ('and', 'the', 'big')
# ('the', 'big', 'quilt')
# ('big', 'quilt', 'on')
# ('quilt', 'on', 'mama')
# ('on', 'mama', 'and')
# ('mama', 'and', 'papa')
# ('and', 'papa', '’')
# ('papa', '’', 's')
# ('’', 's', 'bed')
# ('s', 'bed', 'showed')
# ('bed', 'showed', 'the')
# ('showed', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', '’')
# ('family', '’', 's')
# ('’', 's', 'beautiful')
# ('s', 'beautiful', 'tree')
# ('beautiful', 'tree', 'house')
# ('tree', 'house', '.')
# ('house', '.', 'yes')
# ('.', 'yes', ',')
# ('yes', ',', 'the')
# (',', 'the', 'members')
# ('the', 'members', 'of')
# ('members', 'of', 'the')
# ('of', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', 'had')
# ('family', 'had', 'happy')
# ('had', 'happy', ',')
# ('happy', ',', 'busy')
# (',', 'busy', ',')
# ('busy', ',', 'full')
# (',', 'full', 'lives')
# ('full', 'lives', '.')
# ('lives', '.', 'especially')
# ('.', 'especially', 'mama')
# ('especially', 'mama', '.')
# ('mama', '.', '“')
# ('.', '“', 'my')
# ('“', 'my', 'dear')
# ('my', 'dear', ',')
# ('dear', ',', '”')
# (',', '”', 'called')
# ('”', 'called', 'papa')
# ('called', 'papa', 'to')
# ('papa', 'to', 'mama')
# ('to', 'mama', 'as')
# ('mama', 'as', 'she')
# ('as', 'she', 'worked')
# ('she', 'worked', 'in')
# ('worked', 'in', 'the')
# ('in', 'the', 'vegetable')
# ('the', 'vegetable', 'patch')
# ('vegetable', 'patch', ',')
# ('patch', ',', '“')
# (',', '“', 'if')
# ('“', 'if', 'it')
# ('if', 'it', 'wouldn')
# ('it', 'wouldn', '’')
# ('wouldn', '’', 't')
# ('’', 't', 'be')
# ('t', 'be', 'too')
# ('be', 'too', 'much')
# ('too', 'much', 'trouble')
# ('much', 'trouble', ',')
# ('trouble', ',', 'would')
# (',', 'would', 'you')
# ('would', 'you', 'put')
# ('you', 'put', 'aside')
# ('put', 'aside', 'any')
# ('aside', 'any', 'fishing')
# ('any', 'fishing', 'worms')
# ('fishing', 'worms', 'you')
# ('worms', 'you', 'might')
# ('you', 'might', 'find')
# ('might', 'find', '?')
# ('find', '?', '”')
# ('?', '”', '“')
# ('”', '“', 'look')
# ('“', 'look', ',')
# ('look', ',', 'mama')
# (',', 'mama', '!')
# ('mama', '!', '”')
# ('!', '”', 'called')
# ('”', 'called', 'brother')
# ('called', 'brother', '.')
# ('brother', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', '’')
# ('i', '’', 'm')
# ('’', 'm', 'going')
# ('m', 'going', 'to')
# ('going', 'to', 'fly')
# ('to', 'fly', 'my')
# ('fly', 'my', 'new')
# ('my', 'new', 'biplane')
# ('new', 'biplane', '!')
# ('biplane', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'i')
# ('“', 'i', '’')
# ('i', '’', 'm')
# ('’', 'm', 'going')
# ('m', 'going', 'to')
# ('going', 'to', 'try')
# ('to', 'try', 'for')
# ('try', 'for', 'a')
# ('for', 'a', 'thousand')
# ('a', 'thousand', ',')
# ('thousand', ',', 'mama')
# (',', 'mama', '!')
# ('mama', '!', '”')
# ('!', '”', 'said')
# ('”', 'said', 'sister')
# ('said', 'sister', '.')
# ('sister', '.', '“')
# ('.', '“', 'would')
# ('“', 'would', 'you')
# ('would', 'you', 'please')
# ('you', 'please', 'count')
# ('please', 'count', 'for')
# ('count', 'for', 'me')
# ('for', 'me', '?')
# ('me', '?', '”')
# ('?', '”', 'a')
# ('”', 'a', 'little')
# ('a', 'little', 'too')
# ('little', 'too', 'full')
# ('too', 'full', ',')
# ('full', ',', 'thought')
# (',', 'thought', 'mama')
# ('thought', 'mama', 'from')
# ('mama', 'from', 'time')
# ('from', 'time', 'to')
# ('time', 'to', 'time')
# ('to', 'time', '.')
# ('time', '.', 'she')
# ('.', 'she', 'would')
# ('she', 'would', 'have')
# ('would', 'have', 'liked')
# ('have', 'liked', 'to')
# ('liked', 'to', 'have')
# ('to', 'have', 'a')
# ('have', 'a', 'little')
# ('a', 'little', 'more')
# ('little', 'more', 'time')
# ('more', 'time', 'for')
# ('time', 'for', 'her')
# ('for', 'her', 'quilts')
# ('her', 'quilts', '.')
# ('quilts', '.', 'she')
# ('.', 'she', 'had')
# ('she', 'had', 'some')
# ('had', 'some', 'lovely')
# ('some', 'lovely', 'design')
# ('lovely', 'design', 'ideas')
# ('design', 'ideas', 'she')
# ('ideas', 'she', 'wanted')
# ('she', 'wanted', 'to')
# ('wanted', 'to', 'try')
# ('to', 'try', ':')
# ('try', ':', 'a')
# (':', 'a', 'sunburst')
# ('a', 'sunburst', 'with')
# ('sunburst', 'with', 'clouds')
# ('with', 'clouds', 'and')
# ('clouds', 'and', 'bluebirds')
# ('and', 'bluebirds', '...')
# ('bluebirds', '...', 'a')
# ('...', 'a', 'beautiful')
# ('a', 'beautiful', 'bouquet')
# ('beautiful', 'bouquet', 'of')
# ('bouquet', 'of', 'flowers')
# ('of', 'flowers', 'with')
# ('flowers', 'with', 'butterflies')
# ('with', 'butterflies', '...')
# ('butterflies', '...', 'and')
# ('...', 'and', 'a')
# ('and', 'a', 'harvest')
# ('a', 'harvest', 'scene')
# ('harvest', 'scene', 'with')
# ('scene', 'with', 'pumpkins')
# ('with', 'pumpkins', 'and')
# ('pumpkins', 'and', 'squash')
# ('and', 'squash', '.')
# ('squash', '.', 'but')
# ('.', 'but', 'there')
# ('but', 'there', 'just')
# ('there', 'just', 'never')
# ('just', 'never', 'seemed')
# ('never', 'seemed', 'to')
# ('seemed', 'to', 'be')
# ('to', 'be', 'enough')
# ('be', 'enough', 'time')
# ('enough', 'time', '.')
# ('time', '.', 'then')
# ('.', 'then', 'one')
# ('then', 'one', 'day')
# ('one', 'day', 'something')
# ('day', 'something', 'happed')
# ('something', 'happed', 'that')
# ('happed', 'that', 'changed')
# ('that', 'changed', 'the')
# ('changed', 'the', 'lives')
# ('the', 'lives', 'of')
# ('lives', 'of', 'the')
# ('of', 'the', 'bear')
# ('the', 'bear', 'family—something')
# ('bear', 'family—something', 'that')
# ('family—something', 'that', 'changed')
# ('that', 'changed', 'mama')
# ('changed', 'mama', '’')
# ('mama', '’', 's')
# ('’', 's', 'quilt-making')
# ('s', 'quilt-making', 'from')
# ('quilt-making', 'from', 'a')
# ('from', 'a', 'hobby')
# ('a', 'hobby', '...')
# ('hobby', '...', 'into')
# ('...', 'into', 'a')
# ('into', 'a', 'business')
# ('a', 'business', '!')
# ('business', '!', 'it')
# ('!', 'it', 'might')
# ('it', 'might', 'not')
# ('might', 'not', 'have')
# ('not', 'have', 'happened')
# ('have', 'happened', 'except')
# ('happened', 'except', 'for')
# ('except', 'for', 'a')
# ('for', 'a', 'coincidence')
# ('a', 'coincidence', ',')
# ('coincidence', ',', 'which')
# (',', 'which', 'is')
# ('which', 'is', 'when')
# ('is', 'when', 'two')
# ('when', 'two', 'things')
# ('two', 'things', 'happen')
# ('things', 'happen', 'at')
# ('happen', 'at', 'the')
# ('at', 'the', 'same')
# ('the', 'same', 'time')
# ('same', 'time', '.')
# ('time', '.', 'the')
# ('.', 'the', 'two')
# ('the', 'two', 'things')
# ('two', 'things', 'that')
# ('things', 'that', 'happened')
# ('that', 'happened', 'were')
# ('happened', 'were', 'that')
# ('were', 'that', 'papa')
# ('that', 'papa', 'had')
# ('papa', 'had', 'a')
# ('had', 'a', 'big')
# ('a', 'big', 'sale')
# ('big', 'sale', 'of')
# ('sale', 'of', 'some')
# ('of', 'some', 'very')
# ('some', 'very', 'special')
# ('very', 'special', 'furniture')
# ('special', 'furniture', ',')
# ('furniture', ',', 'and')
# (',', 'and', 'on')
# ('and', 'on', 'the')
# ('on', 'the', 'same')
# ('the', 'same', 'day')
# ('same', 'day', 'mama')
# ('day', 'mama', 'hung')
# ('mama', 'hung', 'out')
# ('hung', 'out', 'the')
# ('out', 'the', 'family')
# ('the', 'family', 'quilts')
# ('family', 'quilts', 'to')
# ('quilts', 'to', 'air')
# ('to', 'air', '.')
# ('air', '.', 'folks')
# ('.', 'folks', 'who')
# ('folks', 'who', 'came')
# ('who', 'came', 'to')
# ('came', 'to', 'buy')
# ('to', 'buy', 'papa')
# ('buy', 'papa', '’')
# ('papa', '’', 's')
# ('’', 's', 'handsome')
# ('s', 'handsome', 'furniture')
# ('handsome', 'furniture', 'became')
# ('furniture', 'became', 'excited')
# ('became', 'excited', 'about')
# ('excited', 'about', 'mama')
# ('about', 'mama', '’')
# ('mama', '’', 's')
# ('’', 's', 'beautiful')
# ('s', 'beautiful', 'quilts')
# ('beautiful', 'quilts', 'and')
# ('quilts', 'and', 'wanted')
# ('and', 'wanted', 'to')
# ('wanted', 'to', 'buy')
# ('to', 'buy', 'them')
# ('buy', 'them', ',')
# ('them', ',', 'too')
# (',', 'too', '.')
# ('too', '.', 'would-be')
# ('.', 'would-be', 'buyers')
# ('would-be', 'buyers', 'offered')
# ('buyers', 'offered', 'mama')
# ('offered', 'mama', 'quite')
# ('mama', 'quite', 'a')
# ('quite', 'a', 'lot')
# ('a', 'lot', 'of')
# ('lot', 'of', 'money')
# ('of', 'money', '.')
# ('money', '.', 'they')
# ('.', 'they', 'were')
# ('they', 'were', 'very')
# ('were', 'very', 'disappointed')
# ('very', 'disappointed', 'when')
# ('disappointed', 'when', 'she')
# ('when', 'she', 'told')
# ('she', 'told', 'them')
# ('told', 'them', 'that')
# ('them', 'that', 'the')
# ('that', 'the', 'quilts')
# ('the', 'quilts', 'were')
# ('quilts', 'were', 'not')
# ('were', 'not', 'for')
# ('not', 'for', 'sale')
# ('for', 'sale', '.')
# ('sale', '.', '“')
# ('.', '“', 'with')
# ('“', 'with', 'your')
# ('with', 'your', 'talent')
# ('your', 'talent', ',')
# ('talent', ',', 'you')
# (',', 'you', 'really')
# ('you', 'really', 'should')
# ('really', 'should', 'be')
# ('should', 'be', 'in')
# ('be', 'in', 'business')
# ('in', 'business', '!')
# ('business', '!', '”')
# ('!', '”', 'they')
# ('”', 'they', 'said')
# ('they', 'said', '.')
# ('said', '.', '“')
# ('.', '“', 'mama')
# ('“', 'mama', 'in')
# ('mama', 'in', 'business')
# ('in', 'business', '?')
# ('business', '?', '”')
# ('?', '”', 'said')
# ('”', 'said', 'papa')
# ('said', 'papa', ',')
# ('papa', ',', 'patting')
# (',', 'patting', 'her')
# ('patting', 'her', 'on')
# ('her', 'on', 'the')
# ('on', 'the', 'shoulder')
# ('the', 'shoulder', '.')
# ('shoulder', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', 'don')
# ('i', 'don', '’')
# ('don', '’', 't')
# ('’', 't', 'think')
# ('t', 'think', 'so')
# ('think', 'so', '.')
# ('so', '.', 'one')
# ('.', 'one', 'business-bear')
# ('one', 'business-bear', 'in')
# ('business-bear', 'in', 'the')
# ('in', 'the', 'family')
# ('the', 'family', 'is')
# ('family', 'is', 'enough.')
# ('is', 'enough.', '”')
# ('enough.', '”', 'but')
# ('”', 'but', 'mama')
# ('but', 'mama', 'wasn')
# ('mama', 'wasn', '’')
# ('wasn', '’', 't')
# ('’', 't', 'so')
# ('t', 'so', 'sure')
# ('so', 'sure', '.')
# ('sure', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'proud')
# ('was', 'proud', 'of')
# ('proud', 'of', 'her')
# ('of', 'her', 'quilt-making')
# ('her', 'quilt-making', 'skills')
# ('quilt-making', 'skills', 'and')
# ('skills', 'and', 'knowledge')
# ('and', 'knowledge', '.')
# ('knowledge', '.', 'after')
# ('.', 'after', 'all')
# ('after', 'all', ',')
# ('all', ',', 'she')
# (',', 'she', 'was')
# ('she', 'was', 'president')
# ('was', 'president', 'of')
# ('president', 'of', 'the')
# ('of', 'the', 'bear')
# ('the', 'bear', 'country')
# ('bear', 'country', 'quilting')
# ('country', 'quilting', 'club')
# ('quilting', 'club', '.')
# ('club', '.', 'other')
# ('.', 'other', 'quilt')
# ('other', 'quilt', 'makers')
# ('quilt', 'makers', 'often')
# ('makers', 'often', 'came')
# ('often', 'came', 'to')
# ('came', 'to', 'her')
# ('to', 'her', 'for')
# ('her', 'for', 'help')
# ('for', 'help', 'and')
# ('help', 'and', 'advice')
# ('and', 'advice', '.')
# ('advice', '.', 'that')
# ('.', 'that', 'evening')
# ('that', 'evening', 'papa')
# ('evening', 'papa', 'and')
# ('papa', 'and', 'the')
# ('and', 'the', 'cubs')
# ('the', 'cubs', 'noticed')
# ('cubs', 'noticed', 'that')
# ('noticed', 'that', 'mama')
# ('that', 'mama', 'was')
# ('mama', 'was', 'very')
# ('was', 'very', 'quiet')
# ('very', 'quiet', '.')
# ('quiet', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'quiet')
# ('was', 'quiet', 'during')
# ('quiet', 'during', 'supper')
# ('during', 'supper', '.')
# ('supper', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'quiet')
# ('was', 'quiet', 'during')
# ('quiet', 'during', 'cleanup')
# ('during', 'cleanup', '.')
# ('cleanup', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'quiet')
# ('was', 'quiet', 'all')
# ('quiet', 'all', 'evening')
# ('all', 'evening', '.')
# ('evening', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'quiet')
# ('was', 'quiet', 'because')
# ('quiet', 'because', 'she')
# ('because', 'she', 'was')
# ('she', 'was', 'thinking—thinking')
# ('was', 'thinking—thinking', 'about')
# ('thinking—thinking', 'about', 'going')
# ('about', 'going', 'into')
# ('going', 'into', 'business')
# ('into', 'business', '.')
# ('business', '.', 'the')
# ('.', 'the', 'next')
# ('the', 'next', 'day')
# ('next', 'day', 'at')
# ('day', 'at', 'lunch')
# ('at', 'lunch', 'she')
# ('lunch', 'she', 'made')
# ('she', 'made', 'her')
# ('made', 'her', 'big')
# ('her', 'big', 'announcement')
# ('big', 'announcement', '.')
# ('announcement', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', '’')
# ('i', '’', 've')
# ('’', 've', 'decided')
# ('ve', 'decided', 'to')
# ('decided', 'to', 'open')
# ('to', 'open', 'up')
# ('open', 'up', 'a')
# ('up', 'a', 'quilt')
# ('a', 'quilt', 'shop.')
# ('quilt', 'shop.', '”')
# ('shop.', '”', 'she')
# ('”', 'she', 'said')
# ('she', 'said', ',')
# ('said', ',', '“')
# (',', '“', 'and')
# ('“', 'and', 'i')
# ('and', 'i', '’')
# ('i', '’', 've')
# ('’', 've', 'rented')
# ('ve', 'rented', 'the')
# ('rented', 'the', 'empty')
# ('the', 'empty', 'store')
# ('empty', 'store', 'just')
# ('store', 'just', 'down')
# ('just', 'down', 'the')
# ('down', 'the', 'road.')
# ('the', 'road.', '”')
# ('road.', '”', '“')
# ('”', '“', 'not')
# ('“', 'not', 'that')
# ('not', 'that', 'overgrown')
# ('that', 'overgrown', 'wreck')
# ('overgrown', 'wreck', 'that')
# ('wreck', 'that', '’')
# ('that', '’', 's')
# ('’', 's', 'been')
# ('s', 'been', 'empty')
# ('been', 'empty', 'for')
# ('empty', 'for', 'years')
# ('for', 'years', '!')
# ('years', '!', '”')
# ('!', '”', 'protested')
# ('”', 'protested', 'papa')
# ('protested', 'papa', '.')
# ('papa', '.', '“')
# ('.', '“', 'but')
# ('“', 'but', 'you')
# ('but', 'you', 'don')
# ('you', 'don', '’')
# ('don', '’', 't')
# ('’', 't', 'want')
# ('t', 'want', 'to')
# ('want', 'to', 'be')
# ('to', 'be', 'a')
# ('be', 'a', 'business-bear')
# ('a', 'business-bear', ',')
# ('business-bear', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'sister')
# ('said', 'sister', '.')
# ('sister', '.', '“')
# ('.', '“', 'you')
# ('“', 'you', '’')
# ('you', '’', 're')
# ('’', 're', 'our')
# ('re', 'our', 'mama')
# ('our', 'mama', '!')
# ('mama', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'that')
# ('“', 'that', '’')
# ('that', '’', 's')
# ('’', 's', 'no')
# ('s', 'no', 'reason')
# ('no', 'reason', 'why')
# ('reason', 'why', 'i')
# ('why', 'i', 'shouldn')
# ('i', 'shouldn', '’')
# ('shouldn', '’', 't')
# ('’', 't', 'open')
# ('t', 'open', 'my')
# ('open', 'my', 'own')
# ('my', 'own', 'quilt')
# ('own', 'quilt', 'shop')
# ('quilt', 'shop', '.')
# ('shop', '.', 'a')
# ('.', 'a', 'lot')
# ('a', 'lot', 'of')
# ('lot', 'of', 'mama')
# ('of', 'mama', 'bears')
# ('mama', 'bears', 'have')
# ('bears', 'have', 'jobs')
# ('have', 'jobs', ':')
# ('jobs', ':', 'mrs.')
# (':', 'mrs.', 'grizzle')
# ('mrs.', 'grizzle', 'is')
# ('grizzle', 'is', 'a')
# ('is', 'a', 'sister')
# ('a', 'sister', ';')
# ('sister', ';', 'mrs.')
# (';', 'mrs.', 'honeybear')
# ('mrs.', 'honeybear', 'teaches')
# ('honeybear', 'teaches', 'school')
# ('teaches', 'school', ';')
# ('school', ';', 'dr.')
# (';', 'dr.', 'gert')
# ('dr.', 'gert', 'grizzly')
# ('gert', 'grizzly', 'is')
# ('grizzly', 'is', 'your')
# ('is', 'your', 'pediatrician')
# ('your', 'pediatrician', '...')
# ('pediatrician', '...', '”')
# ('...', '”', '“')
# ('”', '“', 'yeah')
# ('“', 'yeah', ',')
# ('yeah', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'brother')
# ('said', 'brother', ',')
# ('brother', ',', '“')
# (',', '“', 'but')
# ('“', 'but', 'they')
# ('but', 'they', '’')
# ('they', '’', 're')
# ('’', 're', 'not')
# ('re', 'not', 'our')
# ('not', 'our', 'mama')
# ('our', 'mama', '!')
# ('mama', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'there')
# ('“', 'there', '’')
# ('there', '’', 's')
# ('’', 's', 'really')
# ('s', 'really', 'nothing')
# ('really', 'nothing', 'to')
# ('nothing', 'to', 'worry')
# ('to', 'worry', 'about')
# ('worry', 'about', ',')
# ('about', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'mama')
# ('said', 'mama', '.')
# ('mama', '.', '“')
# ('.', '“', 'things')
# ('“', 'things', 'aren')
# ('things', 'aren', '’')
# ('aren', '’', 't')
# ('’', 't', 'going')
# ('t', 'going', 'to')
# ('going', 'to', 'be')
# ('to', 'be', 'all')
# ('be', 'all', 'that')
# ('all', 'that', 'different.')
# ('that', 'different.', '”')
# ('different.', '”', '“')
# ('”', '“', 'will')
# ('“', 'will', 'you')
# ('will', 'you', 'still')
# ('you', 'still', 'count')
# ('still', 'count', 'for')
# ('count', 'for', 'me')
# ('for', 'me', 'when')
# ('me', 'when', 'i')
# ('when', 'i', 'jump')
# ('i', 'jump', 'rope')
# ('jump', 'rope', '?')
# ('rope', '?', '”')
# ('?', '”', 'asked')
# ('”', 'asked', 'sister')
# ('asked', 'sister', '.')
# ('sister', '.', '“')
# ('.', '“', 'and')
# ('“', 'and', 'will')
# ('and', 'will', 'you')
# ('will', 'you', 'still')
# ('you', 'still', 'watch')
# ('still', 'watch', 'my')
# ('watch', 'my', 'fly')
# ('my', 'fly', 'my')
# ('fly', 'my', 'airplanes')
# ('my', 'airplanes', '?')
# ('airplanes', '?', '”')
# ('?', '”', 'brother')
# ('”', 'brother', 'wanted')
# ('brother', 'wanted', 'to')
# ('wanted', 'to', 'know')
# ('to', 'know', '.')
# ('know', '.', '“')
# ('.', '“', 'and')
# ('“', 'and', 'how')
# ('and', 'how', 'about')
# ('how', 'about', 'my')
# ('about', 'my', 'fishing')
# ('my', 'fishing', 'worms')
# ('fishing', 'worms', '?')
# ('worms', '?', '”')
# ('?', '”', 'asked')
# ('”', 'asked', 'papa')
# ('asked', 'papa', '.')
# ('papa', '.', '“')
# ('.', '“', 'will')
# ('“', 'will', 'you')
# ('will', 'you', 'still')
# ('you', 'still', 'put')
# ('still', 'put', 'them')
# ('put', 'them', 'aside')
# ('them', 'aside', 'for')
# ('aside', 'for', 'me')
# ('for', 'me', 'when')
# ('me', 'when', 'you')
# ('when', 'you', 'tend')
# ('you', 'tend', 'the')
# ('tend', 'the', 'vegetable')
# ('the', 'vegetable', 'patch')
# ('vegetable', 'patch', '?')
# ('patch', '?', '”')
# ('?', '”', '“')
# ('”', '“', 'we')
# ('“', 'we', '’')
# ('we', '’', 'll')
# ('’', 'll', 'see')
# ('ll', 'see', 'about')
# ('see', 'about', 'all')
# ('about', 'all', 'that')
# ('all', 'that', ',')
# ('that', ',', '”')
# (',', '”', 'mama')
# ('”', 'mama', 'said')
# ('mama', 'said', '.')
# ('said', '.', '“')
# ('.', '“', 'meanwhile')
# ('“', 'meanwhile', ',')
# ('meanwhile', ',', 'i')
# (',', 'i', 'have')
# ('i', 'have', 'to')
# ('have', 'to', 'be')
# ('to', 'be', 'at')
# ('be', 'at', 'the')
# ('at', 'the', 'shop')
# ('the', 'shop', '.')
# ('shop', '.', 'some')
# ('.', 'some', 'of')
# ('some', 'of', 'my')
# ('of', 'my', 'quilt')
# ('my', 'quilt', 'club')
# ('quilt', 'club', 'friends')
# ('club', 'friends', 'are')
# ('friends', 'are', 'helping')
# ('are', 'helping', 'me')
# ('helping', 'me', 'get')
# ('me', 'get', 'it')
# ('get', 'it', 'ready—and')
# ('it', 'ready—and', ',')
# ('ready—and', ',', 'oh')
# (',', 'oh', 'yes')
# ('oh', 'yes', ',')
# ('yes', ',', '”')
# (',', '”', 'she')
# ('”', 'she', 'added')
# ('she', 'added', 'as')
# ('added', 'as', 'she')
# ('as', 'she', 'turned')
# ('she', 'turned', 'to')
# ('turned', 'to', 'leave')
# ('to', 'leave', ',')
# ('leave', ',', '“')
# (',', '“', 'there')
# ('“', 'there', '’')
# ('there', '’', 's')
# ('’', 's', 'a')
# ('s', 'a', 'lot')
# ('a', 'lot', 'to')
# ('lot', 'to', 'do')
# ('to', 'do', ',')
# ('do', ',', 'so')
# (',', 'so', 'supper')
# ('so', 'supper', 'may')
# ('supper', 'may', 'be')
# ('may', 'be', 'a')
# ('be', 'a', 'little')
# ('a', 'little', 'late')
# ('little', 'late', 'tonight')
# ('late', 'tonight', '.')
# ('tonight', '.', 'ta-ta')
# ('.', 'ta-ta', '!')
# ('ta-ta', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'ta-ta')
# ('“', 'ta-ta', ',')
# ('ta-ta', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'papa')
# ('said', 'papa', '.')
# ('papa', '.', '“')
# ('.', '“', 'ta-ta')
# ('“', 'ta-ta', ',')
# ('ta-ta', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'the')
# ('said', 'the', 'cubs')
# ('the', 'cubs', '.')
# ('cubs', '.', 'supper')
# ('.', 'supper', 'wasn')
# ('supper', 'wasn', '’')
# ('wasn', '’', 't')
# ('’', 't', 'a')
# ('t', 'a', 'little')
# ('a', 'little', 'late')
# ('little', 'late', 'that')
# ('late', 'that', 'night')
# ('that', 'night', '.')
# ('night', '.', 'it')
# ('.', 'it', 'was')
# ('it', 'was', 'a')
# ('was', 'a', 'lot')
# ('a', 'lot', 'late—and')
# ('lot', 'late—and', 'it')
# ('late—and', 'it', 'was')
# ('it', 'was', 'papa')
# ('was', 'papa', 'and')
# ('papa', 'and', 'the')
# ('and', 'the', 'cubs')
# ('the', 'cubs', 'who')
# ('cubs', 'who', 'prepared')
# ('who', 'prepared', 'it')
# ('prepared', 'it', '.')
# ('it', '.', 'but')
# ('.', 'but', 'they')
# ('but', 'they', 'didn')
# ('they', 'didn', '’')
# ('didn', '’', 't')
# ('’', 't', 'mind')
# ('t', 'mind', ',')
# ('mind', ',', 'because')
# (',', 'because', 'although')
# ('because', 'although', 'mama')
# ('although', 'mama', 'was')
# ('mama', 'was', 'very')
# ('was', 'very', 'tired')
# ('very', 'tired', ',')
# ('tired', ',', 'she')
# (',', 'she', 'was')
# ('she', 'was', 'very')
# ('was', 'very', 'happy')
# ('very', 'happy', ',')
# ('happy', ',', 'too—happy')
# (',', 'too—happy', 'and')
# ('too—happy', 'and', 'excited')
# ('and', 'excited', '!')
# ('excited', '!', '“')
# ('!', '“', 'guess')
# ('“', 'guess', 'what')
# ('guess', 'what', '!')
# ('what', '!', '”')
# ('!', '”', 'said')
# ('”', 'said', 'sister')
# ('said', 'sister', 'as')
# ('sister', 'as', 'she')
# ('as', 'she', 'served')
# ('she', 'served', 'mama')
# ('served', 'mama', 'her')
# ('mama', 'her', 'supper')
# ('her', 'supper', '.')
# ('supper', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', 'reached')
# ('i', 'reached', 'a')
# ('reached', 'a', 'thousand')
# ('a', 'thousand', 'jumps')
# ('thousand', 'jumps', 'today')
# ('jumps', 'today', '!')
# ('today', '!', 'brother')
# ('!', 'brother', 'counted')
# ('brother', 'counted', 'for')
# ('counted', 'for', 'me')
# ('for', 'me', '!')
# ('me', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'and')
# ('“', 'and', 'sis')
# ('and', 'sis', 'helped')
# ('sis', 'helped', 'me')
# ('helped', 'me', 'fly')
# ('me', 'fly', 'my')
# ('fly', 'my', 'tether')
# ('my', 'tether', 'plane')
# ('tether', 'plane', '!')
# ('plane', '!', 'we')
# ('!', 'we', 'had')
# ('we', 'had', 'a')
# ('had', 'a', 'great')
# ('a', 'great', 'flight')
# ('great', 'flight', '!')
# ('flight', '!', '”')
# ('!', '”', 'added')
# ('”', 'added', 'brother')
# ('added', 'brother', '.')
# ('brother', '.', '“')
# ('.', '“', 'and')
# ('“', 'and', 'i')
# ('and', 'i', 'weeded')
# ('i', 'weeded', 'the')
# ('weeded', 'the', 'vegetable')
# ('the', 'vegetable', 'patch')
# ('vegetable', 'patch', ',')
# ('patch', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'papa')
# ('said', 'papa', ',')
# ('papa', ',', 'bringing')
# (',', 'bringing', 'a')
# ('bringing', 'a', 'tub')
# ('a', 'tub', 'of')
# ('tub', 'of', 'warm')
# ('of', 'warm', 'water')
# ('warm', 'water', 'to')
# ('water', 'to', 'mama')
# ('to', 'mama', 'for')
# ('mama', 'for', 'her')
# ('for', 'her', 'tired')
# ('her', 'tired', 'feet')
# ('tired', 'feet', '.')
# ('feet', '.', '“')
# ('.', '“', 'well')
# ('“', 'well', ',')
# ('well', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'mama')
# ('said', 'mama', '.')
# ('mama', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', '’')
# ('i', '’', 'm')
# ('’', 'm', 'very')
# ('m', 'very', 'proud')
# ('very', 'proud', 'of')
# ('proud', 'of', 'you')
# ('of', 'you', 'all.')
# ('you', 'all.', '”')
# ('all.', '”', 'papa')
# ('”', 'papa', 'and')
# ('papa', 'and', 'the')
# ('and', 'the', 'cubs')
# ('the', 'cubs', 'were')
# ('cubs', 'were', 'very')
# ('were', 'very', 'proud')
# ('very', 'proud', 'of')
# ('proud', 'of', 'her')
# ('of', 'her', ',')
# ('her', ',', 'too')
# (',', 'too', '.')
# ('too', '.', 'there')
# ('.', 'there', 'was')
# ('there', 'was', 'no')
# ('was', 'no', 'way')
# ('no', 'way', 'to')
# ('way', 'to', 'tell')
# ('to', 'tell', 'whether')
# ('tell', 'whether', 'the')
# ('whether', 'the', 'quilt')
# ('the', 'quilt', 'shop')
# ('quilt', 'shop', 'would')
# ('shop', 'would', 'be')
# ('would', 'be', 'a')
# ('be', 'a', 'success')
# ('a', 'success', ',')
# ('success', ',', 'but')
# (',', 'but', 'she')
# ('but', 'she', 'certainly')
# ('she', 'certainly', 'was')
# ('certainly', 'was', 'giving')
# ('was', 'giving', 'it')
# ('giving', 'it', 'a')
# ('it', 'a', 'good')
# ('a', 'good', 'try')
# ('good', 'try', '.')
# ('try', '.', 'after')
# ('.', 'after', 'about')
# ('after', 'about', 'two')
# ('about', 'two', 'weeks')
# ('two', 'weeks', 'of')
# ('weeks', 'of', 'hard')
# ('of', 'hard', 'work')
# ('hard', 'work', ',')
# ('work', ',', 'the')
# (',', 'the', 'bear')
# ('the', 'bear', 'country')
# ('bear', 'country', 'quilt')
# ('country', 'quilt', 'shop')
# ('quilt', 'shop', 'had')
# ('shop', 'had', 'its')
# ('had', 'its', 'grand')
# ('its', 'grand', 'opening')
# ('grand', 'opening', '.')
# ('opening', '.', 'it')
# ('.', 'it', 'was')
# ('it', 'was', 'a')
# ('was', 'a', 'very')
# ('a', 'very', 'exciting')
# ('very', 'exciting', 'event')
# ('exciting', 'event', '!')
# ('event', '!', 'not')
# ('!', 'not', 'only')
# ('not', 'only', 'did')
# ('only', 'did', 'mama')
# ('did', 'mama', 'sell')
# ('mama', 'sell', 'her')
# ('sell', 'her', 'own')
# ('her', 'own', 'quilts')
# ('own', 'quilts', ',')
# ('quilts', ',', 'but')
# (',', 'but', 'she')
# ('but', 'she', 'sold')
# ('she', 'sold', 'quilts')
# ('sold', 'quilts', 'for')
# ('quilts', 'for', 'all')
# ('for', 'all', 'the')
# ('all', 'the', 'members')
# ('the', 'members', 'of')
# ('members', 'of', 'her')
# ('of', 'her', 'club')
# ('her', 'club', 'as')
# ('club', 'as', 'well')
# ('as', 'well', '.')
# ('well', '.', 'it')
# ('.', 'it', 'was')
# ('it', 'was', 'a')
# ('was', 'a', 'great')
# ('a', 'great', 'success')
# ('great', 'success', '.')
# ('success', '.', 'why')
# ('.', 'why', ',')
# ('why', ',', 'even')
# (',', 'even', 'mayor')
# ('even', 'mayor', 'and')
# ('mayor', 'and', 'mrs.')
# ('and', 'mrs.', 'honeypot')
# ('mrs.', 'honeypot', 'came')
# ('honeypot', 'came', 'in')
# ('came', 'in', 'their')
# ('in', 'their', 'long')
# ('their', 'long', 'lavender')
# ('long', 'lavender', 'limousine')
# ('lavender', 'limousine', '.')
# ('limousine', '.', 'they')
# ('.', 'they', 'bought')
# ('they', 'bought', 'one')
# ('bought', 'one', 'quilt')
# ('one', 'quilt', 'and')
# ('quilt', 'and', 'ordered')
# ('and', 'ordered', 'three')
# ('ordered', 'three', 'more')
# ('three', 'more', '.')
# ('more', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', 'know')
# ('i', 'know', 'what')
# ('know', 'what', '!')
# ('what', '!', '”')
# ('!', '”', 'said')
# ('”', 'said', 'mama')
# ('said', 'mama', 'as')
# ('mama', 'as', 'she')
# ('as', 'she', 'closed')
# ('she', 'closed', 'up')
# ('closed', 'up', 'shop')
# ('up', 'shop', 'that')
# ('shop', 'that', 'night')
# ('that', 'night', '.')
# ('night', '.', '“')
# ('.', '“', 'let')
# ('“', 'let', '’')
# ('let', '’', 's')
# ('’', 's', 'stop')
# ('s', 'stop', 'off')
# ('stop', 'off', 'at')
# ('off', 'at', 'the')
# ('at', 'the', 'burger')
# ('the', 'burger', 'bear')
# ('burger', 'bear', 'for')
# ('bear', 'for', 'supper')
# ('for', 'supper', '!')
# ('supper', '!', 'my')
# ('!', 'my', 'treat')
# ('my', 'treat', '!')
# ('treat', '!', '”')
# ('!', '”', 'the')
# ('”', 'the', 'bear')
# ('the', 'bear', 'family')
# ('bear', 'family', 'celebrated')
# ('family', 'celebrated', 'with')
# ('celebrated', 'with', 'a')
# ('with', 'a', 'delicious')
# ('a', 'delicious', 'burger')
# ('delicious', 'burger', 'bear')
# ('burger', 'bear', 'supper')
# ('bear', 'supper', '.')
# ('supper', '.', 'papa')
# ('.', 'papa', 'and')
# ('papa', 'and', 'the')
# ('and', 'the', 'cubs')
# ('the', 'cubs', 'were')
# ('cubs', 'were', 'very')
# ('were', 'very', 'proud')
# ('very', 'proud', 'of')
# ('proud', 'of', 'their')
# ('of', 'their', 'business-bear')
# ('their', 'business-bear', 'wife')
# ('business-bear', 'wife', 'and')
# ('wife', 'and', 'mama')
# ('and', 'mama', '.')
# ('mama', '.', 'the')
# ('.', 'the', 'extra')
# ('the', 'extra', 'money')
# ('extra', 'money', 'came')
# ('money', 'came', 'in')
# ('came', 'in', 'handy')
# ('in', 'handy', 'too')
# ('handy', 'too', '!')
# ('too', '!', '``')
# ('!', '``', '``')
# ('``', '``', 'brother')
# ('``', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'bear')
# ('sister', 'bear', ',')
# ('bear', ',', 'who')
# (',', 'who', 'lived')
# ('who', 'lived', 'with')
# ('lived', 'with', 'their')
# ('with', 'their', 'mama')
# ('their', 'mama', 'and')
# ('mama', 'and', 'papa')
# ('and', 'papa', 'in')
# ('papa', 'in', 'the')
# ('in', 'the', 'big')
# ('the', 'big', 'tree')
# ('big', 'tree', 'house')
# ('tree', 'house', 'down')
# ('house', 'down', 'a')
# ('down', 'a', 'sunny')
# ('a', 'sunny', 'dirt')
# ('sunny', 'dirt', 'road')
# ('dirt', 'road', 'dee')
# ('road', 'dee', 'in')
# ('dee', 'in', 'bear')
# ('in', 'bear', 'country')
# ('bear', 'country', ',')
# ('country', ',', 'looked')
# (',', 'looked', 'quite')
# ('looked', 'quite', 'a')
# ('quite', 'a', 'lot')
# ('a', 'lot', 'alike')
# ('lot', 'alike', '.')
# ('alike', '.', 'except')
# ('.', 'except', 'for')
# ('except', 'for', 'the')
# ('for', 'the', 'fact')
# ('the', 'fact', 'that')
# ('fact', 'that', 'brother')
# ('that', 'brother', 'was')
# ('brother', 'was', 'a')
# ('was', 'a', 'boy')
# ('a', 'boy', 'cub')
# ('boy', 'cub', 'and')
# ('cub', 'and', 'sister')
# ('and', 'sister', 'was')
# ('sister', 'was', 'a')
# ('was', 'a', 'girl')
# ('a', 'girl', 'cub')
# ('girl', 'cub', ',')
# ('cub', ',', 'they')
# (',', 'they', 'were')
# ('they', 'were', 'alike')
# ('were', 'alike', 'in')
# ('alike', 'in', 'many')
# ('in', 'many', 'ways')
# ('many', 'ways', '.')
# ('ways', '.', 'and')
# ('.', 'and', 'even')
# ('and', 'even', 'though')
# ('even', 'though', 'they')
# ('though', 'they', 'each')
# ('they', 'each', 'had')
# ('each', 'had', 'hobbies')
# ('had', 'hobbies', '(')
# ('hobbies', '(', 'brother')
# ('(', 'brother', 'loved')
# ('brother', 'loved', 'to')
# ('loved', 'to', 'build')
# ('to', 'build', 'and')
# ('build', 'and', 'fly')
# ('and', 'fly', 'model')
# ('fly', 'model', 'airplanes')
# ('model', 'airplanes', ';')
# ('airplanes', ';', 'sister')
# (';', 'sister', 'had')
# ('sister', 'had', 'all')
# ('had', 'all', 'sorts')
# ('all', 'sorts', 'of')
# ('sorts', 'of', 'special')
# ('of', 'special', 'interests')
# ('special', 'interests', ')')
# ('interests', ')', ',')
# (')', ',', 'they')
# (',', 'they', 'enjoyed')
# ('they', 'enjoyed', 'many')
# ('enjoyed', 'many', 'of')
# ('many', 'of', 'the')
# ('of', 'the', 'same')
# ('the', 'same', 'things')
# ('same', 'things', ':')
# ('things', ':', 'bike')
# (':', 'bike', 'riding')
# ('bike', 'riding', ',')
# ('riding', ',', 'baseball')
# (',', 'baseball', ',')
# ('baseball', ',', 'soccer')
# (',', 'soccer', ',')
# ('soccer', ',', 'frisbee')
# (',', 'frisbee', ',')
# ('frisbee', ',', 'and')
# (',', 'and', 'just')
# ('and', 'just', 'getting')
# ('just', 'getting', 'out')
# ('getting', 'out', 'and')
# ('out', 'and', 'enjoying')
# ('and', 'enjoying', 'nature')
# ('enjoying', 'nature', '.')
# ('nature', '.', 'yes')
# ('.', 'yes', ',')
# ('yes', ',', 'brother')
# (',', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'were')
# ('sister', 'were', 'alike')
# ('were', 'alike', 'in')
# ('alike', 'in', 'many')
# ('in', 'many', 'ways')
# ('many', 'ways', '.')
# ('ways', '.', 'but')
# ('.', 'but', 'in')
# ('but', 'in', 'some')
# ('in', 'some', 'important')
# ('some', 'important', 'ways')
# ('important', 'ways', 'they')
# ('ways', 'they', 'were')
# ('they', 'were', 'different')
# ('were', 'different', '.')
# ('different', '.', 'brother')
# ('.', 'brother', 'bear')
# ('brother', 'bear', 'was')
# ('bear', 'was', 'cautious')
# ('was', 'cautious', 'and')
# ('cautious', 'and', 'careful')
# ('and', 'careful', 'and')
# ('careful', 'and', 'a')
# ('and', 'a', 'little')
# ('a', 'little', 'wary')
# ('little', 'wary', 'of')
# ('wary', 'of', 'strangers')
# ('of', 'strangers', ',')
# ('strangers', ',', 'sister')
# (',', 'sister', ',')
# ('sister', ',', 'on')
# (',', 'on', 'the')
# ('on', 'the', 'other')
# ('the', 'other', 'hand')
# ('other', 'hand', ',')
# ('hand', ',', 'wasn')
# (',', 'wasn', '’')
# ('wasn', '’', 't')
# ('’', 't', 'the')
# ('t', 'the', 'least')
# ('the', 'least', 'bit')
# ('least', 'bit', 'wary')
# ('bit', 'wary', '.')
# ('wary', '.', 'she')
# ('.', 'she', 'was')
# ('she', 'was', 'friendly')
# ('was', 'friendly', 'to')
# ('friendly', 'to', 'a')
# ('to', 'a', 'fault')
# ('a', 'fault', '.')
# ('fault', '.', 'just')
# ('.', 'just', 'about')
# ('just', 'about', 'everybody')
# ('about', 'everybody', 'that')
# ('everybody', 'that', 'came')
# ('that', 'came', 'her')
# ('came', 'her', 'way')
# ('her', 'way', 'got')
# ('way', 'got', 'a')
# ('got', 'a', 'big')
# ('a', 'big', 'hello')
# ('big', 'hello', '.')
# ('hello', '.', '“')
# ('.', '“', 'hello')
# ('“', 'hello', ',')
# ('hello', ',', 'butterfly')
# (',', 'butterfly', '!')
# ('butterfly', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'hello')
# ('“', 'hello', ',')
# ('hello', ',', 'frog')
# (',', 'frog', '!')
# ('frog', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'hello')
# ('“', 'hello', ',')
# ('hello', ',', 'mr.')
# (',', 'mr.', 'truck')
# ('mr.', 'truck', 'driver')
# ('truck', 'driver', '!')
# ('driver', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'hello')
# ('“', 'hello', ',')
# ('hello', ',', 'mrs.')
# (',', 'mrs.', 'shopper')
# ('mrs.', 'shopper', '!')
# ('shopper', '!', '”')
# ('!', '”', 'brother')
# ('”', 'brother', 'worried')
# ('brother', 'worried', 'about')
# ('worried', 'about', 'sister')
# ('about', 'sister', '’')
# ('sister', '’', 's')
# ('’', 's', 'free')
# ('s', 'free', 'and')
# ('free', 'and', 'easy')
# ('and', 'easy', 'way')
# ('easy', 'way', 'with')
# ('way', 'with', 'strangers')
# ('with', 'strangers', '.')
# ('strangers', '.', 'strangers')
# ('.', 'strangers', 'weren')
# ('strangers', 'weren', '’')
# ('weren', '’', 't')
# ('’', 't', 'a')
# ('t', 'a', 'problem')
# ('a', 'problem', 'for')
# ('problem', 'for', 'him')
# ('for', 'him', '.')
# ('him', '.', 'not')
# ('.', 'not', 'talking')
# ('not', 'talking', 'to')
# ('talking', 'to', 'strangers')
# ('to', 'strangers', 'suited')
# ('strangers', 'suited', 'cautious')
# ('suited', 'cautious', 'and')
# ('cautious', 'and', 'careful')
# ('and', 'careful', 'brother')
# ('careful', 'brother', 'just')
# ('brother', 'just', 'fine')
# ('just', 'fine', '.')
# ('fine', '.', 'but')
# ('.', 'but', 'friendly-to-a-fault')
# ('but', 'friendly-to-a-fault', 'sister')
# ('friendly-to-a-fault', 'sister', 'was')
# ('sister', 'was', 'different')
# ('was', 'different', '.')
# ('different', '.', 'she')
# ('.', 'she', 'talked')
# ('she', 'talked', 'to')
# ('talked', 'to', 'everybody')
# ('to', 'everybody', '.')
# ('everybody', '.', '“')
# ('.', '“', 'sister')
# ('“', 'sister', ',')
# ('sister', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'brother')
# ('said', 'brother', '.')
# ('brother', '.', '“')
# ('.', '“', 'you')
# ('“', 'you', '’')
# ('you', '’', 're')
# ('’', 're', 'going')
# ('re', 'going', 'to')
# ('going', 'to', 'have')
# ('to', 'have', 'to')
# ('have', 'to', 'stop')
# ('to', 'stop', 'that')
# ('stop', 'that', '!')
# ('that', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'stop')
# ('“', 'stop', 'what')
# ('stop', 'what', '?')
# ('what', '?', '”')
# ('?', '”', 'she')
# ('”', 'she', 'asked')
# ('she', 'asked', '.')
# ('asked', '.', '“')
# ('.', '“', 'talking')
# ('“', 'talking', 'to')
# ('talking', 'to', 'strangers')
# ('to', 'strangers', '!')
# ('strangers', '!', 'it')
# ('!', 'it', '’')
# ('it', '’', 's')
# ('’', 's', 'just')
# ('s', 'just', 'not')
# ('just', 'not', 'a')
# ('not', 'a', 'good')
# ('a', 'good', 'idea')
# ('good', 'idea', '!')
# ('idea', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'why')
# ('“', 'why', '?')
# ('why', '?', '”')
# ('?', '”', 'she')
# ('”', 'she', 'wanted')
# ('she', 'wanted', 'to')
# ('wanted', 'to', 'know')
# ('to', 'know', '.')
# ...
# ('were', 'super', 'polite')
# ('super', 'polite', '...')
# ('polite', '...', '—on')
# ('...', '—on', 'the')
# ('—on', 'the', 'stairs')
# ('the', 'stairs', ':')
# ('stairs', ':', '“')
# (':', '“', 'after')
# ('“', 'after', 'you')
# ('after', 'you', ',')
# ('you', ',', 'sister')
# (',', 'sister', 'dear')
# ('sister', 'dear', '!')
# ('dear', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'thank')
# ('“', 'thank', 'you')
# ('thank', 'you', ',')
# ('you', ',', 'dear')
# (',', 'dear', 'brother')
# ('dear', 'brother', '!')
# ('brother', '!', '”')
# ('!', '”', '—in')
# ('”', '—in', 'the')
# ('—in', 'the', 'hall')
# ('the', 'hall', ':')
# ('hall', ':', '“')
# (':', '“', 'excuse')
# ('“', 'excuse', 'me')
# ('excuse', 'me', ',')
# ('me', ',', 'brother')
# (',', 'brother', 'dear')
# ('brother', 'dear', '!')
# ('dear', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'why')
# ('“', 'why', ',')
# ('why', ',', 'certainly')
# (',', 'certainly', ',')
# ('certainly', ',', 'my')
# (',', 'my', 'dear')
# ('my', 'dear', 'sister')
# ('dear', 'sister', '!')
# ('sister', '!', '”')
# ('!', '”', '—waiting')
# ('”', '—waiting', 'for')
# ('—waiting', 'for', 'the')
# ('for', 'the', 'bathroom')
# ('the', 'bathroom', ':')
# ('bathroom', ':', '“')
# (':', '“', 'terribly')
# ('“', 'terribly', 'sorry')
# ('terribly', 'sorry', 'to')
# ('sorry', 'to', 'have')
# ('to', 'have', 'kept')
# ('have', 'kept', 'you')
# ('kept', 'you', 'waiting')
# ('you', 'waiting', '!')
# ('waiting', '!', '”')
# ('!', '”', '“')
# ('”', '“', 'think')
# ('“', 'think', 'nothing')
# ('think', 'nothing', 'of')
# ('nothing', 'of', 'it')
# ('of', 'it', ',')
# ('it', ',', 'my')
# (',', 'my', 'dear')
# ('my', 'dear', '!')
# ('dear', '!', '”')
# ('!', '”', 'but')
# ('”', 'but', 'it')
# ('but', 'it', 'didn')
# ('it', 'didn', '’')
# ('didn', '’', 't')
# ('’', 't', 'work')
# ('t', 'work', 'the')
# ('work', 'the', 'way')
# ('the', 'way', 'they')
# ('way', 'they', 'expected')
# ('they', 'expected', '.')
# ('expected', '.', 'mama')
# ('.', 'mama', 'didn')
# ('mama', 'didn', '’')
# ('didn', '’', 't')
# ('’', 't', 'get')
# ('t', 'get', 'fed')
# ('get', 'fed', 'up')
# ('fed', 'up', 'at')
# ('up', 'at', 'all')
# ('at', 'all', '.')
# ('all', '.', 'and')
# ('.', 'and', 'after')
# ('and', 'after', 'a')
# ('after', 'a', 'while')
# ('a', 'while', 'brother')
# ('while', 'brother', 'and')
# ('brother', 'and', 'sister')
# ('and', 'sister', 'forgot')
# ('sister', 'forgot', 'about')
# ('forgot', 'about', 'being')
# ('about', 'being', 'super')
# ('being', 'super', 'polite')
# ('super', 'polite', 'and')
# ('polite', 'and', 'were')
# ('and', 'were', 'just')
# ('were', 'just', 'polite')
# ('just', 'polite', '...')
# ('polite', '...', '—at')
# ('...', '—at', 'the')
# ('—at', 'the', 'table')
# ('the', 'table', ':')
# ('table', ':', '“')
# (':', '“', 'pass')
# ('“', 'pass', 'the')
# ('pass', 'the', 'honey')
# ('the', 'honey', ',')
# ('honey', ',', 'please.')
# (',', 'please.', '”')
# ('please.', '”', '“')
# ('”', '“', 'certainly.')
# ('“', 'certainly.', '”')
# ('certainly.', '”', '—in')
# ('”', '—in', 'their')
# ('—in', 'their', 'room')
# ('their', 'room', ':')
# ('room', ':', '“')
# (':', '“', 'would')
# ('“', 'would', 'you')
# ('would', 'you', 'like')
# ('you', 'like', 'me')
# ('like', 'me', 'to')
# ('me', 'to', 'help')
# ('to', 'help', 'you')
# ('help', 'you', 'pick')
# ('you', 'pick', 'up')
# ('pick', 'up', 'your')
# ('up', 'your', 'toys')
# ('your', 'toys', '?')
# ('toys', '?', '”')
# ('?', '”', '“')
# ('”', '“', 'thank')
# ('“', 'thank', 'you')
# ('thank', 'you', 'very')
# ('you', 'very', 'much.')
# ('very', 'much.', '”')
# ('much.', '”', '—in')
# ('”', '—in', 'the')
# ('—in', 'the', 'yard')
# ('the', 'yard', ':')
# ('yard', ':', '“')
# (':', '“', 'oops')
# ('“', 'oops', '!')
# ('oops', '!', 'sorry—i')
# ('!', 'sorry—i', 'didn')
# ('sorry—i', 'didn', '’')
# ('didn', '’', 't')
# ('’', 't', 'mean')
# ('t', 'mean', 'to')
# ('mean', 'to', 'bump')
# ('to', 'bump', 'you.')
# ('bump', 'you.', '”')
# ('you.', '”', '“')
# ('”', '“', 'that')
# ('“', 'that', '’')
# ('that', '’', 's')
# ('’', 's', 'all')
# ('s', 'all', 'right')
# ('all', 'right', '.')
# ('right', '.', 'no')
# ('.', 'no', 'harm')
# ('no', 'harm', 'done.')
# ('harm', 'done.', '”')
# ('done.', '”', 'and')
# ('”', 'and', 'it')
# ('and', 'it', 'turned')
# ('it', 'turned', 'out')
# ('turned', 'out', 'that')
# ('out', 'that', 'mama')
# ('that', 'mama', 'had')
# ('mama', 'had', 'been')
# ('had', 'been', 'right')
# ('been', 'right', ':')
# ('right', ':', 'thinks')
# (':', 'thinks', 'did')
# ('thinks', 'did', 'go')
# ('did', 'go', 'more')
# ('go', 'more', 'smoothly')
# ('more', 'smoothly', '.')
# ('smoothly', '.', 'once')
# ('.', 'once', 'they')
# ('once', 'they', 'got')
# ('they', 'got', 'into')
# ('got', 'into', 'the')
# ('into', 'the', 'good')
# ('the', 'good', 'manners')
# ('good', 'manners', 'habit')
# ('manners', 'habit', ',')
# ('habit', ',', 'they')
# (',', 'they', 'didn')
# ('they', 'didn', '’')
# ('didn', '’', 't')
# ('’', 't', 'even')
# ('t', 'even', 'have')
# ('even', 'have', 'to')
# ('have', 'to', 'think')
# ('to', 'think', 'about')
# ('think', 'about', 'it')
# ('about', 'it', '.')
# ('it', '.', 'but')
# ('.', 'but', 'it')
# ('but', 'it', 'wasn')
# ('it', 'wasn', '’')
# ('wasn', '’', 't')
# ('’', 't', 'so')
# ('t', 'so', 'easy')
# ('so', 'easy', 'for')
# ('easy', 'for', 'papa')
# ('for', 'papa', '.')
# ('papa', '.', 'he')
# ('.', 'he', 'was')
# ('he', 'was', 'the')
# ('was', 'the', 'one')
# ('the', 'one', 'who')
# ('one', 'who', 'got')
# ('who', 'got', 'fed')
# ('got', 'fed', 'up')
# ('fed', 'up', '.')
# ('up', '.', 'it')
# ('.', 'it', '’')
# ('it', '’', 's')
# ('’', 's', 'a')
# ('s', 'a', 'little')
# ('a', 'little', 'harder')
# ('little', 'harder', 'to')
# ('harder', 'to', 'change')
# ('to', 'change', 'habits')
# ('change', 'habits', 'when')
# ('habits', 'when', 'you')
# ('when', 'you', '’')
# ('you', '’', 're')
# ('’', 're', 'older')
# ('re', 'older', ',')
# ('older', ',', 'and')
# (',', 'and', 'he')
# ('and', 'he', 'had')
# ('he', 'had', 'to')
# ('had', 'to', 'do')
# ('to', 'do', 'quite')
# ('do', 'quite', 'a')
# ('quite', 'a', 'few')
# ('a', 'few', 'extra')
# ('few', 'extra', 'chores')
# ('extra', 'chores', 'for')
# ('chores', 'for', 'forgetting')
# ('for', 'forgetting', 'his')
# ('forgetting', 'his', 'manners')
# ('his', 'manners', '.')
# ('manners', '.', '“')
# ('.', '“', 'i')
# ('“', 'i', '’')
# ('i', '’', 'm')
# ('’', 'm', 'glad')
# ('m', 'glad', 'to')
# ('glad', 'to', 'get')
# ('to', 'get', 'out')
# ('get', 'out', 'of')
# ('out', 'of', 'the')
# ('of', 'the', 'house')
# ('the', 'house', ',')
# ('house', ',', 'away')
# (',', 'away', 'from')
# ('away', 'from', 'that')
# ('from', 'that', 'politeness')
# ('that', 'politeness', 'plan')
# ('politeness', 'plan', '!')
# ('plan', '!', '”')
# ('!', '”', 'he')
# ('”', 'he', 'said')
# ('he', 'said', 'as')
# ('said', 'as', 'he')
# ('as', 'he', 'drove')
# ('he', 'drove', 'the')
# ('drove', 'the', 'family')
# ('the', 'family', 'along')
# ('family', 'along', 'the')
# ('along', 'the', 'highway')
# ('the', 'highway', 'on')
# ('highway', 'on', 'a')
# ('on', 'a', 'trip')
# ('a', 'trip', 'to')
# ('trip', 'to', 'the')
# ('to', 'the', 'supermarket')
# ('the', 'supermarket', '.')
# ('supermarket', '.', '“')
# ('.', '“', 'manners')
# ('“', 'manners', 'and')
# ('manners', 'and', 'courtesy')
# ('and', 'courtesy', 'are')
# ('courtesy', 'are', 'just')
# ('are', 'just', 'as')
# ('just', 'as', 'important')
# ('as', 'important', 'away')
# ('important', 'away', 'from')
# ('away', 'from', 'home—especially')
# ('from', 'home—especially', 'on')
# ('home—especially', 'on', 'the')
# ('on', 'the', 'road')
# ('the', 'road', ',')
# ('road', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'mama')
# ('said', 'mama', 'as')
# ('mama', 'as', 'they')
# ('as', 'they', 'stopped')
# ('they', 'stopped', 'at')
# ('stopped', 'at', 'a')
# ('at', 'a', 'stop')
# ('a', 'stop', 'sign')
# ('stop', 'sign', 'to')
# ('sign', 'to', 'let')
# ('to', 'let', 'pedestrians')
# ('let', 'pedestrians', 'and')
# ('pedestrians', 'and', 'other')
# ('and', 'other', 'cars')
# ('other', 'cars', 'pass')
# ('cars', 'pass', '.')
# ('pass', '.', '“')
# ('.', '“', 'they')
# ('“', 'they', 'help')
# ('they', 'help', 'us')
# ('help', 'us', 'drive')
# ('us', 'drive', 'safely.')
# ('drive', 'safely.', '”')
# ('safely.', '”', '“')
# ('”', '“', 'well')
# ('“', 'well', ',')
# ('well', ',', '”')
# (',', '”', 'grumbled')
# ('”', 'grumbled', 'papa')
# ('grumbled', 'papa', 'as')
# ('papa', 'as', 'they')
# ('as', 'they', 'all')
# ('they', 'all', 'went')
# ('all', 'went', 'into')
# ('went', 'into', 'the')
# ('into', 'the', 'busy')
# ('the', 'busy', 'supermarket')
# ('busy', 'supermarket', ',')
# ('supermarket', ',', '“')
# (',', '“', 'i')
# ('“', 'i', 'think')
# ('i', 'think', 'you')
# ('think', 'you', 'can')
# ('you', 'can', 'have')
# ('can', 'have', 'too')
# ('have', 'too', 'much')
# ('too', 'much', 'of')
# ('much', 'of', 'a')
# ('of', 'a', 'good')
# ('a', 'good', 'thing—you')
# ('good', 'thing—you', '’')
# ('thing—you', '’', 've')
# ('’', 've', 'got')
# ('ve', 'got', 'to')
# ('got', 'to', 'have')
# ('to', 'have', 'common')
# ('have', 'common', 'sense')
# ('common', 'sense', 'along')
# ('sense', 'along', 'with')
# ('along', 'with', 'manners')
# ('with', 'manners', '!')
# ('manners', '!', '!')
# ('!', '!', 'why')
# ('!', 'why', 'if')
# ('why', 'if', 'you')
# ('if', 'you', 'let')
# ('you', 'let', 'everyone')
# ('let', 'everyone', 'go')
# ('everyone', 'go', 'ahead')
# ('go', 'ahead', 'of')
# ('ahead', 'of', 'you')
# ('of', 'you', 'at')
# ('you', 'at', 'the')
# ('at', 'the', 'checkout')
# ('the', 'checkout', ',')
# ('checkout', ',', 'you')
# (',', 'you', '’')
# ('you', '’', 'd')
# ('’', 'd', 'be')
# ('d', 'be', 'there')
# ('be', 'there', 'forever')
# ('there', 'forever', '!')
# ('forever', '!', '“')
# ('!', '“', 'and')
# ('“', 'and', 'sometimes')
# ('and', 'sometimes', 'you')
# ('sometimes', 'you', 'have')
# ('you', 'have', 'to')
# ('have', 'to', 'interrupt—excuse')
# ('to', 'interrupt—excuse', 'me')
# ('interrupt—excuse', 'me', ',')
# ('me', ',', 'madam')
# (',', 'madam', ',')
# ('madam', ',', '”')
# (',', '”', 'he')
# ('”', 'he', 'interrupted')
# ('he', 'interrupted', 'a')
# ('interrupted', 'a', 'shopper')
# ('a', 'shopper', ',')
# ('shopper', ',', '“')
# (',', '“', 'but')
# ('“', 'but', 'i')
# ('but', 'i', 'believe')
# ('i', 'believe', 'you')
# ('believe', 'you', 'have')
# ('you', 'have', 'a')
# ('have', 'a', 'leaking')
# ('a', 'leaking', 'bottle')
# ('leaking', 'bottle', 'in')
# ('bottle', 'in', 'your')
# ('in', 'your', 'cart')
# ('your', 'cart', '!')
# ('cart', '!', '”')
# ('!', '”', 'the')
# ('”', 'the', 'shopper')
# ('the', 'shopper', 'thanked')
# ('shopper', 'thanked', 'him')
# ('thanked', 'him', 'for')
# ('him', 'for', 'his')
# ('for', 'his', 'help')
# ('his', 'help', '.')
# ('help', '.', '“')
# ('.', '“', 'you')
# ('“', 'you', 'see')
# ('you', 'see', '?')
# ('see', '?', '”')
# ('?', '”', 'he')
# ('”', 'he', 'said')
# ('he', 'said', ',')
# ('said', ',', 'driving')
# (',', 'driving', 'home')
# ('driving', 'home', '.')
# ('home', '.', '“')
# ('.', '“', 'there')
# ('“', 'there', '’')
# ('there', '’', 's')
# ('’', 's', 'more')
# ('s', 'more', 'to')
# ('more', 'to', 'life')
# ('to', 'life', 'than')
# ('life', 'than', 'remembering')
# ('than', 'remembering', 'your')
# ('remembering', 'your', 'manners')
# ('your', 'manners', '.')
# ('manners', '.', 'besides')
# ('.', 'besides', ',')
# ('besides', ',', 'manners')
# (',', 'manners', 'are')
# ('manners', 'are', 'all')
# ('are', 'all', 'right')
# ('all', 'right', 'for')
# ('right', 'for', 'cubs')
# ('for', 'cubs', 'and')
# ('cubs', 'and', 'mama')
# ('and', 'mama', 'bears')
# ('mama', 'bears', '...')
# ('bears', '...', '”')
# ('...', '”', '“')
# ('”', '“', '...')
# ('“', '...', 'but')
# ('...', 'but', 'we')
# ('but', 'we', 'papa')
# ('we', 'papa', 'bears')
# ('papa', 'bears', 'have')
# ('bears', 'have', 'other')
# ('have', 'other', 'things')
# ('other', 'things', 'to')
# ('things', 'to', 'think')
# ('to', 'think', 'about—')
# ('think', 'about—', '”')
# ('about—', '”', 'at')
# ('”', 'at', 'that')
# ('at', 'that', 'moment')
# ('that', 'moment', 'the')
# ('moment', 'the', 'car')
# ('the', 'car', 'in')
# ('car', 'in', 'front')
# ('in', 'front', 'stopped')
# ('front', 'stopped', 'suddenly')
# ('stopped', 'suddenly', 'and')
# ('suddenly', 'and', 'papa')
# ('and', 'papa', 'bumped')
# ('papa', 'bumped', 'into')
# ('bumped', 'into', 'it')
# ('into', 'it', '.')
# ('it', '.', 'he')
# ('.', 'he', 'was')
# ('he', 'was', 'furious')
# ('was', 'furious', '.')
# ('furious', '.', '“')
# ('.', '“', 'why')
# ('“', 'why', ',')
# ('why', ',', 'that')
# (',', 'that', 'pinheaded')
# ('that', 'pinheaded', 'fiddlebrain')
# ('pinheaded', 'fiddlebrain', '!')
# ('fiddlebrain', '!', '”')
# ('!', '”', 'he')
# ('”', 'he', 'snarled')
# ('he', 'snarled', '.')
# ('snarled', '.', '“')
# ('.', '“', 'name')
# ('“', 'name', 'calling')
# ('name', 'calling', '!')
# ('calling', '!', '”')
# ('!', '”', 'reminded')
# ('”', 'reminded', 'sister')
# ('reminded', 'sister', '.')
# ('sister', '.', 'the')
# ('.', 'the', 'penalty')
# ('the', 'penalty', 'for')
# ('penalty', 'for', 'name')
# ('for', 'name', 'calling')
# ('name', 'calling', 'was')
# ('calling', 'was', 'cleaning')
# ('was', 'cleaning', 'the')
# ('cleaning', 'the', 'whole')
# ('the', 'whole', 'cellar')
# ('whole', 'cellar', ',')
# ('cellar', ',', 'so')
# (',', 'so', 'papa')
# ('so', 'papa', 'gritted')
# ('papa', 'gritted', 'his')
# ('gritted', 'his', 'teeth')
# ('his', 'teeth', 'and')
# ('teeth', 'and', 'remembered')
# ('and', 'remembered', 'his')
# ('remembered', 'his', 'manners')
# ('his', 'manners', '.')
# ('manners', '.', 'and')
# ('.', 'and', 'a')
# ('and', 'a', 'good')
# ('a', 'good', 'thing')
# ('good', 'thing', ',')
# ('thing', ',', 'too')
# (',', 'too', '.')
# ('too', '.', 'because')
# ('.', 'because', 'climbing')
# ('because', 'climbing', 'out')
# ('climbing', 'out', 'of')
# ('out', 'of', 'the')
# ('of', 'the', 'other')
# ('the', 'other', 'car')
# ('other', 'car', 'was')
# ('car', 'was', 'the')
# ('was', 'the', 'biggest')
# ('the', 'biggest', ',')
# ('biggest', ',', 'angriest')
# (',', 'angriest', 'bear')
# ('angriest', 'bear', 'he')
# ('bear', 'he', 'had')
# ('he', 'had', 'ever')
# ('had', 'ever', 'seen')
# ('ever', 'seen', '.')
# ('seen', '.', 'but')
# ('.', 'but', 'when')
# ('but', 'when', 'the')
# ('when', 'the', 'angry')
# ('the', 'angry', 'bear')
# ('angry', 'bear', 'saw')
# ('bear', 'saw', 'how')
# ('saw', 'how', 'polite')
# ('how', 'polite', 'papa')
# ('polite', 'papa', 'was')
# ('papa', 'was', ',')
# ('was', ',', 'he')
# (',', 'he', 'remembered')
# ('he', 'remembered', 'his')
# ('remembered', 'his', 'manners')
# ('his', 'manners', 'too')
# ('manners', 'too', '.')
# ('too', '.', 'he')
# ('.', 'he', 'explained')
# ('he', 'explained', 'that')
# ('explained', 'that', 'he')
# ('that', 'he', 'had')
# ('he', 'had', 'stopped')
# ('had', 'stopped', 'short')
# ('stopped', 'short', 'because')
# ('short', 'because', 'a')
# ('because', 'a', 'mama')
# ('a', 'mama', 'duck')
# ('mama', 'duck', 'and')
# ('duck', 'and', 'her')
# ('and', 'her', 'ducklings')
# ('her', 'ducklings', 'had')
# ('ducklings', 'had', 'crossed')
# ('had', 'crossed', 'in')
# ('crossed', 'in', 'front')
# ('in', 'front', 'of')
# ('front', 'of', 'him')
# ('of', 'him', '.')
# ('him', '.', 'then')
# ('.', 'then', 'he')
# ('then', 'he', 'and')
# ('he', 'and', 'papa')
# ('and', 'papa', 'bear')
# ('papa', 'bear', 'looked')
# ('bear', 'looked', 'at')
# ('looked', 'at', 'their')
# ('at', 'their', 'bumpers')
# ('their', 'bumpers', 'and')
# ('bumpers', 'and', 'saw')
# ('and', 'saw', 'that')
# ('saw', 'that', 'no')
# ('that', 'no', 'harm')
# ('no', 'harm', 'had')
# ('harm', 'had', 'been')
# ('had', 'been', 'done')
# ('been', 'done', '.')
# ('done', '.', '“')
# ('.', '“', 'as')
# ('“', 'as', 'i')
# ('as', 'i', 'was')
# ('i', 'was', 'saying')
# ('was', 'saying', ',')
# ('saying', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'papa')
# ('said', 'papa', 'as')
# ('papa', 'as', 'they')
# ('as', 'they', 'continued')
# ('they', 'continued', 'on')
# ('continued', 'on', 'their')
# ('on', 'their', 'way')
# ('their', 'way', ',')
# ('way', ',', '“')
# (',', '“', 'it')
# ('“', 'it', '’')
# ('it', '’', 's')
# ('’', 's', 'very')
# ('s', 'very', 'important')
# ('very', 'important', 'for')
# ('important', 'for', 'us')
# ('for', 'us', 'to')
# ('us', 'to', 'remember')
# ('to', 'remember', 'our')
# ('remember', 'our', 'manners')
# ('our', 'manners', 'at')
# ('manners', 'at', 'all')
# ('at', 'all', 'times—and')
# ('all', 'times—and', 'i')
# ('times—and', 'i', 'want')
# ('i', 'want', 'to')
# ('want', 'to', 'thank')
# ('to', 'thank', 'you')
# ('thank', 'you', ',')
# ('you', ',', 'sister')
# (',', 'sister', ',')
# ('sister', ',', 'for')
# (',', 'for', 'reminding')
# ('for', 'reminding', 'me')
# ('reminding', 'me', 'to')
# ('me', 'to', 'remember')
# ('to', 'remember', 'mine.')
# ('remember', 'mine.', '”')
# ('mine.', '”', '“')
# ('”', '“', 'you')
# ('“', 'you', '’')
# ('you', '’', 're')
# ('’', 're', 'very')
# ('re', 'very', 'welcome')
# ('very', 'welcome', ',')
# ('welcome', ',', 'i')
# (',', 'i', '’')
# ('i', '’', 'm')
# ('’', 'm', 'sure')
# ('m', 'sure', ',')
# ('sure', ',', '”')
# (',', '”', 'said')
# ('”', 'said', 'sister')
# ('said', 'sister', 'bear')
# ('sister', 'bear', 'politely.')
# ('bear', 'politely.', '``')

# %% [markdown]
# BOMB
# Summary (not working)

# %%
#@markdown <font color = 'red'> Summary suggested by ChatGPT not working!

# !pip install nltk
import nltk
nltk.download('punkt') # Download the punkt tokenizer data
from nltk.tokenize import word_tokenize
from nltk.text import Text

# !pip install transformers
# !pip install torch
from transformers import pipeline

# Load the summarization pipeline
summarizer = pipeline("summarization")
# Generate the summary
summary = summarizer(text, max_length=50, min_length=25, do_sample=False)

# Print the summary
print(summary[0]['summary_text'])
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.4.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (13267 > 1024). Running this sequence through the model will result in indexing errors
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-2fb6dc4d10dc> in <cell line: 16>()
#      14 summarizer = pipeline("summarization")
#      15 # Generate the summary
# ---> 16 summary = summarizer(text, max_length=50, min_length=25, do_sample=False)
#      17
#      18 # Print the summary
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     267               ids of the summary.
#     268         """
# --> 269         return super().__call__(*args, **kwargs)
#     270
#     271     def check_inputs(self, input_length: int, min_length: int, max_length: int) -> bool:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     165         """
#     166
# --> 167         result = super().__call__(*args, **kwargs)
#     168         if (
#     169             isinstance(args[0], list)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1255             )
#    1256         else:
# -> 1257             return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#    1258
#    1259     def run_multi(self, inputs, preprocess_params, forward_params, postprocess_params):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1262     def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1263         model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1264         model_outputs = self.forward(model_inputs, **forward_params)
#    1265         outputs = self.postprocess(model_outputs, **postprocess_params)
#    1266         return outputs
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1162                 with inference_context():
#    1163                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1164                     model_outputs = self._forward(model_inputs, **forward_params)
#    1165                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1166             else:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in _forward(self, model_inputs, **generate_kwargs)
#     189             generate_kwargs.get("max_length", self.model.config.max_length),
#     190         )
# --> 191         output_ids = self.model.generate(**model_inputs, **generate_kwargs)
#     192         out_b = output_ids.shape[0]
#     193         if self.framework == "pt":
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     114     def decorate_context(*args, **kwargs):
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#     118     return decorate_context
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1743         if self.config.is_encoder_decoder and "encoder_outputs" not in model_kwargs:
#    1744             # if model is encoder decoder encoder_outputs are created and added to `model_kwargs`
# -> 1745             model_kwargs = self._prepare_encoder_decoder_kwargs_for_generation(
#    1746                 inputs_tensor, model_kwargs, model_input_name, generation_config
#    1747             )
#
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py in _prepare_encoder_decoder_kwargs_for_generation(self, inputs_tensor, model_kwargs, model_input_name, generation_config)
#     547         encoder_kwargs["return_dict"] = True
#     548         encoder_kwargs[model_input_name] = inputs_tensor
# --> 549         model_kwargs["encoder_outputs"]: ModelOutput = encoder(**encoder_kwargs)
#     550
#     551         return model_kwargs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bart/modeling_bart.py in forward(self, input_ids, attention_mask, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict)
#    1059             inputs_embeds = self.embed_tokens(input_ids)
#    1060
# -> 1061         embed_pos = self.embed_positions(input)
#    1062         embed_pos = embed_pos.to(inputs_embeds.device)
#    1063
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1551             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1552         else:
# -> 1553             return self._call_impl(*args, **kwargs)
#    1554
#    1555     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1560                 or _global_backward_pre_hooks or _global_backward_hooks
#    1561                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1562             return forward_call(*args, **kwargs)
#    1563
#    1564         try:
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/bart/modeling_bart.py in forward(self, input_ids, past_key_values_length)
#     113         ).expand(bsz, -1)
#     114
# --> 115         return super().forward(positions + self.offset)
#     116
#     117
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/sparse.py in forward(self, input)
#     162
#     163     def forward(self, input: Tensor) -> Tensor:
# --> 164         return F.embedding(
#     165             input, self.weight, self.padding_idx, self.max_norm,
#     166             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2265         # remove once script supports set_grad_enabled
#    2266         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2267     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2268
#    2269
#
# IndexError: index out of range in self

# %% [markdown]
# ##💯 Before you proceed...
# You can write the regular expression pattern as <font color = 'red'> either</font> **RegexpTokenizer("[\w]+"), <font color = 'red'> either</font> **RegexpTokenizer("\w+"), <font color = 'red'> either</font> **RegexpTokenizer(r"\w+")** <font color = 'red'>or</font> **RegexpTokenizer(r"[\w]+")**. <font color = 'blue'> The 'r' before the string denotes a raw string literal, which is often used with regular expressions to avoid issues with escape characters.
#
# The regular expression [\w]+ breaks down as follows:
#
# - **\w** shorthand character class, which represents word characters "a-zA-Z0-9".
# - [ ] matches any single character specified in a pair of the square brackets.
# - **[\w]**: Match any word character (equivalent to [a-zA-Z0-9_]).
# - **+**: Match one or more occurrences of the preceding character class.
# - So, **[\w]+** will match one or more consecutive word characters, effectively tokenizing text into words.
# >
# 🆘 If you remove the square brackets and use \w+ (without [ ]), it would still work the same way, as \w+ is a shorthand for "match one or more word characters." The square brackets, in this case, are redundant but can be used for clarity or when you want to match a specific set of characters.
# >
# 🆘 The 'r' before the string (as in r"[\w]+") is optional in this case but is a good practice, especially with regular expressions, to avoid unintended escape character interpretation. It tells Python to treat the string as a "raw string," where backslashes are treated literally and not as escape characters.

# %%
from nltk.tokenize import RegexpTokenizer
# Create a RegexpTokenizer with the pattern [\w]+
retokenize = RegexpTokenizer("[\w]+")
# Tokenize the text using the regular expression pattern
words = retokenize.tokenize(text)

# %% [markdown]
# ### 🔴 ⚪ 🔵 Normalization
# Stemming: am → am, having → hav
# Lemmatization: am → be, having → have

# %% [markdown]
# ### <font color = 'red'> **Student Activity** 1️⃣
# - Examine the tokens listed in the result and understand how words are tokenized with **Poterstemmer()** function.⤵️

# %%
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
[stemmer.stem(w) for w in words]
# Out:
# ['down',
#  'a',
#  'sunni',
#  'dirt',
#  'road',
#  'over',
#  'a',
#  'log',
#  'bridg',
#  'up',
#  'a',
#  'grassi',
#  'hill',
#  'deep',
#  'in',
#  'bear',
#  'countri',
#  'live',
#  'a',
#  'famili',
#  'of',
#  'bear',
#  'papa',
#  'bear',
#  'mama',
#  'bear',
#  'and',
#  'small',
#  'bear',
#  'they',
#  'live',
#  'in',
#  'a',
#  'larg',
#  'tree',
#  'which',
#  'papa',
#  'bear',
#  'had',
#  'hollow',
#  'out',
#  'and',
#  'made',
#  'into',
#  'a',
#  'hous',
#  'it',
#  'wa',
#  'a',
#  'veri',
#  'fine',
#  'hous',
#  'thi',
#  'is',
#  'what',
#  'it',
#  'look',
#  'like',
#  'insid',
#  'it',
#  'wa',
#  'fun',
#  'grow',
#  'up',
#  'in',
#  'bear',
#  'countri',
#  'help',
#  'papa',
#  'get',
#  'honey',
#  'from',
#  'the',
#  'old',
#  'bee',
#  'tree',
#  'help',
#  'mama',
#  'bring',
#  'the',
#  'veget',
#  'in',
#  'from',
#  'the',
#  'garden',
#  'there',
#  'were',
#  'all',
#  'sort',
#  'of',
#  'interest',
#  'thing',
#  'for',
#  'a',
#  'small',
#  'bear',
#  'to',
#  'do',
#  'and',
#  'see',
#  'in',
#  'bear',
#  'countri',
#  'small',
#  'bear',
#  'felt',
#  'good',
#  'grow',
#  'up',
#  'in',
#  'a',
#  'tree',
#  'in',
#  'hi',
#  'own',
#  'room',
#  'in',
#  'the',
#  'snug',
#  'littl',
#  'bed',
#  'that',
#  'papa',
#  'bear',
#  'had',
#  'made',
#  'for',
#  'him',
#  'when',
#  'he',
#  'wa',
#  'a',
#  'babi',
#  'but',
#  'one',
#  'morn',
#  'it',
#  'did',
#  'not',
#  'feel',
#  'so',
#  'good',
#  'small',
#  'bear',
#  'woke',
#  'up',
#  'with',
#  'pain',
#  'in',
#  'hi',
#  'knee',
#  'and',
#  'ach',
#  'in',
#  'hi',
#  'leg',
#  'small',
#  'bear',
#  'you',
#  'have',
#  'outgrown',
#  'your',
#  'littl',
#  'bed',
#  'said',
#  'papa',
#  'bear',
#  'as',
#  'he',
#  'hitch',
#  'up',
#  'hi',
#  'overal',
#  'and',
#  'button',
#  'hi',
#  'shoulder',
#  'strap',
#  'today',
#  'we',
#  'shall',
#  'go',
#  'out',
#  'into',
#  'the',
#  'wood',
#  'and',
#  'make',
#  'you',
#  'a',
#  'bigger',
#  'one',
#  'with',
#  'that',
#  'he',
#  'ate',
#  'hi',
#  'breakfast',
#  'of',
#  'pipe',
#  'hot',
#  'porridg',
#  'wash',
#  'it',
#  'down',
#  'with',
#  'a',
#  'gulp',
#  'of',
#  'honey',
#  'from',
#  'the',
#  'famili',
#  'pot',
#  'took',
#  'up',
#  'hi',
#  'ax',
#  'and',
#  'wa',
#  'out',
#  'the',
#  'door',
#  'but',
#  'papa',
#  'call',
#  'small',
#  'bear',
#  'follow',
#  'after',
#  'him',
#  'what',
#  'will',
#  'happen',
#  'to',
#  'my',
#  'littl',
#  'bed',
#  'don',
#  't',
#  'worri',
#  'about',
#  'that',
#  'small',
#  'bear',
#  'said',
#  'mama',
#  'bear',
#  'as',
#  'she',
#  'close',
#  'the',
#  'door',
#  'after',
#  'him',
#  'she',
#  'smile',
#  'and',
#  'pat',
#  'her',
#  'front',
#  'which',
#  'had',
#  'late',
#  'grown',
#  'veri',
#  'big',
#  'and',
#  'round',
#  'you',
#  've',
#  'outgrown',
#  'that',
#  'snug',
#  'littl',
#  'bed',
#  'just',
#  'in',
#  'time',
#  'he',
#  'test',
#  'the',
#  'ax',
#  'to',
#  'see',
#  'if',
#  'it',
#  'wa',
#  'sharp',
#  'then',
#  'head',
#  'off',
#  'into',
#  'the',
#  'wood',
#  'what',
#  'will',
#  'happen',
#  'to',
#  'my',
#  'littl',
#  'bed',
#  'small',
#  'bear',
#  'ask',
#  'again',
#  'as',
#  'he',
#  'caught',
#  'up',
#  'with',
#  'papa',
#  'bear',
#  'in',
#  'the',
#  'wood',
#  'papa',
#  'had',
#  'chop',
#  'down',
#  'a',
#  'tree',
#  'and',
#  'wa',
#  'split',
#  'it',
#  'into',
#  'board',
#  'we',
#  'will',
#  'have',
#  'a',
#  'new',
#  'babi',
#  'soon',
#  'who',
#  'will',
#  'need',
#  'that',
#  'littl',
#  'bed',
#  'said',
#  'papa',
#  'bear',
#  'as',
#  'he',
#  'whack',
#  'off',
#  'anoth',
#  'board',
#  'a',
#  'ne',
#  'babi',
#  'ask',
#  'small',
#  'bear',
#  'he',
#  'hadn',
#  't',
#  'notic',
#  'that',
#  'mama',
#  'bear',
#  'had',
#  'grown',
#  'veri',
#  'round',
#  'late',
#  'although',
#  'he',
#  'had',
#  'notic',
#  'it',
#  'wa',
#  'harder',
#  'and',
#  'harder',
#  'to',
#  'sit',
#  'on',
#  'her',
#  'lap',
#  'and',
#  'it',
#  's',
#  'come',
#  'soon',
#  'ye',
#  'veri',
#  'soon',
#  'said',
#  'papa',
#  'bear',
#  'with',
#  'a',
#  'final',
#  'whack',
#  'he',
#  'split',
#  'off',
#  'the',
#  'last',
#  'board',
#  'which',
#  'gave',
#  'him',
#  'enough',
#  'wood',
#  'to',
#  'make',
#  'a',
#  'bigger',
#  'bed',
#  'for',
#  'small',
#  'bear',
#  'they',
#  'made',
#  'the',
#  'bed',
#  'a',
#  'good',
#  'size',
#  'and',
#  'took',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'day',
#  'to',
#  'chip',
#  'and',
#  'shave',
#  'it',
#  'smooth',
#  'and',
#  'neat',
#  'then',
#  'they',
#  'carri',
#  'it',
#  'back',
#  'to',
#  'the',
#  'tree',
#  'and',
#  'up',
#  'to',
#  'small',
#  'bear',
#  's',
#  'room',
#  'when',
#  'they',
#  'got',
#  'there',
#  'small',
#  'bear',
#  'notic',
#  'right',
#  'away',
#  'that',
#  'hi',
#  'old',
#  'bed',
#  'wasn',
#  't',
#  'there',
#  'ani',
#  'more',
#  'my',
#  'littl',
#  'bed',
#  'said',
#  'small',
#  'bear',
#  'it',
#  's',
#  'alreadi',
#  'gone',
#  'you',
#  'outgrew',
#  'it',
#  'just',
#  'in',
#  'time',
#  'call',
#  'mama',
#  'bear',
#  'from',
#  'the',
#  'next',
#  'room',
#  'come',
#  'and',
#  'see',
#  'it',
#  'wa',
#  'true',
#  'there',
#  'wa',
#  'hi',
#  'snug',
#  'littl',
#  'bed',
#  'with',
#  'a',
#  'new',
#  'littl',
#  'babi',
#  'in',
#  'it',
#  'small',
#  'bear',
#  'had',
#  'outgrown',
#  'hi',
#  'snug',
#  'littl',
#  'bed',
#  'just',
#  'in',
#  'time',
#  'for',
#  'hi',
#  'new',
#  'babi',
#  'sister',
#  'and',
#  'now',
#  'he',
#  'wa',
#  'a',
#  'big',
#  'brother',
#  'she',
#  'wa',
#  'veri',
#  'littl',
#  'but',
#  'veri',
#  'live',
#  'as',
#  'small',
#  'bear',
#  'learn',
#  'over',
#  'for',
#  'a',
#  'closer',
#  'look',
#  'she',
#  'pop',
#  'him',
#  'on',
#  'the',
#  'nose',
#  'with',
#  'a',
#  'tini',
#  'fist',
#  'hmm',
#  'said',
#  'small',
#  'bear',
#  'she',
#  'ha',
#  'a',
#  'pretti',
#  'good',
#  'punch',
#  'for',
#  'a',
#  'littl',
#  'babi',
#  'that',
#  'night',
#  'he',
#  'stretch',
#  'out',
#  'proudli',
#  'in',
#  'hi',
#  'bigger',
#  'bed',
#  'aah',
#  'he',
#  'said',
#  'be',
#  'a',
#  'big',
#  'brother',
#  'is',
#  'go',
#  'to',
#  'be',
#  'fun',
#  'the',
#  'next',
#  'morn',
#  'he',
#  'woke',
#  'up',
#  'feel',
#  'fine',
#  'with',
#  'no',
#  'pain',
#  'in',
#  'hi',
#  'knee',
#  'or',
#  'ach',
#  'in',
#  'hi',
#  'leg',
#  'hi',
#  'nose',
#  'wa',
#  'a',
#  'littl',
#  'tender',
#  'though',
#  'the',
#  'bear',
#  'famili',
#  'didn',
#  't',
#  'alway',
#  'live',
#  'in',
#  'the',
#  'big',
#  'tree',
#  'hous',
#  'down',
#  'a',
#  'sunni',
#  'dirt',
#  'road',
#  'deep',
#  'in',
#  'bear',
#  'countri',
#  'year',
#  'ago',
#  'when',
#  'brother',
#  'bear',
#  'wa',
#  'an',
#  'onli',
#  'cub',
#  'they',
#  'live',
#  'in',
#  'a',
#  'hillsid',
#  'cave',
#  'halfway',
#  'up',
#  'great',
#  'bear',
#  'mountain',
#  'at',
#  'the',
#  'far',
#  'edg',
#  'of',
#  'bear',
#  'countri',
#  'it',
#  'wa',
#  'a',
#  'comfort',
#  'cave',
#  'cool',
#  'in',
#  'summer',
#  'and',
#  'cozi',
#  'in',
#  'winter',
#  'and',
#  'while',
#  'it',
#  'wasn',
#  't',
#  'perfect',
#  'it',
#  'tend',
#  'to',
#  'be',
#  'dark',
#  'and',
#  'it',
#  'drip',
#  'and',
#  'trickl',
#  'a',
#  'bit',
#  'it',
#  'wa',
#  'home',
#  'and',
#  'the',
#  'bear',
#  'famili',
#  'wa',
#  'quit',
#  'happi',
#  'there',
#  'happi',
#  'and',
#  'busi',
#  'mama',
#  'bear',
#  'kept',
#  'busi',
#  'manag',
#  'thing',
#  'and',
#  'tend',
#  'the',
#  'veget',
#  'patch',
#  'papa',
#  'bear',
#  'had',
#  'plenti',
#  'to',
#  'do',
#  'with',
#  'hi',
#  'wood',
#  'cut',
#  'and',
#  'furnitur',
#  'make',
#  'and',
#  'brother',
#  'bear',
#  'kept',
#  'busi',
#  'climb',
#  'collect',
#  'rock',
#  'and',
#  'play',
#  'with',
#  'hi',
#  'friend',
#  'but',
#  'live',
#  'on',
#  'the',
#  'mountainsid',
#  'wasn',
#  't',
#  'perfect',
#  'it',
#  'wasn',
#  't',
#  'easi',
#  'grow',
#  'veget',
#  'in',
#  'the',
#  'thin',
#  'rocki',
#  'soil',
#  'and',
#  'the',
#  'tree',
#  'papa',
#  'need',
#  'were',
#  'get',
#  'fewer',
#  'and',
#  'farther',
#  'between',
#  'but',
#  'the',
#  'sun',
#  'wa',
#  'bright',
#  'the',
#  'air',
#  'wa',
#  'clear',
#  'and',
#  'sparkl',
#  'and',
#  'the',
#  'view',
#  'wa',
#  'magnific',
#  'ye',
#  'the',
#  'bear',
#  'famili',
#  'wa',
#  'happi',
#  'and',
#  'content',
#  'live',
#  'in',
#  'their',
#  'hillsid',
#  'cave',
#  'halfway',
#  'up',
#  'great',
#  'bear',
#  'mountain',
#  'at',
#  'the',
#  'far',
#  'edg',
#  'of',
#  'bear',
#  'countri',
#  'until',
#  'one',
#  'day',
#  'papa',
#  'bear',
#  'said',
#  'my',
#  'dear',
#  'the',
#  'time',
#  'ha',
#  'come',
#  'to',
#  'move',
#  'move',
#  'cri',
#  'brother',
#  'bear',
#  'that',
#  's',
#  'right',
#  'said',
#  'papa',
#  'the',
#  'tree',
#  'are',
#  'get',
#  'few',
#  'and',
#  'far',
#  'between',
#  'on',
#  'the',
#  'mountainsid',
#  'ye',
#  'said',
#  'mama',
#  'and',
#  'it',
#  's',
#  'not',
#  'easi',
#  'rais',
#  'enough',
#  'veget',
#  'for',
#  'a',
#  'grow',
#  'famili',
#  'in',
#  'thi',
#  'thin',
#  'rocki',
#  'soil',
#  'where',
#  'are',
#  'we',
#  'go',
#  'to',
#  'move',
#  'to',
#  'brother',
#  'ask',
#  'to',
#  'the',
#  'valley',
#  'said',
#  'papa',
#  'as',
#  'he',
#  'began',
#  'put',
#  'lamp',
#  'and',
#  'thing',
#  'into',
#  'a',
#  'box',
#  'the',
#  'valley',
#  'said',
#  'brother',
#  'the',
#  'valley',
#  'down',
#  'there',
#  'wa',
#  'nice',
#  'to',
#  'look',
#  'at',
#  'but',
#  'he',
#  'wasn',
#  't',
#  'so',
#  'sure',
#  'he',
#  'want',
#  'to',
#  'live',
#  'there',
#  'it',
#  'wa',
#  'so',
#  'far',
#  'away',
#  'what',
#  'about',
#  'my',
#  'toy',
#  'ask',
#  'brother',
#  'we',
#  'll',
#  'take',
#  'them',
#  'along',
#  'of',
#  'cours',
#  'put',
#  'them',
#  'in',
#  'there',
#  'said',
#  'papa',
#  'hand',
#  'him',
#  'a',
#  'box',
#  'and',
#  'what',
#  'about',
#  'my',
#  'book',
#  'we',
#  'll',
#  'take',
#  'them',
#  'along',
#  'too',
#  'said',
#  'papa',
#  'hand',
#  'him',
#  'anoth',
#  'box',
#  'and',
#  'what',
#  'about',
#  'my',
#  'friend',
#  'ask',
#  'brother',
#  'we',
#  'can',
#  't',
#  'put',
#  'them',
#  'in',
#  'a',
#  'box',
#  'and',
#  'take',
#  'them',
#  'along',
#  'that',
#  's',
#  'true',
#  'said',
#  'mama',
#  'lift',
#  'brother',
#  'onto',
#  'her',
#  'lap',
#  ...]

# %% [markdown]
# ### <font color = 'red'> **Student Activity** 2️⃣
# - Examine the tokens listed in the result and understand how words are tokenized with **LancasterStemmer()** function.⤵️

# %%
#from nltk.stem import LancasterStemmer
#stemmer = LancasterStemmer()
#[stemmer.stem(w) for w in words]

# %% [markdown]
# ### <font color = 'red'> **Student Activity** 3️⃣
# - Examine the tokens listed in the result and understand how words are tokenized with **WordNetLemmatizer()** function.⤵️

# %%
#from nltk.stem import WordNetLemmatizer
#nltk.download('wordnet')
#lemmatizer = WordNetLemmatizer()
#[lemmatizer.lemmatize(w) for w in words]

# %% [markdown]
# ### ⛔ <font color = 'brown'> **Stopword**
#
# ✏️ In natural language processing, stop words are commonly used words (e.g., "the," "and," "is") that are often filtered out because they don't contribute much to the meaning of a text. Here's an example list of English stop words:
#
# stopwords = [ 'i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't",'wouldn', "wouldn't" ]
#
# You can customize or extend this list based on your specific needs and the requirements of your natural language processing task. Keep in mind that the appropriateness of stop words may vary depending on the specific context and analysis you are conducting.

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
print(words)
words = [w for w in words if not w in stopwords.words('english')]
print(words)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# ['Down', 'a', 'sunny', 'dirt', 'road', 'over', 'a', 'log', 'bridge', 'up', 'a', 'grassy', 'hill', 'deep', 'in', 'Bear', 'Country', 'lived', 'a', 'family', 'of', 'bears', 'Papa', 'Bear', 'Mama', 'Bear', 'and', 'Small', 'Bear', 'They', 'lived', 'in', 'a', 'large', 'tree', 'which', 'Papa', 'Bear', 'had', 'hollowed', 'out', 'and', 'made', 'into', 'a', 'house', 'It', 'was', 'a', 'very', 'fine', 'house', 'This', 'is', 'what', 'it', 'looked', 'like', 'inside', 'It', 'was', 'fun', 'growing', 'up', 'in', 'Bear', 'Country', 'helping', 'Papa', 'get', 'honey', 'from', 'the', 'old', 'bee', 'tree', 'helping', 'Mama', 'bring', 'the', 'vegetables', 'in', 'from', 'the', 'garden', 'There', 'were', 'all', 'sorts', 'of', 'interesting', 'things', 'for', 'a', 'small', 'bear', 'to', 'do', 'and', 'see', 'in', 'Bear', 'Country', 'Small', 'Bear', 'felt', 'good', 'growing', 'up', 'in', 'a', 'tree', 'in', 'his', 'own', 'room', 'in', 'the', 'snug', 'little', 'bed', 'that', 'Papa', 'Bear', 'had', 'made', 'for', 'him', 'when', 'he', 'was', 'a', 'baby', 'But', 'one', 'morning', 'it', 'did', 'not', 'feel', 'so', 'good', 'Small', 'Bear', 'woke', 'up', 'with', 'pains', 'in', 'his', 'knees', 'and', 'aches', 'in', 'his', 'legs', 'Small', 'Bear', 'you', 'have', 'outgrown', 'your', 'little', 'bed', 'said', 'Papa', 'Bear', 'as', 'he', 'hitched', 'up', 'his', 'overalls', 'and', 'buttoned', 'his', 'shoulder', 'straps', 'Today', 'we', 'shall', 'go', 'out', 'into', 'the', 'woods', 'and', 'make', 'you', 'a', 'bigger', 'one', 'With', 'that', 'he', 'ate', 'his', 'breakfast', 'of', 'piping', 'hot', 'porridge', 'washed', 'it', 'down', 'with', 'a', 'gulp', 'of', 'honey', 'from', 'the', 'family', 'pot', 'took', 'up', 'his', 'ax', 'and', 'was', 'out', 'the', 'door', 'But', 'Papa', 'called', 'Small', 'Bear', 'following', 'after', 'him', 'What', 'will', 'happen', 'to', 'my', 'little', 'bed', 'Don', 't', 'worry', 'about', 'that', 'Small', 'Bear', 'said', 'Mama', 'Bear', 'as', 'she', 'closed', 'the', 'door', 'after', 'him', 'She', 'smiled', 'and', 'patted', 'her', 'front', 'which', 'had', 'lately', 'grown', 'very', 'big', 'and', 'round', 'You', 've', 'outgrown', 'that', 'snug', 'little', 'bed', 'just', 'in', 'time', 'He', 'tested', 'the', 'ax', 'to', 'see', 'if', 'it', 'was', 'sharp', 'then', 'headed', 'off', 'into', 'the', 'woods', 'What', 'will', 'happen', 'to', 'my', 'little', 'bed', 'Small', 'Bear', 'asked', 'again', 'as', 'he', 'caught', 'up', 'with', 'Papa', 'Bear', 'in', 'the', 'woods', 'Papa', 'had', 'chopped', 'down', 'a', 'tree', 'and', 'was', 'splitting', 'it', 'into', 'boards', 'We', 'will', 'have', 'a', 'new', 'baby', 'soon', 'who', 'will', 'need', 'that', 'little', 'bed', 'said', 'papa', 'Bear', 'as', 'he', 'whacked', 'off', 'another', 'board', 'A', 'ne', 'baby', 'asked', 'Small', 'Bear', 'He', 'hadn', 't', 'noticed', 'that', 'Mama', 'Bear', 'had', 'grown', 'very', 'round', 'lately', 'although', 'he', 'had', 'noticed', 'it', 'was', 'harder', 'and', 'harder', 'to', 'sit', 'on', 'her', 'lap', 'And', 'it', 's', 'coming', 'soon', 'Yes', 'very', 'soon', 'said', 'Papa', 'Bear', 'With', 'a', 'final', 'whack', 'he', 'split', 'off', 'the', 'last', 'board', 'which', 'gave', 'him', 'enough', 'wood', 'to', 'make', 'a', 'bigger', 'bed', 'for', 'Small', 'Bear', 'They', 'made', 'the', 'bed', 'a', 'good', 'size', 'and', 'took', 'the', 'rest', 'of', 'the', 'day', 'to', 'chip', 'and', 'shave', 'it', 'smooth', 'and', 'neat', 'Then', 'they', 'carried', 'it', 'back', 'to', 'the', 'tree', 'and', 'up', 'to', 'Small', 'Bear', 's', 'room', 'When', 'they', 'got', 'there', 'Small', 'Bear', 'noticed', 'right', 'away', 'that', 'his', 'old', 'bed', 'wasn', 't', 'there', 'any', 'more', 'My', 'little', 'bed', 'said', 'Small', 'Bear', 'It', 's', 'already', 'gone', 'You', 'outgrew', 'it', 'just', 'in', 'time', 'called', 'Mama', 'Bear', 'from', 'the', 'next', 'room', 'Come', 'and', 'see', 'It', 'was', 'true', 'There', 'was', 'his', 'snug', 'little', 'bed', 'with', 'a', 'new', 'little', 'baby', 'in', 'i ...
# ['Down', 'sunny', 'dirt', 'road', 'log', 'bridge', 'grassy', 'hill', 'deep', 'Bear', 'Country', 'lived', 'family', 'bears', 'Papa', 'Bear', 'Mama', 'Bear', 'Small', 'Bear', 'They', 'lived', 'large', 'tree', 'Papa', 'Bear', 'hollowed', 'made', 'house', 'It', 'fine', 'house', 'This', 'looked', 'like', 'inside', 'It', 'fun', 'growing', 'Bear', 'Country', 'helping', 'Papa', 'get', 'honey', 'old', 'bee', 'tree', 'helping', 'Mama', 'bring', 'vegetables', 'garden', 'There', 'sorts', 'interesting', 'things', 'small', 'bear', 'see', 'Bear', 'Country', 'Small', 'Bear', 'felt', 'good', 'growing', 'tree', 'room', 'snug', 'little', 'bed', 'Papa', 'Bear', 'made', 'baby', 'But', 'one', 'morning', 'feel', 'good', 'Small', 'Bear', 'woke', 'pains', 'knees', 'aches', 'legs', 'Small', 'Bear', 'outgrown', 'little', 'bed', 'said', 'Papa', 'Bear', 'hitched', 'overalls', 'buttoned', 'shoulder', 'straps', 'Today', 'shall', 'go', 'woods', 'make', 'bigger', 'one', 'With', 'ate', 'breakfast', 'piping', 'hot', 'porridge', 'washed', 'gulp', 'honey', 'family', 'pot', 'took', 'ax', 'door', 'But', 'Papa', 'called', 'Small', 'Bear', 'following', 'What', 'happen', 'little', 'bed', 'Don', 'worry', 'Small', 'Bear', 'said', 'Mama', 'Bear', 'closed', 'door', 'She', 'smiled', 'patted', 'front', 'lately', 'grown', 'big', 'round', 'You', 'outgrown', 'snug', 'little', 'bed', 'time', 'He', 'tested', 'ax', 'see', 'sharp', 'headed', 'woods', 'What', 'happen', 'little', 'bed', 'Small', 'Bear', 'asked', 'caught', 'Papa', 'Bear', 'woods', 'Papa', 'chopped', 'tree', 'splitting', 'boards', 'We', 'new', 'baby', 'soon', 'need', 'little', 'bed', 'said', 'papa', 'Bear', 'whacked', 'another', 'board', 'A', 'ne', 'baby', 'asked', 'Small', 'Bear', 'He', 'noticed', 'Mama', 'Bear', 'grown', 'round', 'lately', 'although', 'noticed', 'harder', 'harder', 'sit', 'lap', 'And', 'coming', 'soon', 'Yes', 'soon', 'said', 'Papa', 'Bear', 'With', 'final', 'whack', 'split', 'last', 'board', 'gave', 'enough', 'wood', 'make', 'bigger', 'bed', 'Small', 'Bear', 'They', 'made', 'bed', 'good', 'size', 'took', 'rest', 'day', 'chip', 'shave', 'smooth', 'neat', 'Then', 'carried', 'back', 'tree', 'Small', 'Bear', 'room', 'When', 'got', 'Small', 'Bear', 'noticed', 'right', 'away', 'old', 'bed', 'My', 'little', 'bed', 'said', 'Small', 'Bear', 'It', 'already', 'gone', 'You', 'outgrew', 'time', 'called', 'Mama', 'Bear', 'next', 'room', 'Come', 'see', 'It', 'true', 'There', 'snug', 'little', 'bed', 'new', 'little', 'baby', 'Small', 'Bear', 'outgrown', 'snug', 'little', 'bed', 'time', 'new', 'baby', 'sister', 'And', 'big', 'brother', 'She', 'little', 'lively', 'As', 'Small', 'Bear', 'learned', 'closer', 'look', 'popped', 'nose', 'tiny', 'fist', 'Hmm', 'said', 'Small', 'Bear', 'She', 'pretty', 'good', 'punch', 'little', 'baby', 'That', 'night', 'stretched', 'proudly', 'bigger', 'bed', 'Aah', 'said', 'Being', 'big', 'brother', 'going', 'fun', 'The', 'next', 'morning', 'woke', 'feeling', 'fine', 'pains', 'knees', 'aches', 'legs', 'His', 'nose', 'little', 'tender', 'though', 'The', 'Bear', 'family', 'always', 'live', 'big', 'tree', 'house', 'sunny', 'dirt', 'road', 'deep', 'Bear', 'Country', 'Years', 'ago', 'Brother', 'Bear', 'cub', 'lived', 'hillside', 'cave', 'halfway', 'Great', 'Bear', 'Mountain', 'far', 'edge', 'Bear', 'Country', 'It', 'comfortable', 'cave', 'cool', 'summer', 'cozy', 'winter', 'And', 'perfect', 'tended', 'dark', 'dripped', 'trickled', 'bit', 'home', 'Bear', 'family', 'quite', 'happy', 'Happy', 'busy', 'Mama', 'Bear', 'kept', 'busy', 'managing', 'things', 'tending', 'vegetable', 'patch', 'Papa', 'Bear', 'plenty', 'wood', 'cutting', 'furniture', 'making', 'And', 'Brother', 'Bear', 'kept', 'busy', 'climbing', 'collecting', 'rocks', 'playing', 'friends', 'But', 'living', 'mountainside', 'perfect', 'easy', 'growing', 'vegetables', 'thin', 'rocky', 'soil', 'trees', 'Papa', 'needed', 'getting', 'fewer', 'farther', 'But', 'sun', 'bright', 'air', 'clear', 'sparkling', 'view', 'magnificent', 'Yes', 'Bear', ...

# %% [markdown]
# ### 📍 Collocation 📍Concordance

# %%
#!pip install nltk
#import nltk
#from nltk.tokenize import word_tokenize

# Download the Gutenberg corpus
#nltk.download('gutenberg')
# Load the text from 'austen-emma.txt'
#text = nltk.corpus.gutenberg.raw('austen-emma.txt')

# Create a RegexpTokenizer
#import re
#from nltk.tokenize import RegexpTokenizer
#retokenize = RegexpTokenizer(r"[\w]+")
# Tokenize the text using the regular expression pattern
#words = retokenize.tokenize(text)

# Print the first 50 words as an example
#print(words[:50])

# %% [markdown]
# Before you proceed...
#
# In NLTK (Natural Language Toolkit), the **Text class** is part of the nltk.text module. The Text class is designed to work with a sequence of words and provides several methods for exploring and analyzing text data. It is often used to represent and analyze corpora or individual texts.

# %%
# Create an NLTK Text object from the list of words.
text_object = nltk.Text(words)

# %% [markdown]
# 🆘 <font color = 'blue'> **Collocations** (연어) are pairs of words that occur together frequently in a given context.

# %%
# !pip install nltk
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize

nltk.download('punkt')

# Download the stopwords resource
#nltk.download('stopwords')
#nltk.download('genesis') #I don't know this codeline exactly.

# Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase

# Step 2: Create an NLTK Text object
text_object = Text(tokens)

# Step 3: Find and print collocations (this automatically finds frequent word pairs)
print(text_object.collocations())

# Step 4: Display a concordance for the word 'Emma'
text_object.concordance('Sister', width=100, lines=20)

# Step 5: Plotting
text_object.dispersion_plot(['Papa', ' Mama', 'Brother', 'Sister'])
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# tree house; bear family; small bear; bear country; said papa; sunny
# dirt; said mama; dirt road; said sister; said brother; little bed;
# vegetable patch; grizzly bob; silly goose; common sense; wing tips;
# sister bear; name calling; radio-controlled job; skull rock
# None
# Displaying 20 of 125 matches:
#  snug little bed just in time for his new baby sister . and now he was a big brother ! she was very
# t about perfect. `` `` “ brother bear , ” said sister impatiently , “ are you going to take all day
# u going to take all day to pick your books ? ” sister and brother bear at the bear country library .
# and brother bear at the bear country library . sister had already chosen her books and was waiting a
# brother . “ i am looking for a good mystery. ” sister bear usually took out storybooks and books abo
#  “ okay , let ’ s check out. ” “ hmmm , ” said sister , looking at the cover . it was called the cas
# uld you like me to read it to you ? ” he asked sister . sister was looking at a storybook about thre
# ike me to read it to you ? ” he asked sister . sister was looking at a storybook about three kittens
#  ? ” teased brother . “ of course not , ” said sister . she left her book on the floor and climbed o
# ession . “ ’ who-o-o-o-o ! ’ ” “ stop ! ” said sister , putting her fingers in her ears . “ that ’ s
# d off , on and off . but inside the tree house sister bear wasn ’ t even beginning to fall asleep .
# r papa and tripped over him . in the commotion sister fell out of bed and landed on both of them . t
# oky wail , turned on the light . what a mess ! sister , still scared , was holding on to papa . papa
# bing your toe ) —but it didn ’ t do any good . sister absolutely refused to go to sleep with the lig
# hink i have an idea that might help. ” he took sister ’ s hand . “ come with me , ” he said . “ wher
#  sometimes. ” “ what ’ s imagination ? ” asked sister . “ imagination is what makes us think that ch
# tures. ” “ i wish i didn ’ t have one , ” said sister . “ don ’ t say that , ” said papa . “ a livel
# ummage through boxes , looking for something . sister tried to follow papa ’ s advice and not let he
#  little trouble falling asleep in the dark ! ” sister couldn ’ t quite believe that her big , powerf
# ng the rest of the case of the crying cave ? ” sister asked brother later that day . “ are you sure

# %% [markdown]
# 🆘 <font color = 'blue'> **Concordance** (용례) shows the context in which a word appears in the text

# %%
# !pip install nltk
import nltk
from nltk.text import Text
from nltk.tokenize import word_tokenize

nltk.download('punkt')

# Download the stopwords resource
#nltk.download('stopwords')
#nltk.download('genesis') #I don't know this codeline exactly.

# Step 1: Tokenize the text
tokens = word_tokenize(text.lower())  # Tokenize the text and convert to lowercase

# Step 2: Create an NLTK Text object
text_object = Text(tokens)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Display a concordance for the word 'Emma'
text_object.concordance('Sister', width=100, lines=20)
# Out:
# Displaying 20 of 125 matches:
#  snug little bed just in time for his new baby sister . and now he was a big brother ! she was very
# t about perfect. `` `` “ brother bear , ” said sister impatiently , “ are you going to take all day
# u going to take all day to pick your books ? ” sister and brother bear at the bear country library .
# and brother bear at the bear country library . sister had already chosen her books and was waiting a
# brother . “ i am looking for a good mystery. ” sister bear usually took out storybooks and books abo
#  “ okay , let ’ s check out. ” “ hmmm , ” said sister , looking at the cover . it was called the cas
# uld you like me to read it to you ? ” he asked sister . sister was looking at a storybook about thre
# ike me to read it to you ? ” he asked sister . sister was looking at a storybook about three kittens
#  ? ” teased brother . “ of course not , ” said sister . she left her book on the floor and climbed o
# ession . “ ’ who-o-o-o-o ! ’ ” “ stop ! ” said sister , putting her fingers in her ears . “ that ’ s
# d off , on and off . but inside the tree house sister bear wasn ’ t even beginning to fall asleep .
# r papa and tripped over him . in the commotion sister fell out of bed and landed on both of them . t
# oky wail , turned on the light . what a mess ! sister , still scared , was holding on to papa . papa
# bing your toe ) —but it didn ’ t do any good . sister absolutely refused to go to sleep with the lig
# hink i have an idea that might help. ” he took sister ’ s hand . “ come with me , ” he said . “ wher
#  sometimes. ” “ what ’ s imagination ? ” asked sister . “ imagination is what makes us think that ch
# tures. ” “ i wish i didn ’ t have one , ” said sister . “ don ’ t say that , ” said papa . “ a livel
# ummage through boxes , looking for something . sister tried to follow papa ’ s advice and not let he
#  little trouble falling asleep in the dark ! ” sister couldn ’ t quite believe that her big , powerf
# ng the rest of the case of the crying cave ? ” sister asked brother later that day . “ are you sure

# %%
#@markdown 🐹 🐾 <font color = 'green'> **This code cell is repeated, referring to code cells from [7] to [10] right above.**

# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

# Download the Gutenberg corpus
nltk.download('gutenberg')
# Load the text from 'austen-emma.txt'
text = nltk.corpus.gutenberg.raw('austen-emma.txt')

# Create a RegexpTokenizer
import re
from nltk.tokenize import RegexpTokenizer
retokenize = RegexpTokenizer(r"[\w]+")
# Tokenize the text using the regular expression pattern
words = retokenize.tokenize(text)

# Create an NLTK Text object from the list of words.
text_object = nltk.Text(words)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Unzipping corpora/gutenberg.zip.

# %%
# Generate a dispersion plot (분산도) for the specified words
text_object.dispersion_plot(["Mama","Papa","Brother", "Sister"])

# %%
# Generate a dispersion plot (분산도) for the specified words
text_object.dispersion_plot(["Mama", "Papa", "Brother Bear", "Sister Bear"])

# %%
# Generate a dispersion plot (분산도) for the specified words
text_object.dispersion_plot(["Mama Bear","Papa Bear","Brother", "Sister"])

# %% [markdown]
# ###⛔ **Befoe you proceed...**
# - The similar() method in NLTK's Text class is used to find _words_ that appear _in a similar context to the specified word_. It helps identify words that tend to occur in similar contexts within the given text.

# %%
#Finds words that appear in a similar context to "Emma."
text_object.similar("Emma")
# Out:
# she it he i harriet you her jane him that me and all they them herself
# there but be isabella

# %% [markdown]
# ###🚫 **Befoe you proceed...**
# - The common_contexts() method in NLTK's Text class is used to display contexts shared by two or more words. It helps identify situations where specific words appear together in similar contexts.
#
# ###- How to interpret the result?
#     - said_i and_could: In contexts where "said" is followed by "I" and "could."
#     - but_could said_as and_was: In contexts where "but" is followed by "could," "said as," and "was."
#     - that_could said_in as_could: In contexts where "that" is followed by "could," "said in," and "as could," and so on.

# %%
nltk.Text(words).common_contexts(["Emma", "she"])
# Out:
# said_i and_could but_could said_as and_was that_could and_felt
# which_could that_began than_had but_was that_should this_could
# there_was said_in as_could think_was as_felt that_was which_had

# %% [markdown]
# ### Frequency distribution, Frequency plot

# %%
# Create a frequency distribution of words and get the 20 most common words
fd = nltk.FreqDist(words).most_common(20)
# print the result by writing its variable name.
print(fd) # results as a list horizontally
fd # results as a list vertically
# Out:
# [('to', 5183), ('the', 4844), ('and', 4672), ('of', 4279), ('I', 3178), ('a', 3004), ('was', 2385), ('her', 2381), ('it', 2128), ('in', 2118), ('not', 2101), ('be', 1970), ('she', 1778), ('that', 1730), ('you', 1677), ('had', 1606), ('as', 1387), ('he', 1365), ('for', 1321), ('have', 1301)]
# [('to', 5183),
#  ('the', 4844),
#  ('and', 4672),
#  ('of', 4279),
#  ('I', 3178),
#  ('a', 3004),
#  ('was', 2385),
#  ('her', 2381),
#  ('it', 2128),
#  ('in', 2118),
#  ('not', 2101),
#  ('be', 1970),
#  ('she', 1778),
#  ('that', 1730),
#  ('you', 1677),
#  ('had', 1606),
#  ('as', 1387),
#  ('he', 1365),
#  ('for', 1321),
#  ('have', 1301)]

# %%
# Create an NLTK Text object and plot the frequency distribution of the 20 most common words
nltk.Text(words).plot(20)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ### 📚<font color ='blue'> **Dictionary**

# %%
# Download the 'words' corpus and display the last 20 words in the English language
nltk.download('words')
nltk.corpus.words.words('en')[-20:-1]
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# ['zymosis',
#  'zymosterol',
#  'zymosthenic',
#  'zymotechnic',
#  'zymotechnical',
#  'zymotechnics',
#  'zymotechny',
#  'zymotic',
#  'zymotically',
#  'zymotize',
#  'zymotoxic',
#  'zymurgy',
#  'Zyrenian',
#  'Zyrian',
#  'Zyryan',
#  'zythem',
#  'Zythia',
#  'zythum',
#  'Zyzomys']

# %%
# Get the total number of words in the English language corpus
len(nltk.corpus.words.words('en'))
# Out:
# 235886

# %% [markdown]
# ### ♊ Regular expression

# %%
import re

# %%
# Load the English words corpus
engdict = nltk.corpus.words.words('en')

# Filter words in the English dictionary that end with 'ed'
result = [w for w in engdict if re.search('ed$', w)]
# result = [w for w in engdict if re.search('^..j..t..$', w)]
# result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
# result = [w for w in engdict if re.search('^[ah]+$', w)][:10]

# Print the first 10 words in the result list
print(result[:10])
# Out:
# ['abaissed', 'abandoned', 'abased', 'abashed', 'abatised', 'abed', 'aborted', 'abridged', 'abscessed', 'absconded']

# %%
#@markdown 🅿️ Additional exercise2 for RE. Check out the code line if you are interested...
result = [w for w in engdict if re.search('^[ghi][mno][jlk][def]$', w)]
print(result[:10])
# Out:
# ['gold', 'golf', 'hold', 'hole']

# %%
# Download the 'treebank' corpus
nltk.download('treebank')
# Load the words from the treebank corpus
wsj = nltk.corpus.treebank.words()

# Filter words in the treebank corpus that end with 'ed' or 'ing'
result = [w for w in wsj if re.search('(ed|ing)$', w)]

#If you are interested, play with the following RE.
# result = [w for w in wsj if re.search('^[0-9]+\.[0-9]+$', w)]
# result = [w for w in wsj if re.search('^[A-Z]+\$$', w)]
# result = [w for w in wsj if re.search('^[0-9]{4}$', w)]
# result = [w for w in wsj if re.search('^[0-9]+-[a-z]{3,5}$', w)]
# result = [w for w in wsj if re.search('^[a-z]{5,}-[a-z]{2,3}-[a-z]{,6}$', w)]

result = sorted(set(result))
print(result[:10])
# Out:
# [nltk_data] Downloading package treebank to /root/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# ['62%-owned', 'Absorbed', 'According', 'Adopting', 'Advanced', 'Advancing', 'Alfred', 'Allied', 'Annualized', 'Anything']

# %% [markdown]
# ### 🔨🔧 Extract information (pos tag, named entity)

# %% [markdown]
# ##💯 Before you proceed...
#
# 🐣The nltk.download('punkt') command is used to download the 'punkt' resource from the NLTK (Natural Language Toolkit) library.
#
# 🐣This resource includes the pre-trained Punkt tokenizer models **for tokenization**.
#
# 🐣Tokenization is the process of breaking down **a text into words or sentences**,vand the Punkt tokenizer is <font color = 'blue'>_a machine learning-based tokenization algorithm_ included in NLTK.

# %%
# !pip install nltk
import nltk
nltk.download('punkt')

# Example sentence and tokenization
sent = "I am Jhon from America and would like to go to Starbucks"
words = nltk.word_tokenize(sent)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
'''
POS tag list:

CC	coordinating conjunction
CD	cardinal digit
DT	determiner
EX	existential there (like: "there is" ... think of it like "there exists")
FW	foreign word
IN	preposition/subordinating conjunction
JJ	adjective	'big'
JJR	adjective, comparative	'bigger'
JJS	adjective, superlative	'biggest'
LS	list marker	1)
MD	modal	could, will
NN	noun, singular 'desk'
NNS	noun plural	'desks'
NNP	proper noun, singular	'Harrison'
NNPS	proper noun, plural	'Americans'
PDT	predeterminer	'all the kids'
POS	possessive ending	parent's
PRP	personal pronoun	I, he, she
PRP$	possessive pronoun	my, his, hers
RB	adverb	very, silently,
RBR	adverb, comparative	better
RBS	adverb, superlative	best
RP	particle	give up
TO	to	go 'to' the store.
UH	interjection	errrrrrrrm
VB	verb, base form	take
VBD	verb, past tense	took
VBG	verb, gerund/present participle	taking
VBN	verb, past participle	taken
VBP	verb, sing. present, non-3d	take
VBZ	verb, 3rd person sing. present	takes
WDT	wh-determiner	which
WP	wh-pronoun	who, what
WP$	possessive wh-pronoun	whose
WRB	wh-abverb	where, when
'''
# Out:
# '\nPOS tag list:\n\nCC\tcoordinating conjunction\nCD\tcardinal digit\nDT\tdeterminer\nEX\texistential there (like: "there is" ... think of it like "there exists")\nFW\tforeign word\nIN\tpreposition/subordinating conjunction\nJJ\tadjective\t\'big\'\nJJR\tadjective, comparative\t\'bigger\'\nJJS\tadjective, superlative\t\'biggest\'\nLS\tlist marker\t1)\nMD\tmodal\tcould, will\nNN\tnoun, singular \'desk\'\nNNS\tnoun plural\t\'desks\'\nNNP\tproper noun, singular\t\'Harrison\'\nNNPS\tproper noun, plural\t\'Americans\'\nPDT\tpredeterminer\t\'all the kids\'\nPOS\tpossessive ending\tparent\'s\nPRP\tpersonal pronoun\tI, he, she\nPRP$\tpossessive pronoun\tmy, his, hers\nRB\tadverb\tvery, silently,\nRBR\tadverb, comparative\tbetter\nRBS\tadverb, superlative\tbest\nRP\tparticle\tgive up\nTO\tto\tgo \'to\' the store.\nUH\tinterjection\terrrrrrrrm\nVB\tverb, base form\ttake\nVBD\tverb, past tense\ttook\nVBG\tverb, gerund/present participle\ttaking\nVBN\tverb, past participle\ttaken\nVBP\tverb, sing. present, non-3d\ttake\nVBZ\tverb, 3rd person sing. present\ttakes\nWDT\twh-determiner\twhich\nWP\twh-pronoun\twho, what\nWP$\tpossessive wh-pronoun\twhose\nWRB\twh-abverb\twhere, when\n'

# %%
#🐣The 'averaged_perceptron_tagger' is a trained model used by NLTK for POS tagging.
nltk.download('averaged_perceptron_tagger')
#The nltk.pos_tag function is used for part-of-speech tagging. It tags each word in a given list of words with its corresponding part of speech.
pos = nltk.pos_tag(words)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %% [markdown]
# ##💯 Before you proceed...
#
# 🐣The **nltk.download('maxent_ne_chunker')** command is used to download the _'maxent_ne_chunker' resource_ from the NLTK (Natural Language Toolkit) library.
#
# 🐣This resource is related to the **named entity chunker**.
# - <font color = 'red'> **Named Entity Recognition (NER)** </font> is a natural language processing task that involves identifying common entities such as persons, organizations, date, time, money, GPE(geo-political entity), and locations in text.

# %%
# Download the 'maxent_ne_chunker' resource
nltk.download('maxent_ne_chunker')

# Perform named entity chunking
NE = nltk.ne_chunk(pos)
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping chunkers/maxent_ne_chunker.zip.

# %% [markdown]
# # ☁️ ☁️ ☁️  **Wordcloud** ☁️ ☁️ ☁️

# %% [markdown]
# ### 1️⃣ 💊 <font color = 'red'> **Cautions:** The WordCloud object created using WordCloud() implicitly exclude stopwords by default. <font color = 'blue'> 아래 코드를 사용하면 기본으로 불용어가 제외되어 나옵니다.

# %%
# Install and import nltk for tokenizing words
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

# Import necessary libraries for generating word clouds where stop words are included by default.
from wordcloud import WordCloud
import matplotlib.pyplot as plt


# Download the Gutenberg corpus
nltk.download('gutenberg')

# Load the text of Alice's Adventures in Wonderland by Lewis Carroll in 1865
text = nltk.corpus.gutenberg.raw('carroll-alice.txt')

# Generate a Word Cloud from the text
wc = WordCloud().generate(text)

# Display the Word Cloud using Matplotlib
plt.imshow(wc)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %% [markdown]
# ### 2️⃣ 💊 <font color = 'red'> When you want to customize stop words, e.g., add some vocabulary to your graphic, you need to explicitly pass the WordCloud class which has a parameter called STOPWORDS where we can provide a set of stopwords and then write the following code lines.
#
#     > WordCloud(stopwords = stopwords).generate(text)
#     > stopwords.add('the')
#
# **설명:** wordcloud 라이브러리를 사용하여 워드클라우드를 만들 경우 불용어는 제외되어 그래픽이 형성된다. 반면, 불용어를 지정해 놓는 경우가 있다. 이 경우는 불용어를 열거해 놓은 세트를 명시하고,  불용어 중에서 분석에 추가해 넣고 싶은 특정 어휘를 추가할 때이다. 아래 코드셀은 i) 불용어 중에 'the'만 추가로 워드클라우드 그래픽 만들 때 추가하고, ii) 나머지 불용어는 제외한다는 것을 작성한 것이다.

# %%
# Install and import nltk for tokenizing words
# !pip install nltk
import nltk
from nltk.tokenize import word_tokenize

# This imports the WordCloud class and a parameter called STOPWORDS set from the wordcloud library.
from wordcloud import WordCloud, STOPWORDS

# Download the Gutenberg corpus
nltk.download('gutenberg')

# Load the text of Alice's Adventures in Wonderland by Lewis Carroll in 1865
text = nltk.corpus.gutenberg.raw('carroll-alice.txt')

# Create a set of stopwords
stopwords = set(STOPWORDS) #This creates This line creates a set of stop words by converting STOPWORDS (which is a frozenset) into a regular set.

# Generate Word Cloud which includes 'the' but excludes other stopwords
wc1 = WordCloud(stopwords = stopwords).generate(text) #This generates the word cloud from the provided text, explicitly excluding the words which are present in the stopwords set. This code is prerequsite for the following code line (stopwords.add('the'))
stopwords.add('the') #Among excluded stop words, include 'the' in the analysis.

# Display the Word Cloud using Matplotlib
plt.imshow(wc1)
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.9.11)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.5)
# [nltk_data] Downloading package gutenberg to /root/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %% [markdown]
# ### 💊 <font color = 'red'> **3️⃣ For your information:**
#
# In the following code cell, you can get a list of stopwords specified in the wordcloud library.

# %%
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)
sorted(stopwords)
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'all',
#  'also',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  "can't",
#  'cannot',
#  'com',
#  'could',
#  "couldn't",
#  'did',
#  "didn't",
#  'do',
#  'does',
#  "doesn't",
#  'doing',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'else',
#  'ever',
#  'few',
#  'for',
#  'from',
#  'further',
#  'get',
#  'had',
#  "hadn't",
#  'has',
#  "hasn't",
#  'have',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  "he's",
#  'hence',
#  'her',
#  'here',
#  "here's",
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  "how's",
#  'however',
#  'http',
#  'i',
#  "i'd",
#  "i'll",
#  "i'm",
#  "i've",
#  'if',
#  'in',
#  'into',
#  'is',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'k',
#  "let's",
#  'like',
#  'me',
#  'more',
#  'most',
#  "mustn't",
#  'my',
#  'myself',
#  'no',
#  'nor',
#  'not',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'otherwise',
#  'ought',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  'r',
#  'same',
#  'shall',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  "shouldn't",
#  'since',
#  'so',
#  'some',
#  'such',
#  'than',
#  'that',
#  "that's",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  "there's",
#  'therefore',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  'very',
#  'was',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  "we've",
#  'were',
#  "weren't",
#  'what',
#  "what's",
#  'when',
#  "when's",
#  'where',
#  "where's",
#  'which',
#  'while',
#  'who',
#  "who's",
#  'whom',
#  'why',
#  "why's",
#  'with',
#  "won't",
#  'would',
#  "wouldn't",
#  'www',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves']
