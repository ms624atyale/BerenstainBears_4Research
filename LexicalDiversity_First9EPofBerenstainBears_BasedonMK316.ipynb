# %% [markdown]
# <a href="https://colab.research.google.com/github/ms624atyale/BerenstainBears_4Research/blob/main/LexicalDiversity_First9EPofBerenstainBears_BasedonMK316.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color = 'red'> **Notes**
#
# ## - Final Script for first <font color = 'blue'> 9 copies of **Berenstain Bears**.
# ## - <font color = 'blue'> This Script modified on _October 11, 2024_

# %%
! git clone https://github.com/ms624atyale/BerenstainBears_4Research #copy & paste the url of a repository of your concern

# %% [markdown]
# ### <font color = 'pink'> 🔋 🔌 **Now** move "PG Aesop NoQuotes' file under [PG Aesop NoQuotes folder] **to** [the sample_data folder]!

# %% [markdown]
# ###**<font color = 'red'>Gneral Information**
# Function.	Type	symbols or words	result	example
# RegexpTokenizer()	punctuation	".", ",", "?", "!", ";", ":"	deleted
# apostrophe	"'"	deleted
# word-linking hyphen	"-"	deleted
# phrase-linking hyphen	"--"	deleted
# Capital vs. small	The ones	tokenize	'The', 'ones'
# they're, were having		'they', 're', 'were', 'hav'

# %% [markdown]
# 💡 🔎 **RegexpTokenizer** is a <font color = 'red'>_class_</font>.
# - An example code line:
#   - **from nltk.tokenize import RegexpTokenizer**
#
# - It is part of the nltk.tokenize module and is used for tokenizing text based on regular expression patterns. When you import RegexpTokenizer using this line, you make the RegexpTokenizer class available for use in your Python script or program. You can create instances of this class to tokenize text based on specific regular expression patterns.

# %% [markdown]
# 💣 <font color = 'red'>I need to understand ChatGPT's explanation in the following:
#
# In regular expressions, square brackets [ ] are used to create character classes, which define a set of characters that you want to match. The usage of square brackets depends on the context and what you want to achieve in your regular expression.
#
# In the two code lines you provided:
#
# (1) retokenize = RegexpTokenizer("[\w]+")
#
# Here, you are using square brackets to create a character class that matches one or more word characters (\w). In this case, you are explicitly defining a character class within the regular expression.
#
# (2) pattern = r'\w+'; retokenize = RegexpTokenizer(pattern)
#
# In the second code line, you define the regular expression pattern separately as r'\w+', and then you pass this pattern as a string to the RegexpTokenizer constructor. The RegexpTokenizer class is designed to accept a string pattern as an argument, so you don't need to use square brackets in this specific line because the pattern is already defined as a string.
#
# In both cases, you achieve the same result: tokenizing text based on one or more word characters. The difference is in how you specify the pattern. In the first case, you define the pattern within the constructor and use square brackets to create a character class. In the second case, you define the pattern as a string separately and then pass it to the constructor. The second approach is often preferred when you want to reuse the pattern or make the code more readable.

# %% [markdown]
# Consider including eliminating stopwords if you can come up with something decent cause.
# - shortword = re.compile(r'\W*\b\w{1,3}\b') #Remove words less than 3 letters.

# %% [markdown]
# 🔌 After getting reviewers' comments on sttr.

# %% [markdown]
# 🔌 [chatGPT) I apologize for the confusion. It seems there is an issue with the textstat library, and it doesn't provide the STTR attribute. To calculate the standardized type-token ratio (STTR), you can use a different approach without relying on the textstat library.
#
# Here's an alternative method to calculate the STTR:

# %% [markdown]
# 🔌 The below is the original script for ttr used in the 1st draft of the paper. Then split it into 7 arbitrary parts.

# %% [markdown]
# #**<font color = 'red'>First 10 Epdisodes of Berenstain Bears**

# %% [markdown]
# BB_NewBaby_1

# %%
file = open("/content/Ref_Scripts4Research/BerenstainBears/BB_NewBaby_1.csv", 'rt')

obj = file.read().replace("\n"," ")
obj.split
'good', 'habits', 'then', 'she', 'thought', 'of', 'a', 'plan', 'she', 'got', 'a', 'big', 'piece', 'of', 'cardboard', 'and', 'a', 'marker', 'at', 'the', 'top', 'she', 'wrote', 'the', 'bear', 'family', 'politeness', 'plan', 'when', 'the', 'plan', 'was', 'finished', 'she', 'called', 'a', 'family', 'meeting', 'and', 'showed', 'it', 'to', 'papa', 'and', 'the', 'cubs', 'the', 'bear', 'family', 'politeness', 'plan', 'rudeness', 'forgetting', '“please”', 'or', '“thank', 'you”', 'pushing', 'or', 'shoving', 'interrupting', 'name', 'calling', 'reaching', 'at', 'table', 'playing', 'with', 'food', 'ude', 'noises', 'banging', 'door', 'forgetting', '“excuse', 'me”', 'hogging', 'bathroom', 'penalty', 'sweep', 'front', 'steps', 'beat', '2', 'rugs', 'dust', 'downstairs', 'clean', 'cellar', 'clean', 'yard', 'wash', 'dishes', 'weed', 'garden', 'clean', 'attic', 'empty', 'gargage', 'put', 'out', 'trash', 'it', 'certainly', 'got', 'the', 'bear', 'family’s', 'attention', 'mama’s', 'plan', 'had', 'a', 'list', 'of', 'all', 'the', 'rude', 'things', 'she', 'wanted', 'to', 'stop', 'beside', 'each', 'one', 'was', 'a', 'penalty–a', 'job', 'or', 'chore', 'that', 'went', 'with', 'it', 'if', 'you', 'forgot', 'a', '“please”', 'or', 'a', '“thank', 'you”', 'you', 'had', 'to', 'sweep', 'the', 'front', 'steps', 'if', 'you', 'pushed', 'or', 'shoved', 'you', 'had', 'to', 'beat', 'two', 'rugs', 'if', 'you', 'got', 'caught', 'name', 'calling', 'you', 'had', 'to', 'clean', 'the', 'whole', 'cellar', '“but', 'mama”', 'sputtered', 'the', 'cubs', '“you’re', 'not', 'being', 'fair”', '“it', 'seems', 'to', 'me”', 'she', 'said', '“that', 'you’re', 'the', 'ones', 'who', 'aren’t', 'being', 'fair–to', 'yourselves', 'or', 'anyone', 'else', 'that’s', 'what', 'manners', 'are', 'all', 'about–being', 'fair', 'and', 'considerate', 'manners', 'are', 'very', 'important', 'they', 'help', 'us', 'get', 'along', 'with', 'each', 'other', 'why', 'without', 'manners–“', '“your', 'mama’s', 'absolutely', 'right”', 'interrupted', 'papa', '“thank', 'you', 'papa', 'for', 'your', 'comment', 'but', 'interrupting', 'is', 'number', 'three', 'on', 'rude', 'list', 'and', 'the', 'penalty', 'is', 'dusting', 'the', 'downstairs”', 'mama', 'said', 'and', 'handed', 'him', 'the', 'feather', ...
# 0.3730232558139535
# STTR (Standardized Type-Token Ratio): 0.7185256222066418

# %% [markdown]
# BB_GetaStageFright_10

# %%
# Word Count, TTR, STTR for Part1 of Aesop for Children

file = open("/content/Ref_Scripts4Research/BerenstainBears/BB_GetaStageFright_10.csv", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/Ref_Scripts4Research/BerenstainBears/BB_GetaStageFright_10.csv", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld

with open("/content/Ref_Scripts4Research/BerenstainBears/BB_GetaStageFright_10.csv", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

#STTR
from collections import Counter
import math

# Load your text data
with open("/content/Ref_Scripts4Research/BerenstainBears/BB_GetaStageFright_10.csv", "r") as file:  # Replace with the path to your text file
    text = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or a custom tokenizer)
words = text.split()  # Simple word splitting for this example

# Calculate the number of unique tokens and total tokens
word_counts = Counter(words)
num_unique_tokens = len(word_counts)
total_tokens = len(words)

# Calculate STTR
sttr = num_unique_tokens / total_tokens

# Apply square root to STTR for standardization
sttr_standardized = math.sqrt(sttr)

# Print both STTR values
print("STTR (Standardized Type-Token Ratio):", sttr_standardized)
# Out:
# count word tokens: 1406
# Tokenizing Words with RegexpTokenizer: ['On', 'the', 'way', 'to', 'school', 'one', 'day', 'Sister', 'Bear', 'Brother', 'Bear', 'and', 'Cousin', 'Freddie', 'got', 'to', 'talking', 'about', 'an', 'important', 'subject', 'their', 'teachers', 'Teacher', 'Bob', 'is', 'tough', 'but', 'fair', 'said', 'Freddie', 'who', 'was', 'in', 'the', 'same', 'class', 'as', 'Brother', 'Brother', 'agreed', 'How', 'about', 'your', 'teacher', 'he', 'asked', 'Sister', 'Is', 'she', 'easy', 'or', 'hard', 'Teacher', 'Jane', 'isn', 't', 'easy', 'or', 'hard', 'Sister', 'Said', 'She', 's', 'good', 'Then', 'the', 'bell', 'rang', 'and', 'the', 'cubs', 'were', 'ready', 'for', 'the', 'school', 'day', 'The', 'reason', 'Sister', 'thought', 'Teacher', 'Jane', 'was', 'good', 'was', 'that', 'she', 'made', 'things', 'interesting', 'When', 'they', 'were', 'learning', 'to', 'add', 'and', 'subtract', 'Teacher', 'jane', 'set', 'up', 'a', 'pretend', 'store', 'with', 'play', 'money', 'and', 'a', 'toy', 'cash', 'register', 'It', 'helped', 'the', 'cubs', 'learns', 'and', 'it', 'was', 'fun', 'When', 'the', 'class', 'was', 'studying', 'words', 'and', 'ideas', 'they', 'made', 'posters', 'That', 'helped', 'them', 'learn', 'too', 'And', 'sometimes', 'in', 'reading', 'class', 'instead', 'of', 'just', 'reading', 'from', 'their', 'books', 'they', 'acted', 'out', 'the', 'stories', 'That', 's', 'what', 'they', 'were', 'doing', 'with', 'Grizzlystiltskin', 'the', 'story', 'of', 'the', 'funny', 'old', 'elf', 'bear', 'who', 'was', 'sure', 'that', 'nobody', 'could', 'ever', 'guess', 'his', 'name', 'Sister', 'Bear', 'was', 'acting', 'out', 'the', 'part', 'of', 'the', 'miller', 's', 'daughter', 'who', 'becomes', 'a', 'princess', 'and', 'has', 'to', 'spin', 'straw', 'into', 'gold', 'They', 'had', 'come', 'to', 'the', 'part', 'where', 'the', 'princess', 'has', 'one', 'last', 'change', 'to', 'guess', 'the', 'elf', 'bear', 's', 'name', 'Ah', 'good', 'sir', 'read', 'Sister', 'in', 'a', 'loud', 'clear', 'voice', 'We', 've', 'come', 'to', 'the', 'end', 'of', 'our', 'guessing', 'game', 'because', 'I', 'say', 'Grizzlystiltskin', 'is', 'your', 'name', 'That', 's', 'when', 'Grizzlystiltskin', 'flies', 'into', 'a', 'range', 'and', 'disappears', 'in', 'a', 'puff', 'of', 'smoke', 'and', 'the', 'princess', 'lives', 'happily', 'ever', 'after', 'That', 'was', 'very', 'good', 'class', 'said', 'Teacher', 'Jane', 'So', 'good', 'in', 'fact', 'that', 'I', 'have', 'a', 'surprise', 'for', 'you', 'I', 'm', 'in', 'charge', 'of', 'the', 'school', 'play', 'this', 'year', '
file = open("/content/Ref_Scripts4Research/BerenstainBears/BB_ForgettheManners_9.csv", 'rt')

obj = file.read().replace("\n"," ")
obj.split()

file = open("/content/Ref_Scripts4Research/BerenstainBears/BB_ForgettheManners_9.csv", 'rt') #reading using the 'rt'

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('count word tokens:', count)

print('Tokenizing Words with RegexpTokenizer: %s' %result); import re


import pandas as pd
import textstat

# Define the URL for the text data
url = 'https://github.com/ms624atyale/Data_Class/raw/main/PG%20Aesop%20Lexical%20Diversity/txtdata_only_lexicaldiversity.txt'

# Read the text data from the URL
df = pd.read_csv(url, header=None, names=['Text'], sep='\n')

# Extract the text from the DataFrame
text_data = df['Text'].str.cat(sep=' ')

# Tokenize the text into words (you can use NLTK, spaCy, or other tokenizers)
words = text_data.split()

# Define the window size for MSTTR
window_size = 500

# Calculate MSTTR using the textstat library
msttr_values = textstat.msttr(words, window_size)

# Print the MSTTR values
print("MSTTR (Moving Standardized Type-Token Ratio) values:")
print(msttr_values)

# %%
import pandas as pd
import textstat

with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the content and TTR
tok = ld.tokenize(file_content)
print(tok)
flt = ld.flemmatize(file_content); print(ld.ttr(flt))

# Read the text content from the file
with open("/content/sample_data/txtdata_only_lexicaldiversity.txt", 'rt') as file:
    file_content = file.read()

# Tokenize the text into words (you can use NLTK, spaCy, or other tokenizers)
words = file_content.split()

# Define the window size for MSTTR
window_size = 500

# Calculate MSTTR using the textstat library
msttr_values = textstat.msttr(words, window_size)

# Print the MSTTR values
print("MSTTR (Moving Standardized Type-Token Ratio) values:")
print(msttr_values)
# Out:
# ['the', 'wolf', 'and', 'the', 'kid', 'there', 'was', 'once', 'a', 'little', 'kid', 'whose', 'growing', 'horns', 'made', 'him', 'think', 'he', 'was', 'a', 'grownup', 'billy', 'goat', 'and', 'able', 'to', 'take', 'care', 'of', 'himself', 'so', 'one', 'evening', 'when', 'the', 'flock', 'started', 'home', 'from', 'the', 'pasture', 'and', 'his', 'mother', 'called', 'the', 'kid', 'paid', 'no', 'heed', 'and', 'kept', 'right', 'on', 'nibbling', 'the', 'tender', 'grass', 'a', 'little', 'later', 'when', 'he', 'lifted', 'his', 'head', 'the', 'flock', 'was', 'gone', 'he', 'was', 'all', 'alone', 'the', 'sun', 'was', 'sinking', 'long', 'shadows', 'came', 'creeping', 'over', 'the', 'ground', 'a', 'chilly', 'little', 'wind', 'came', 'creeping', 'with', 'them', 'making', 'scary', 'noises', 'in', 'the', 'grass', 'the', 'kid', 'shivered', 'as', 'he', 'thought', 'of', 'the', 'terrible', 'wolf', 'then', 'he', 'started', 'wildly', 'over', 'the', 'field', 'bleating', 'for', 'his', 'mother', 'but', 'not', 'halfway', 'near', 'a', 'clump', 'of', 'trees', 'there', 'was
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-98-ff3918362b8b> in <cell line: 23>()
#      21
#      22 # Calculate MSTTR using the textstat library
# ---> 23 msttr_values = textstat.msttr(words, window_size)
#      24
#      25 # Print the MSTTR values
#
# AttributeError: module 'textstat' has no attribute 'msttr'

# %% [markdown]
# ### <font color = 'red'> **1. Adopting MK316's script (as of 05NOV23) for Aesop Fables**
# ### <font color = 'brown'> **2. Adopting MK316's script (as of 11OCT24) for Berenstain Bears (first 9 copes)**

# %%
import pandas as pd

url = 'https://raw.githubusercontent.com/ms624atyale/BerenstainBears_4Research/refs/heads/main/BerenstainBears/BerenstainBears_First9Copies_BodyTitleYear.csv'

df1 = pd.read_csv(url, sep=',') #separator 표시. other examples are sep='\t', etc.
df1
# Out:
#                                                 text                  title  \
# 0  Down a sunny dirt road, over a log bridge, up ...               NEW BABY
# 1  The Bear family didn’t always live in the big ...            MOVING DAY
# 2  “Brother Bear,” said Sister impatiently, “are ...           IN THE Dark
# 3  Most morning, in Bear Country, the sun rose to...         GET in a FIGHT
# 4  It was the last day of school and the beginnin...             GO TO CAMP
# 5  It was a lazy sort of day in Bear Country. The...              THE TRUTH
# 6  The Bear family, who lived in the big tree hou...        MAMA’s NEW JOB
# 7  Brother and Sister Bear, who lived with their ...  LEARN ABOUT STRANGERS
# 8  There was trouble in the big tree house down a...   FORGET THEIR MANNERS
#
#    year_published  episode  grouping
# 0            1974        1         1
# 1            1981        2         1
# 2            1982        3         1
# 3            1982        4         1
# 4            1982        5         1
# 5            1983        6         2
# 6            1984        7         2
# 7            1985        8         2
# 8            1985        9         2

# %% [markdown]
# ### **[🍭 Annotation] ⏫**
# **🍭 Do NOT use the direct directory of csv from github.com** ⤵️
#
#     url = 'https://github.com/ms624atyale/BerenstainBears_4Research/blob/main/BerenstainBears/BerenstainBears_First9Copies_BodyTitleYear.csv'

# %% [markdown]
# ###Adding a colum with length info
# - Data: df2 = df1

# %%
df2 = df1

# %%
# !pip install textstat
import textstat
df2['N_Sents'] = df2['text'].apply(textstat.sentence_count)
# Out:
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from textstat) (71.0.4)

# %%
# Added column:  Splitted words, Length of splitted words
tsplit = []
splen = []

for i in range(0, len(df2['text'])):
  TSP = df2['text'][i].split()
  SPLEN = len(TSP)
  tsplit.append(TSP)
  splen.append(SPLEN)
  print(TSP)

print('\n')
df2['Splits'] = tsplit
df2['N_Words'] = splen
print(df2)

print('\n')
df2
# Out:
# ['Down', 'a', 'sunny', 'dirt', 'road,', 'over', 'a', 'log', 'bridge,', 'up', 'a', 'grassy', 'hill,', 'deep', 'in', 'Bear', 'Country,', 'lived', 'a', 'family', 'of', 'bears—Papa', 'Bear,', 'Mama', 'Bear', 'and', 'Small', 'Bear.', 'They', 'lived', 'in', 'a', 'large', 'tree', 'which', 'Papa', 'Bear', 'had', 'hollowed', 'out', 'and', 'made', 'into', 'a', 'house.', 'It', 'was', 'a', 'very', 'fine', 'house.', 'This', 'is', 'what', 'it', 'looked', 'like', 'inside.', 'It', 'was', 'fun', 'growing', 'up', 'in', 'Bear', 'Country...helping', 'Papa', 'get', 'honey', 'from', 'the', 'old', 'bee', 'tree...helping', 'Mama', 'bring', 'the', 'vegetables', 'in', 'from', 'the', 'garden.', 'There', 'were', 'all', 'sorts', 'of', 'interesting', 'things', 'for', 'a', 'small', 'bear', 'to', 'do', 'and', 'see', 'in', 'Bear-Country.', 'Small', 'B
 'mail.', 'This', 'is', 'what', 'it', 'looked', 'like:', 'TIRED', 'OF', 'SITTING', 'AROUND', 'DOING', 'NOTHING?', 'COME', 'TO', 'GRIZZLY', 'BOB”S', 'DAY', 'CAMP', 'SUMMER', 'FUN', 'FOR', 'CUBS', 'OF', 'ALL', 'AGES', 'SIMMING', 'CANOEING', 'ARTS', '&', 'CRAFTS', 'SPORTS', '&', 'GAMES', 'NATURE', 'STUDY', 'FULLY', 'SUPERVISED', 'BOB', 'AND', 'DON’T', 'FORGET', 'OUR', 'EXCITING', 'OVERNIGHT', 'CAMPFIRE', 'POWWOW', 'AND', 'SLEEP-OUT.', 'Some', 'of', 'the', 'things', 'looked', 'interesting.', 'But', 'Brother', 'wondered', 'what', '“fully', 'supervised”', 'meant.', 'And', 'Sister', 'wasn’t', 'so', 'sure', 'about', 'that', '“overnight', 'sleep-out.”', 'It', 'sounded', 'a', 'little', 'scary.', '“Where', 'is', 'this', 'camp?”', 'asked', 'Sister.', '“Not', 'far,”', 'answered', 'Mama.', '“How', 'will', 'we', 'get', 'there?”', 'Brother', 'wanted', 'to', 'know.', '“A', 'bus', 'comes', 'for', 'you', 'in', 'the', 'morning', 'and', 'brings', 'you', 'home', 'in', 'the', 'afternoon.”', '“Sounds', 'a', 'little', 'like', 'school,”', 'said', 'Brother.', '“We’ll', 'think', 'about', 'it,”', 'said', 'the', 'cubs,', 'and', 'went', 'back', 'to', 'doing', 'nothing—well,', 'not', 'exactly', 'nothing...They', 'picked', 'a', 'few', 'wildflowers,', 'chased', 'a', 'few', 'butterflies,', 'turned', 'over', 'a', 'few', 'rocks...', '—and', 'thought', 'about', 'it.', '“Mama,', 'could', 'we', 'try', 'Grizzly', 'Bob’s', 'Day', 'Camp', 'just', 'to', 'see', 'if', 'we', 'like', 'it?”', 'they', 'asked.', '“Of', 'course,”', 'said', 'Mama.', 'A', 'couple', 'of', 'mornings', 'later,', 'Brother', 'and', 'Sister', 'were', 'in', 'camp', 'shorts', 'and', 'T-shirts,', 'all', 'ready', 'and', 'waiting', 'when', 'the', 'bus', 'came.', 'It', 'didn’t', 'look', 'much', 'like', 'the', 'school', 'bus.', 'And', 'Grizzly', 'Bob', 'didn’t', 'look', 'much', 'like', 'Teacher', 'Jane.', 'And', 'the', 'camp', 'didn’t', 'look', 'anything', 'like', 'school!', 'Grizzly', 'Bob', 'had', 'built', 'his', 'camp', 'beside', 'a', 'lake', 'at', 'the', 'edge', 'of', 'the', 'forest.', 'There', 'were', 'log', 'buildings,', 'a', 'flagpole', 'flying', 'the', 'camp', 'flag,', 'a', 'big', 'bulletin', 'board', 'with', 'the', 'camp', 'rules—there', 'certainly', 'were', 'a', 'lot', 'of', 'rules—some', 'interesting', 'paths,', 'a', 'roped-in', 'place', 'to', 'swim...', 'There', 'was', 'even', 'a', 'big', 'red', 'canoe!', 'Bod', 'had', 'made', 'name', 'tags', 'for', 'the', 'cubs.', '“You’re', 'campmates', 'now,', 'so', 'you', 'better', 'get', 'to', 'know',
', 'a', 'brother.', 'Those', 'are', 'for', 'a', 'mama', 'or', 'papa...”', '“Sister', 'Bear,', 'I’m', 'glad', 'you', 'asked', 'those', 'questions!”', 'said', 'Papa', 'Bear,', 'in', 'his', 'deepest', 'and', 'most', 'serious', 'voice.', '“The', 'reason', 'you', 'should', 'never', 'talk', 'to', 'a', 'stranger', 'and', 'never', 'ever', 'take', 'presents', 'from', 'a', 'stranger', 'and', 'never', 'ever', 'ever', 'go', 'anywhere', 'with', 'a', 'stranger', 'is', 'that', 'it’s', 'dangerous.”', '“What’s', 'dangerous', 'about', 'it?”', 'she', 'asked,', 'wide-eyed.', '“What', 'can', 'happen?”', '“Oh,', 'dear,”', 'thought', 'Mama', 'Bear.', '“I', 'do', 'hope', 'Papa', 'can', 'tell', 'Sister', 'about', 'strangers', 'without', 'making', 'everything', 'scary.”', '“All', 'sorts', 'of', 'thinks!”', 'Papa', 'said.', '“Here!', 'Look', 'at', 'the', 'newspaper!”', 'As', 'she', 'looked', 'at', 'it', 'her', 'eyes', 'got', 'wider', 'and', 'wider.', 'This', 'is', 'what', 'she', 'saw...', '“I', 'hope', 'you’re', 'paying', 'attention', 'to', 'all', 'this,”', 'called', 'Papa', 'to', 'Brother', 'Bear.', '“Yes,', 'Papa,”', 'said', 'Brother', 'looking', 'up', 'from', 'his', 'airplanes.', 'When', 'Sister', 'asked', 'for', 'a', 'bedtime', 'story', 'that', 'evening,', 'Papa', 'said,', '“Of', 'course!', 'I', 'have', 'just', 'the', 'one!”', 'It', 'was', 'in', 'an', 'old', 'book', 'that', 'Papa', 'had', 'kept', 'since', 'he', 'was', 'a', 'cub.', 'The', 'story', 'was', 'called', '“Silly', 'Goose', 'and', 'Wily', 'Fox.”', 'It', 'told', 'how', 'Silly', 'Goose', 'got', 'into', 'a', 'conversation', 'with', 'Wily', 'Fox,', 'and', 'before', 'Silly', 'knew', 'quite', 'what', 'was', 'happening', 'she', 'found', 'herself', 'in', 'Wily’s', 'lair.', 'This', 'is', 'h ...
# ['There', 'was', 'trouble', 'in', 'the', 'big', 'tree', 'house', 'down', 'a', 'sunny', 'dirt', 'road', 'deep', 'in', 'Bear', 'Country—trouble', 'with', 'manners.', 'The', 'Bear', 'family’s', 'trouble', 'with', 'manners', 'was', 'that', 'they', 'forgot', 'them!', 'At', 'first', 'it', 'was', 'just', 'an', 'occasional', '“please”', 'or', '“thank', 'you”', 'that', 'was', 'forgotten.', 'Then', 'there', 'was', 'a', 'rude', 'push', 'without', 'an', '“excuse', 'me.”', 'Then', 'a', 'reach', 'across', 'the', 'table', 'instead', 'of', 'a', '“please', 'pass', 'the', 'broccoli.”', 'Mama', 'Bear', 'wasn’t', 'quite', 'sure', 'how', 'or', 'why', 'it', 'happened.', 'But', 'she', 'was', 'sure', 'of', 'one', 'thing—whatever', 'the', 'reason,', 'the', 'Bear', 'family', 'had', 'become', 'a', 'pushing,', 'shoving,', 'name-calling,', 'ill-mannered', 'mess!', 'At', 'the', 'table', 'it', 'was', 'even
.', '“Hmm,”', 'said', 'Brother.', '“This', 'looks', 'serious.', 'I', 'think', 'we’d', 'better', 'come', 'up', 'with', 'a', 'plan', 'of', 'our', 'own', 'or', 'we’re', 'going', 'to', 'be', 'doing', 'a', 'lot', 'of', 'extra', 'chores.”', '“What', 'sort', 'of', 'plan?”', 'asked', 'Sister.', '“Well,”', 'he', 'said,', '“instead', 'of', 'just', 'being', 'polite,', 'we’ll', 'be', 'super', 'polite.', 'We’ll', '‘please’', 'and', '‘thank', 'you’', 'so', 'much', 't ...
#
#
#                                                 text                  title  \
# 0  Down a sunny dirt road, over a log bridge, up ...               NEW BABY
# 1  The Bear family didn’t always live in the big ...            MOVING DAY
# 2  “Brother Bear,” said Sister impatiently, “are ...           IN THE Dark
# 3  Most morning, in Bear Country, the sun rose to...         GET in a FIGHT
# 4  It was the last day of school and the beginnin...             GO TO CAMP
# 5  It was a lazy sort of day in Bear Country. The...              THE TRUTH
# 6  The Bear family, who lived in the big tree hou...        MAMA’s NEW JOB
# 7  Brother and Sister Bear, who lived with their ...  LEARN ABOUT STRANGERS
# 8  There was trouble in the big tree house down a...   FORGET THEIR MANNERS
#
#    year_published  episode  grouping  N_Sents  \
# 0            1974        1         1       55
# 1            1981        2         1       74
# 2            1982        3         1       94
# 3            1982        4         1       67
# 4            1982        5         1       82
# 5            1983        6         2       92
# 6            1984        7         2      104
# 7            1985        8         2      137
# 8            1985        9         2       92
#
#                                               Splits  N_Words
# 0  [Down, a, sunny, dirt, road,, over, a, log, br...      608
# 1  [The, Bear, family, didn’t, always, live, in, ...      875
# 2  [“Brother, Bear,”, said, Sister, impatiently,,...     1129
# 3  [Most, morning,, in, Bear, Country,, the, sun,...      771
# 4  [It, was, the, last, day, of, school, and, the...      988
# 5  [It, was, a, lazy, sort, of, day, in, Bear, Co...     1065
# 6  [The, Bear, family,, who, lived, in, the, big,...     1118
# 7  [Brother, and, Sister, Bear,, who, lived, with...     1443
# 8  [There, was, trouble, in, the, big, tree, hous...     1019
#                                                 text                  title  \
# 0  Down a sunny dirt road, over a log bridge, up ...               NEW BABY
# 1  The Bear family didn’t always live in the big ...            MOVING DAY
# 2  “Brother Bear,” said Sister impatiently, “are ...           IN THE Dark
# 3  Most morning, in Bear Country, the sun rose to...         GET in a FIGHT
# 4  It was the last day of school and the beginnin...             GO TO CAMP
# 5  It was a lazy sort of day in Bear Country. The...              THE TRUTH
# 6  The Bear family, who lived in the big tree hou...        MAMA’s NEW JOB
# 7  Brother and Sister Bear, who lived with their ...  LEARN ABOUT STRANGERS
# 8  There was trouble in the big tree house down a...   FORGET THEIR MANNERS
#
#    year_published  episode  grouping  N_Sents  \
# 0            1974        1         1       55
# 1            1981        2         1       74
# 2            1982        3         1       94
# 3            1982        4         1       67
# 4            1982        5         1       82
# 5            1983        6         2       92
# 6            1984        7         2      104
# 7            1985        8         2      137
# 8            1985        9         2       92
#
#                                               Splits  N_Words
# 0  [Down, a, sunny, dirt, road,, over, a, log, br...      608
# 1  [The, Bear, family, didn’t, always, live, in, ...      875
# 2  [“Brother, Bear,”, said, Sister, impatiently,,...     1129
# 3  [Most, morning,, in, Bear, Country,, the, sun,...      771
# 4  [It, was, the, last, day, of, school, and, the...      988
# 5  [It, was, a, lazy, sort, of, day, in, Bear, Co...     1065
# 6  [The, Bear, family,, who, lived, in, the, big,...     1118
# 7  [Brother, and, Sister, Bear,, who, lived, with...     1443
# 8  [There, was, trouble, in, the, big, tree, hous...     1019

# %%
#@markdown Counting syllables of words, using regular expression

#@markdown {re} count syllables: count_syllables(word)

import re

def count_syllables(word):
    return len(
        re.findall('(?!e$)[aeiouy]+', word, re.I) +
        re.findall('^[^aeiouy]*e$', word, re.I)
    )

# %%
# Example by using the function created
count_syllables("Berenstain")
# Out:
# 3

# %%
# Sample test for the Berenstain Bears "The New Baby"
obj="""
Down a sunny dirt road, over a log bridge, up a grassy hill, deep in Bear Country, lived a family of bears—Papa Bear, Mama Bear and Small Bear. They lived in a large tree which Papa Bear had hollowed out and made into a house. It was a very fine house. This is what it looked like inside. It was fun growing up in Bear Country...helping Papa get honey from the old bee tree...helping Mama bring the vegetables in from the garden. There were all sorts of interesting things for a small bear to do and see in Bear-Country. Small Bear felt good growing up in a tree...in his own room...in the snug little bed that Papa Bear had made for him when he was a baby. But one morning, it did not feel so good. Small Bear woke up with pains in his knees and aches in his legs. “Small Bear, you have outgrown your little bed,” said Papa Bear, as he hitched up his overalls and buttoned his shoulder straps. “Today, we shall go out into the woods and make you a bigger one!” With that, he ate his breakfast of piping-hot porridge...washed it down with a gulp of honey from the family pot...took up his ax and was out the door. “But, Papa,” called Small Bear, following after him. “What will happen to my little bed?” “Don’t worry about that, Small Bear,” said Mama Bear as she closed the door after him. She smiled and patted her front, which had lately grown very big and round. “You’ve outgrown that snug little bed just in time!” He tested the ax to see if it was sharp, then headed off into the woods. “What will happen to my little bed?” Small Bear asked again as he caught up with Papa Bear in the woods. Papa had chopped down a tree and was splitting it into boards. “We will have a new baby soon who will need that little bed,” said papa Bear as he whacked off another board. “A ne baby?” asked Small Bear. (He hadn’t noticed that Mama Bear had grown very round lately, although he had noticed it was harder and harder to sit on her lap.) “And it’s coming soon?” “Yes, very soon!” said Papa Bear. With a final whack he split off the last board, which gave him enough wood to make a bigger bed for Small Bear. They made the bed a good size and took the rest of the day to chip and shave it smooth and neat. Then they carried it back to the tree and up to Small Bear’s room. When they got there, Small Bear noticed right away that his old bed wasn’t there any more. “My little bed!” said Small Bear. “It’s already gone!” “You outgrew it just in time,” called Mama Bear from the next room. “Come and see.” It was true! There was his snug little bed with a new little baby in it. Small Bear had outgrown his snug little bed just in time for his new baby sister. And now he was a big brother! She was very little but very lively. As Small Bear learned over for a closer look, she popped him on the nose with a tiny fist. “Hmm,” said Small Bear. “She has a pretty good punch for a little baby.” That night he stretched out proudly in his bigger bed. “Aah!” he said. “Being a big brother is going to be fun.” The next morning he woke up feeling fine, with no pains in his knees or aches in his legs. His nose was a little tender, though.
"""

from nltk.tokenize import RegexpTokenizer

retokenize = RegexpTokenizer("[\w]+")

result = retokenize.tokenize(obj)
count = len(result)
print('Count word tokens:', count)

#The way to calculate words are different from Lexical Diversity in this script using TextStat Library.
# Out:
# Count word tokens: 624

# %%
#@markdown Adding a column: String length (i.e., text data size)
length = []

for i in range(0, len(df2['text'])):
  LEN = len(df2['text'][i])
  length.append(LEN)
df2['Data_Size'] = length
df2
# Out:
#                                                 text                  title  \
# 0  Down a sunny dirt road, over a log bridge, up ...               NEW BABY
# 1  The Bear family didn’t always live in the big ...            MOVING DAY
# 2  “Brother Bear,” said Sister impatiently, “are ...           IN THE Dark
# 3  Most morning, in Bear Country, the sun rose to...         GET in a FIGHT
# 4  It was the last day of school and the beginnin...             GO TO CAMP
# 5  It was a lazy sort of day in Bear Country. The...              THE TRUTH
# 6  The Bear family, who lived in the big tree hou...        MAMA’s NEW JOB
# 7  Brother and Sister Bear, who lived with their ...  LEARN ABOUT STRANGERS
# 8  There was trouble in the big tree house down a...   FORGET THEIR MANNERS
#
#    year_published  episode  grouping  N_Sents  \
# 0            1974        1         1       55
# 1            1981        2         1       74
# 2            1982        3         1       94
# 3            1982        4         1       67
# 4            1982        5         1       82
# 5            1983        6         2       92
# 6            1984        7         2      104
# 7            1985        8         2      137
# 8            1985        9         2       92
#
#                                               Splits  N_Words  Data_Size
# 0  [Down, a, sunny, dirt, road,, over, a, log, br...      608       3125
# 1  [The, Bear, family, didn’t, always, live, in, ...      875       4801
# 2  [“Brother, Bear,”, said, Sister, impatiently,,...     1129       6285
# 3  [Most, morning,, in, Bear, Country,, the, sun,...      771       4354
# 4  [It, was, the, last, day, of, school, and, the...      988       5498
# 5  [It, was, a, lazy, sort, of, day, in, Bear, Co...     1065       5798
# 6  [The, Bear, family,, who, lived, in, the, big,...     1118       6151
# 7  [Brother, and, Sister, Bear,, who, lived, with...     1443       8163
# 8  [There, was, trouble, in, the, big, tree, hous...     1019       5670

# %%
print(df2)
# Out:
#                                                 text                  title  \
# 0  Down a sunny dirt road, over a log bridge, up ...               NEW BABY
# 1  The Bear family didn’t always live in the big ...            MOVING DAY
# 2  “Brother Bear,” said Sister impatiently, “are ...           IN THE Dark
# 3  Most morning, in Bear Country, the sun rose to...         GET in a FIGHT
# 4  It was the last day of school and the beginnin...             GO TO CAMP
# 5  It was a lazy sort of day in Bear Country. The...              THE TRUTH
# 6  The Bear family, who lived in the big tree hou...        MAMA’s NEW JOB
# 7  Brother and Sister Bear, who lived with their ...  LEARN ABOUT STRANGERS
# 8  There was trouble in the big tree house down a...   FORGET THEIR MANNERS
#
#    year_published  episode  grouping  N_Sents  \
# 0            1974        1         1       55
# 1            1981        2         1       74
# 2            1982        3         1       94
# 3            1982        4         1       67
# 4            1982        5         1       82
# 5            1983        6         2       92
# 6            1984        7         2      104
# 7            1985        8         2      137
# 8            1985        9         2       92
#
#                                               Splits  N_Words  Data_Size
# 0  [Down, a, sunny, dirt, road,, over, a, log, br...      608       3125
# 1  [The, Bear, family, didn’t, always, live, in, ...      875       4801
# 2  [“Brother, Bear,”, said, Sister, impatiently,,...     1129       6285
# 3  [Most, morning,, in, Bear, Country,, the, sun,...      771       4354
# 4  [It, was, the, last, day, of, school, and, the...      988       5498
# 5  [It, was, a, lazy, sort, of, day, in, Bear, Co...     1065       5798
# 6  [The, Bear, family,, who, lived, in, the, big,...     1118       6151
# 7  [Brother, and, Sister, Bear,, who, lived, with...     1443       8163
# 8  [There, was, trouble, in, the, big, tree, hous...     1019       5670

# %%
df2['N_Sents'].groupby(df2['grouping']).describe()
# Out:
#           count    mean        std   min   25%   50%     75%    max
# grouping
# 1           5.0   74.40  14.774979  55.0  67.0  74.0   82.00   94.0
# 2           4.0  106.25  21.266170  92.0  92.0  98.0  112.25  137.0

# %%
df2.describe()
# Out:
#        year_published   episode  grouping     N_Sents      N_Words  \
# count        9.000000  9.000000  9.000000    9.000000     9.000000
# mean      1982.000000  5.000000  1.444444   88.555556  1001.777778
# std          3.316625  2.738613  0.527046   23.675468   238.024567
# min       1974.000000  1.000000  1.000000   55.000000   608.000000
# 25%       1982.000000  3.000000  1.000000   74.000000   875.000000
# 50%       1982.000000  5.000000  1.000000   92.000000  1019.000000
# 75%       1984.000000  7.000000  2.000000   94.000000  1118.000000
# max       1985.000000  9.000000  2.000000  137.000000  1443.000000
#
#          Data_Size
# count     9.000000
# mean   5538.333333
# std    1399.938392
# min    3125.000000
# 25%    4801.000000
# 50%    5670.000000
# 75%    6151.000000
# max    8163.000000

# %%
from nltk.tokenize.regexp import WhitespaceTokenizer
from nltk.tokenize.regexp import WordPunctTokenizer

# %%
n = len(df2['N_Words'])
token_total = 0
type_total = 0
sent_total = 0
for i in range(0,n):
  tokens = len(WhitespaceTokenizer().tokenize(df2['text'][i]))
  token_total = token_total + tokens
  types = len(set(df2['text'][i]))
  type_total = type_total + types
  sents = df2["N_Sents"][i]
  sent_total = sent_total + sents

print("Total Number of tokens: %d"%token_total)
print("Total Number of types: %d"%type_total)
print("Total Number of sentences: %d"%sent_total)
# Out:
# Total Number of tokens: 9016
# Total Number of types: 506
# Total Number of sentences: 797

# %% [markdown]
# ##Text lengh and boxplot

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 210])

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['episode'],value_vars=['N_Words'], var_name='Tokens')
ax = sns.boxplot(x='episode',y='value',data=dd,hue='Tokens',palette="Accent")
ax.set_ylim([600,1500]) #modified min/max value as of 05OCT23
ax.set(xlabel='Episodes of Berenstain Bears', ylabel='N of words (count)')
plt.savefig('boxplot_Episode.png')

# %% [markdown]
# ##Lexical Diversity Indices (10 types)

# %% [markdown]
# Getting LD indices

# %%
# !pip install lexical-diversity
from lexical_diversity import lex_div as ld
# Out:
# Collecting lexical-diversity
#   Downloading lexical_diversity-0.1.1-py3-none-any.whl.metadata (4.1 kB)
# Downloading lexical_diversity-0.1.1-py3-none-any.whl (117 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.0 MB/s eta 0:00:00
# Installing collected packages: lexical-diversity
# Successfully installed lexical-diversity-0.1.1

# %%
# Added column: String length
lem = []

for i in range(0, len(df2['text'])):
  LEM = ld.flemmatize(df2['text'][i])
  lem.append(LEM)

df2['Lemma'] = lem

# %%
# ADD LD indices

#1. Create empty lists.
TTR = []
RTTR = []
LogTTR = []
MassTTR = []
MSTTR = []
MATTR = []
HDD = []
MTLD = []
MTLD_wrap = []
MTLD_bid = []

# 2. Getting LD index values for each cell:

for i in range(0, len(df2['Lemma'])):
  flt = df2['Lemma'][i]
  ttr = ld.ttr(flt)
  rttr = ld.root_ttr(flt)
  logttr = ld.log_ttr(flt)
  mass = ld.maas_ttr(flt)
  msttr = ld.msttr(flt)
  mattr = ld.mattr(flt)
  hdd = ld.hdd(flt)
  mtld = ld.mtld(flt)
  mtld_wrap = ld.mtld_ma_wrap(flt)
  mtld_bid = ld.mtld_ma_bid(flt)

  # Add values to each list
  TTR.append(ttr)
  RTTR.append(rttr)
  LogTTR.append(logttr)
  MassTTR.append(mass)
  MSTTR.append(msttr)
  MATTR.append(mattr)
  HDD.append(hdd)
  MTLD.append(mtld)
  MTLD_wrap.append(mtld_wrap)
  MTLD_bid.append(mtld_bid)

# Add columns
df2['TTR'] = TTR
df2['RTTR'] = RTTR
df2['LogTTR'] = LogTTR
df2['MassTTR'] = MassTTR
df2['MSTTR'] = MSTTR
df2['MATTR'] = MATTR
df2['HDD'] = HDD
df2['MTLD'] = MTLD
df2['MTLD_wrap'] = MTLD_wrap
df2['MTLD_bid'] = MTLD_bid

# %% [markdown]
# # **Number of sentences**

# %%
# !pip install textstat
import textstat
# Out:
# Requirement already satisfied: textstat in /usr/local/lib/python3.10/dist-packages (0.7.4)
# Requirement already satisfied: pyphen in /usr/local/lib/python3.10/dist-packages (from textstat) (0.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from textstat) (71.0.4)

# %% [markdown]
# # **Result file:** Number of sentences included

# %%
df2['N_Sents'] = df2['text'].apply(textstat.sentence_count)
df2.to_csv('LD_result_with_Nsents.csv')

# %% [markdown]
# ## Result file

# %%
df2.describe()
# Out:
#        year_published   episode  grouping     N_Sents      N_Words  \
# count        9.000000  9.000000  9.000000    9.000000     9.000000
# mean      1982.000000  5.000000  1.444444   88.555556  1001.777778
# std          3.316625  2.738613  0.527046   23.675468   238.024567
# min       1974.000000  1.000000  1.000000   55.000000   608.000000
# 25%       1982.000000  3.000000  1.000000   74.000000   875.000000
# 50%       1982.000000  5.000000  1.000000   92.000000  1019.000000
# 75%       1984.000000  7.000000  2.000000   94.000000  1118.000000
# max       1985.000000  9.000000  2.000000  137.000000  1443.000000
#
#          Data_Size       TTR       RTTR    LogTTR   MassTTR     MSTTR  \
# count     9.000000  9.000000   9.000000  9.000000  9.000000  9.000000
# mean   5538.333333  0.370583  11.614218  0.855592  0.048364  0.791800
# std    1399.938392  0.020666   1.114513  0.006331  0.002906  0.016915
# min    3125.000000  0.346738   9.327732  0.848351  0.045171  0.762353
# 25%    4801.000000  0.354597  11.517052  0.851287  0.046178  0.789091
# 50%    5670.000000  0.365297  11.598897  0.855439  0.047349  0.799286
# 75%    6151.000000  0.378289  12.115095  0.858227  0.049487  0.802727
# max    8163.000000  0.414508  13.452027  0.867549  0.054473  0.806316
#
#           MATTR       HDD       MTLD  MTLD_wrap   MTLD_bid
# count  9.000000  9.000000   9.000000   9.000000   9.000000
# mean   0.795591  0.849159  76.961159  78.428898  77.537824
# std    0.012189  0.012796   7.589672   8.112697   8.372971
# min    0.771657  0.820415  65.219300  68.206621  67.539329
# 25%    0.791925  0.846194  71.027588  72.806971  71.503547
# 50%    0.797961  0.850540  76.639741  76.542746  75.066182
# 75%    0.801604  0.853980  82.117515  82.004425  80.826036
# max    0.809723  0.865990  88.361195  91.376471  91.693993

# %%
df2['MATTR'].groupby(df2['episode']).describe()
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.797961  NaN  0.797961  0.797961  0.797961  0.797961
# 2          1.0  0.771657  NaN  0.771657  0.771657  0.771657  0.771657
# 3          1.0  0.801369  NaN  0.801369  0.801369  0.801369  0.801369
# 4          1.0  0.801604  NaN  0.801604  0.801604  0.801604  0.801604
# 5          1.0  0.809723  NaN  0.809723  0.809723  0.809723  0.809723
# 6          1.0  0.782301  NaN  0.782301  0.782301  0.782301  0.782301
# 7          1.0  0.791925  NaN  0.791925  0.791925  0.791925  0.791925
# 8          1.0  0.795911  NaN  0.795911  0.795911  0.795911  0.795911
# 9          1.0  0.807868  NaN  0.807868  0.807868  0.807868  0.807868
#
#               max
# episode
# 1        0.797961
# 2        0.771657
# 3        0.801369
# 4        0.801604
# 5        0.809723
# 6        0.782301
# 7        0.791925
# 8        0.795911
# 9        0.807868

# %%
print(df2['MATTR'].groupby(df2['episode']).describe())
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.797961  NaN  0.797961  0.797961  0.797961  0.797961
# 2          1.0  0.771657  NaN  0.771657  0.771657  0.771657  0.771657
# 3          1.0  0.801369  NaN  0.801369  0.801369  0.801369  0.801369
# 4          1.0  0.801604  NaN  0.801604  0.801604  0.801604  0.801604
# 5          1.0  0.809723  NaN  0.809723  0.809723  0.809723  0.809723
# 6          1.0  0.782301  NaN  0.782301  0.782301  0.782301  0.782301
# 7          1.0  0.791925  NaN  0.791925  0.791925  0.791925  0.791925
# 8          1.0  0.795911  NaN  0.795911  0.795911  0.795911  0.795911
# 9          1.0  0.807868  NaN  0.807868  0.807868  0.807868  0.807868
#
#               max
# episode
# 1        0.797961
# 2        0.771657
# 3        0.801369
# 4        0.801604
# 5        0.809723
# 6        0.782301
# 7        0.791925
# 8        0.795911
# 9        0.807868

# %%
df2['MATTR'].describe()
# Out:
# count    9.000000
# mean     0.795591
# std      0.012189
# min      0.771657
# 25%      0.791925
# 50%      0.797961
# 75%      0.801604
# max      0.809723
# Name: MATTR, dtype: float64

# %%
df2['MATTR'].groupby(df2['grouping']).describe()
# Out:
#           count      mean       std       min       25%       50%       75%  \
# grouping
# 1           5.0  0.796463  0.014525  0.771657  0.797961  0.801369  0.801604
# 2           4.0  0.794501  0.010585  0.782301  0.789519  0.793918  0.798900
#
#                max
# grouping
# 1         0.809723
# 2         0.807868

# %%
print(df2['MATTR'].groupby(df2['grouping']).describe())
# Out:
#           count      mean       std       min       25%       50%       75%  \
# grouping
# 1           5.0  0.796463  0.014525  0.771657  0.797961  0.801369  0.801604
# 2           4.0  0.794501  0.010585  0.782301  0.789519  0.793918  0.798900
#
#                max
# grouping
# 1         0.809723
# 2         0.807868

# %%
df2['HDD'].groupby(df2['episode']).describe()
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.820415  NaN  0.820415  0.820415  0.820415  0.820415
# 2          1.0  0.843107  NaN  0.843107  0.843107  0.843107  0.843107
# 3          1.0  0.846194  NaN  0.846194  0.846194  0.846194  0.846194
# 4          1.0  0.865990  NaN  0.865990  0.865990  0.865990  0.865990
# 5          1.0  0.850540  NaN  0.850540  0.850540  0.850540  0.850540
# 6          1.0  0.851726  NaN  0.851726  0.851726  0.851726  0.851726
# 7          1.0  0.850268  NaN  0.850268  0.850268  0.850268  0.850268
# 8          1.0  0.853980  NaN  0.853980  0.853980  0.853980  0.853980
# 9          1.0  0.860209  NaN  0.860209  0.860209  0.860209  0.860209
#
#               max
# episode
# 1        0.820415
# 2        0.843107
# 3        0.846194
# 4        0.865990
# 5        0.850540
# 6        0.851726
# 7        0.850268
# 8        0.853980
# 9        0.860209

# %%
df2['HDD'].describe()
# Out:
# count    9.000000
# mean     0.849159
# std      0.012796
# min      0.820415
# 25%      0.846194
# 50%      0.850540
# 75%      0.853980
# max      0.865990
# Name: HDD, dtype: float64

# %% [markdown]
# Plotting

# %%
from matplotlib import pyplot as plt
import seaborn as sns

# %%
sns.set(rc={'figure.figsize':(8,6),"font.size":40,"axes.titlesize":140,"axes.labelsize":60},style="white") # font size doesn't work
# ax = sns.boxplot (y=df2)
# ax.set_ylim([0, 500]) #modified from y=210 to y=500(05OCT23)

sns.set_theme(style='white')
dd=pd.melt(df2,id_vars=['episode'],value_vars=['N_Words'],var_name='Tokens')
ax = sns.boxplot(x='episode',y='value',data=dd,hue='Tokens',palette="Accent")
ax.set_ylim([600,1500])
ax.set(xlabel='episode', ylabel='N of words (count)')
plt.savefig('boxplot_Nwords.png')

# %%
sns.kdeplot(x='N_Words', data=df2, hue='episode', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_Nsplit.png')
# Out:
# <ipython-input-61-94673ffdd24f>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='N_Words', data=df2, hue='episode', common_norm=False);

# %%
sns.scatterplot(data=df2, x="episode", y="N_Words")
sns.rugplot(data=df2, x="episode", y="N_Words", height=.1)
plt.savefig('Rug_Nsplit.png')

# %% [markdown]
# 문항별 어휘수 및 문장수

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df2, x="episode", y="N_Words")
ax = sns.rugplot(data=df2, x="episode", y="N_Words", height=.1)
ax.set_ylim([600,1500]) #modified from [90,200] to [600,1500]
ax.set(xlabel='Episodes of Berenstain Bears', ylabel='N of words (count)')
plt.savefig('Rug_Nsplit_byQ.png')

# %% [markdown]
# # Lexical Diversity analysis: select TTR, MassTTR, MTLD, HDD

# %%
df3 = df2
for col in df3.columns:
    print(col)
# Out:
# text
# title
# year_published
# episode
# grouping
# N_Sents
# Splits
# N_Words
# Data_Size
# Lemma
# TTR
# RTTR
# LogTTR
# MassTTR
# MSTTR
# MATTR
# HDD
# MTLD
# MTLD_wrap
# MTLD_bid

# %%
df3 = df2[['episode','N_Words','N_Sents','TTR','MSTTR','MATTR','HDD','MTLD']]
df3.head(10)
# Out:
#    episode  N_Words  N_Sents       TTR     MSTTR     MATTR       HDD  \
# 0        1      608       55  0.378289  0.805000  0.797961  0.820415
# 1        2      875       74  0.365297  0.762353  0.771657  0.843107
# 2        3     1129       94  0.361947  0.802727  0.801369  0.846194
# 3        4      771       67  0.414508  0.802667  0.801604  0.865990
# 4        5      988       82  0.385238  0.806316  0.809723  0.850540
# 5        6     1065       92  0.354597  0.764762  0.782301  0.851726
# 6        7     1118      104  0.346738  0.789091  0.791925  0.850268
# 7        8     1443      137  0.354123  0.799286  0.795911  0.853980
# 8        9     1019       92  0.374510  0.794000  0.807868  0.860209
#
#         MTLD
# 0  70.890591
# 1  65.219300
# 2  88.361195
# 3  76.639741
# 4  86.145189
# 5  71.027588
# 6  74.063513
# 7  78.185796
# 8  82.117515

# %%
df3.groupby('episode')['TTR'].describe()
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.378289  NaN  0.378289  0.378289  0.378289  0.378289
# 2          1.0  0.365297  NaN  0.365297  0.365297  0.365297  0.365297
# 3          1.0  0.361947  NaN  0.361947  0.361947  0.361947  0.361947
# 4          1.0  0.414508  NaN  0.414508  0.414508  0.414508  0.414508
# 5          1.0  0.385238  NaN  0.385238  0.385238  0.385238  0.385238
# 6          1.0  0.354597  NaN  0.354597  0.354597  0.354597  0.354597
# 7          1.0  0.346738  NaN  0.346738  0.346738  0.346738  0.346738
# 8          1.0  0.354123  NaN  0.354123  0.354123  0.354123  0.354123
# 9          1.0  0.374510  NaN  0.374510  0.374510  0.374510  0.374510
#
#               max
# episode
# 1        0.378289
# 2        0.365297
# 3        0.361947
# 4        0.414508
# 5        0.385238
# 6        0.354597
# 7        0.346738
# 8        0.354123
# 9        0.374510

# %%
df3.groupby('episode')['MSTTR'].describe()
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.805000  NaN  0.805000  0.805000  0.805000  0.805000
# 2          1.0  0.762353  NaN  0.762353  0.762353  0.762353  0.762353
# 3          1.0  0.802727  NaN  0.802727  0.802727  0.802727  0.802727
# 4          1.0  0.802667  NaN  0.802667  0.802667  0.802667  0.802667
# 5          1.0  0.806316  NaN  0.806316  0.806316  0.806316  0.806316
# 6          1.0  0.764762  NaN  0.764762  0.764762  0.764762  0.764762
# 7          1.0  0.789091  NaN  0.789091  0.789091  0.789091  0.789091
# 8          1.0  0.799286  NaN  0.799286  0.799286  0.799286  0.799286
# 9          1.0  0.794000  NaN  0.794000  0.794000  0.794000  0.794000
#
#               max
# episode
# 1        0.805000
# 2        0.762353
# 3        0.802727
# 4        0.802667
# 5        0.806316
# 6        0.764762
# 7        0.789091
# 8        0.799286
# 9        0.794000

# %%
df3['TTR'].describe()
# Out:
# count    9.000000
# mean     0.370583
# std      0.020666
# min      0.346738
# 25%      0.354597
# 50%      0.365297
# 75%      0.378289
# max      0.414508
# Name: TTR, dtype: float64

# %%
df3['MSTTR'].describe()
# Out:
# count    9.000000
# mean     0.791800
# std      0.016915
# min      0.762353
# 25%      0.789091
# 50%      0.799286
# 75%      0.802727
# max      0.806316
# Name: MSTTR, dtype: float64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.set(rc={'figure.figsize':(8,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
# sns.set_theme(style='white')
dd=pd.melt(df3,id_vars=['grouping'],value_vars=['MSTTR'],var_name='LD index')
ax = sns.boxplot(x='Part',y='value',data=dd,hue='LD index',palette="Accent")
ax.set_ylim([.6,.9])
ax.set(xlabel='grouping', ylabel='MSTTR')
plt.savefig('boxplot_MSTTR_by_part.png')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-d3047e5dff20> in <cell line: 3>()
#       1 sns.set(rc={'figure.figsize':(8,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
#       2 # sns.set_theme(style='white')
# ----> 3 dd=pd.melt(df3,id_vars=['grouping'],value_vars=['MSTTR'],var_name='LD index')
#       4 ax = sns.boxplot(x='Part',y='value',data=dd,hue='LD index',palette="Accent")
#       5 ax.set_ylim([.6,.9])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      72                 lab for lab, not_found in zip(labels, missing) if not_found
#      73             ]
# ---> 74             raise KeyError(
#      75                 "The following id_vars or value_vars are not present in "
#      76                 f"the DataFrame: {missing_labels}"
#
# KeyError: "The following id_vars or value_vars are not present in the DataFrame: ['grouping']"

# %%
sns.kdeplot(x='MSTTR', data=df3, hue='Part', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_MTLD.png')

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df3, x="Part", y="MSTTR")
ax = sns.rugplot(data=df3, x="Part", y="MSTTR", height=.1)
ax.set_ylim([0,1])
ax.set_xlim([-1,8])
ax.set(xlabel='Part', ylabel='MSTTR index')
plt.savefig('Rug_MSTTR_byPart.png')

# %% [markdown]
# ##MATTR

# %%
sns.kdeplot(x='MATTR', data=df3, hue='episode', common_norm=False);
plt.title("Kernel Density Function")
plt.savefig('Density_MATTR.png')
# Out:
# <ipython-input-71-45ddfeaca001>:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x='MATTR', data=df3, hue='episode', common_norm=False);

# %%
df3.groupby('episode')['MATTR'].describe()
# Out:
#          count      mean  std       min       25%       50%       75%  \
# episode
# 1          1.0  0.797961  NaN  0.797961  0.797961  0.797961  0.797961
# 2          1.0  0.771657  NaN  0.771657  0.771657  0.771657  0.771657
# 3          1.0  0.801369  NaN  0.801369  0.801369  0.801369  0.801369
# 4          1.0  0.801604  NaN  0.801604  0.801604  0.801604  0.801604
# 5          1.0  0.809723  NaN  0.809723  0.809723  0.809723  0.809723
# 6          1.0  0.782301  NaN  0.782301  0.782301  0.782301  0.782301
# 7          1.0  0.791925  NaN  0.791925  0.791925  0.791925  0.791925
# 8          1.0  0.795911  NaN  0.795911  0.795911  0.795911  0.795911
# 9          1.0  0.807868  NaN  0.807868  0.807868  0.807868  0.807868
#
#               max
# episode
# 1        0.797961
# 2        0.771657
# 3        0.801369
# 4        0.801604
# 5        0.809723
# 6        0.782301
# 7        0.791925
# 8        0.795911
# 9        0.807868

# %% [markdown]
# ##Readability indices & Plotting for papers

# %%
from typing import TextIO
FRE = []
FKG = []
GF = []
ARI = []
CLI = []
LWF = []
DCRS = []
TS = []

for i in range(0, len(df2['Text'])):
  text = df2['Text'][i]
  fre = textstat.flesch_reading_ease(text)
  fkg = textstat.flesch_kincaid_grade(text)
  gf = textstat.gunning_fog(text)
  ari = textstat.automated_readability_index(text)
  cli = textstat.coleman_liau_index(text)
  lwf = textstat.linsear_write_formula(text)
  dcrs = textstat.dale_chall_readability_score(text)
  ts = textstat.text_standard(text)

  FRE.append(fre)
  FKG.append(fkg)
  GF.append(gf)
  ARI.append(ari)
  CLI.append(cli)
  LWF.append(lwf)
  DCRS.append(dcrs)
  TS.append(ts)


df3['FRE'] = FRE
df3['FKG'] = FKG
df3['GF'] = GF
df3['ARI'] = ARI
df3['CLI'] = CLI
df3['LWF'] = LWF
df3['DCRS'] = DCRS
df3['TS'] = TS
# Out:
# <ipython-input-68-62d119fe0300>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['FRE'] = FRE
# <ipython-input-68-62d119fe0300>:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['FKG'] = FKG
# <ipython-input-68-62d119fe0300>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['GF'] = GF
# <ipython-input-68-62d119fe0300>:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['ARI'] = ARI
# <ipython-input-68-62d119fe0300>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['CLI'] = CLI
# <ipython-input-68-62d119fe0300>:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['LWF'] = LWF
# <ipython-input-68-62d119fe0300>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['DCRS'] = DCRS
# <ipython-input-68-62d119fe0300>:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['TS'] = TS

# %% [markdown]
# df3: LD(4 indices) + Readability

# %%
df3.to_csv('results_all.csv')

# %%
df3.head()
# Out:
#    Part                           Episode  N_Words  N_Sents       TTR  \
# 0     1            “THE WOLF AND THE KID”      285       20  0.536842
# 1     1      “THE TORTOISE AND THE DUCKS”      291       17  0.549828
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”       95        8  0.642105
# 3     1            “THE FROGS AND THE OX”      134       12  0.604478
# 4     1  “THE DOG, THE COCK, AND THE FOX”      308       19  0.535714
#
#       MATTR       HDD       MTLD    FRE  FKG    GF  ARI   CLI      LWF  DCRS  \
# 0  0.775424  0.813943  80.278561  90.90  4.1  5.96  5.7  5.79   5.2500  6.90
# 1  0.792066  0.816526  78.488159  87.96  5.2  8.22  6.9  5.68  11.0000  6.17
# 2  0.743043  0.798062  73.381695  93.34  3.2  5.57  4.7  4.68   5.1875  5.57
# 3  0.750824  0.809381  49.012951  94.05  2.9  4.74  4.6  4.62   4.1000  5.97
# 4  0.773745  0.802820  68.226050  88.97  4.8  7.49  6.3  5.68  10.4000  6.96
#
#                   TS
# 0  5th and 6th grade
# 1  5th and 6th grade
# 2  5th and 6th grade
# 3  4th and 5th grade
# 4  6th and 7th grade

# %%
#47/136 Where are the numbers from and what for? Ask MK316

# %%
a = df3[df3['FRE'] < 50]
a.shape
# Out:
# (0, 16)

# %%
df4 = df3
#df4 = df4[['Part','Episode','N_Splits','N_Sents','TTR','MTLD','FRE','FKG','GF','DCRS']] #Original from MK316
df4 = df4[['Part','Episode','N_Sents','TTR','MTLD','FRE','FKG','GF','DCRS']] #Modified, self-taught

# %%
sns.set(rc={'figure.figsize':(6,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Part", y="FRE")
ax = sns.rugplot(data=df4, x="Part", y="FRE", height=.1)
ax.set_ylim([0,100])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Part', ylabel='Flesch Reading Ease index')
ax.axhline(50, color="gray")
ax.axhline(30, color="red")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_FRE_byPart.png')

# %%
sns.set(rc={'figure.figsize':(6,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Part", y="FKG")
ax = sns.rugplot(data=df4, x="Part", y="FKG", height=.1)
ax.set_ylim([0,20])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Part', ylabel='Flesch Kincaid Grade')
ax.axhline(15, color="red")
ax.axhline(12, color="blue")
ax.axhline(6, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_FKG_byPart.png')

# %%
a = df4.groupby('Part')['FKG'].describe()
a.to_csv('FKG_summary_by_Part.csv')

# %%
b = df4.groupby('Part')['FRE'].describe()
b.to_csv('FRE_summary_by_Part.csv')

# %%
b1 = df4.describe()
b1.to_csv('Readability_summary_total.csv')

# %% [markdown]
# ##Getting individual numbers for the paper
# -I don't get it. No matter what, I copied and work on being trained with code lines.

# %%
b2 = df4[15 <= df3['GF']]
b2.shape
# Out:
# (0, 9)

# %%
#WHY? 38/136

# %%
a1 = df4[10 <= df3['DCRS']]
a1.shape
# Out:
# (0, 9)

# %%
#WHY? 31/136

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Episode", y="DCRS")
ax = sns.rugplot(data=df4, x="Episode", y="DCRS", height=.1)
ax.set_ylim([5,13])
# ax.set_xlim([2014,2023])
ax.set(xlabel='Question Number', ylabel='Dale-Chall Reading Score')
ax.axhline(10, color="red")
ax.axhline(9, color="blue")
# ax.axhline(6, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('Rug_DCRS_byEpisode.png')

# %%
a2 = df4[10 <= df3['DCRS']]
a2.shape
# Out:
# (0, 9)

# %%
#??? 74/136

# %% [markdown]
# ## Pie chart of readability indices
# -Origianl from MK316. Later I need to modify after working on it.

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work
# declaring data
data = [44, 45, 40, 41, 39]
keys = ['Class 1', 'Class 2', 'CLass 3', 'Class 4', 'Class 5']

# declaring exploding pie
explode = [0, 0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
plt.show()

# %% [markdown]
# ## Data cut (categorize)

# %%
import pandas as pd
df4.head()
# Out:
#    Part                           Episode  N_Sents       TTR       MTLD  \
# 0     1            “THE WOLF AND THE KID”       20  0.536842  80.278561
# 1     1      “THE TORTOISE AND THE DUCKS”       17  0.549828  78.488159
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”        8  0.642105  73.381695
# 3     1            “THE FROGS AND THE OX”       12  0.604478  49.012951
# 4     1  “THE DOG, THE COCK, AND THE FOX”       19  0.535714  68.226050
#
#      FRE  FKG    GF  DCRS
# 0  90.90  4.1  5.96  6.90
# 1  87.96  5.2  8.22  6.17
# 2  93.34  3.2  5.57  5.57
# 3  94.05  2.9  4.74  5.97
# 4  88.97  4.8  7.49  6.96

# %%
## pd.cut: how to use

b1 = pd.cut(df4['FRE'], bins=[0, 30, 50, 60,100], include_lowest=True, labels=['Very difficult', 'Difficult', 'Appropriate',"Easy"])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Very difficult    0
# Difficult         0
# Appropriate       0
# Name: FRE, dtype: int64

# %%
## pd.cut: how to use

b1 = pd.cut(df4['GF'], bins=[0, 9, 13, 16,20], include_lowest=True, labels=["Easy", 'Appropriate', 'Difficult', 'Very difficult'])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Appropriate       0
# Difficult         0
# Very difficult    0
# Name: GF, dtype: int64

# %%
## pd.cut: how to use

b1 = pd.cut(df4['DCRS'], bins=[0, 7, 8, 9, 10], include_lowest=True, labels=["Easy", 'Appropriate', 'Difficult', 'Very difficult'])

count = b1.value_counts()
print(count)
# Out:
# Easy              5
# Appropriate       0
# Difficult         0
# Very difficult    0
# Name: DCRS, dtype: int64

# %%
b1
# Out:
# 0    Easy
# 1    Easy
# 2    Easy
# 3    Easy
# 4    Easy
# Name: DCRS, dtype: category
# Categories (4, object): ['Easy' < 'Appropriate' < 'Difficult' < 'Very difficult']

# %% [markdown]
# [1] FRE pie chart

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [18, 47, 31, 40]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Flesch Reading Ease")

plt.savefig('Pie_FRE.png')
plt.show()

# %% [markdown]
# [2] Gunning-Fog pie

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [21, 45, 47, 17]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Gunning-Fog")

plt.savefig('Pie_GF.png')
plt.show()

# %% [markdown]
# [3] Dale-Chall pie

# %%
import matplotlib.pyplot as plt
import seaborn

sns.set(rc={'figure.figsize':(6,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white") # font size doesn't work

# declaring data
data = [44, 41, 15, 6]
keys = ['Very difficult', 'Difficult','Appropriate','Easy']
# declaring exploding pie
explode = [0.1, 0, 0, 0]
# define Seaborn color palette to use
palette_color = seaborn.color_palette("Set2")

# plotting data on chart
plt.pie(data, labels=keys, colors=palette_color,
        explode=explode, autopct='%.0f%%')

# displaying chart
ax.set_title("Dale-Chall")

plt.savefig('Pie_DC.png')
plt.show()

# %% [markdown]
# Statistic analysis for the data

# %%
#df5 = df3[['Part','Episode','N_Splits','N_Sents','TTR','MATTR','MTLD','HDD','FRE','FKG','GF','DCRS']] #Original with 'N_Splits
#df5.head()

df5 = df3[['Part','Episode','N_Sents','TTR','MATTR','MTLD','HDD','FRE','FKG','GF','DCRS']]
df5.head()
# Out:
#    Part                           Episode  N_Sents       TTR     MATTR  \
# 0     1            “THE WOLF AND THE KID”       20  0.536842  0.775424
# 1     1      “THE TORTOISE AND THE DUCKS”       17  0.549828  0.792066
# 2     1   “THE YOUNG CRAB AND HIS MOTHER”        8  0.642105  0.743043
# 3     1            “THE FROGS AND THE OX”       12  0.604478  0.750824
# 4     1  “THE DOG, THE COCK, AND THE FOX”       19  0.535714  0.773745
#
#         MTLD       HDD    FRE  FKG    GF  DCRS
# 0  80.278561  0.813943  90.90  4.1  5.96  6.90
# 1  78.488159  0.816526  87.96  5.2  8.22  6.17
# 2  73.381695  0.798062  93.34  3.2  5.57  5.57
# 3  49.012951  0.809381  94.05  2.9  4.74  5.97
# 4  68.226050  0.802820  88.97  4.8  7.49  6.96

# %%
ld = df5[['TTR','MATTR','MTLD','HDD']]

# %%
corrMatrix = ld.corr()
corrMatrix
# Out:
#             TTR     MATTR      MTLD       HDD
# TTR    1.000000 -0.875575 -0.389218 -0.593094
# MATTR -0.875575  1.000000  0.545925  0.728857
# MTLD  -0.389218  0.545925  1.000000  0.207689
# HDD   -0.593094  0.728857  0.207689  1.000000

# %%
import seaborn as sn
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(12,6),"font.size":20,"axes.titlesize":20,"axes.labelsize":30},style="white")

sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# # Others

# %% [markdown]
# The Gunning Fog index: It generates a grade level between 0 and 20. It estimates the education level required to understand the text. Too many different words per thoughsand, not enough simple sentences, too difficult for the inteded audience.

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Year", y="GF")
ax = sns.rugplot(data=df4, x="Year", y="GF", height=.1)
ax.set_ylim([0,20])
# ax.set_xlim([0,150])
ax.set(xlabel='Year', ylabel='Dale-Chall Reading Score')
ax.axhline(15, color="red")
ax.axhline(12, color="blue")
ax.axhline(9, color="gray")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('GF_scatter.png')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-483dfeabf263> in <cell line: 2>()
#       1 sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
# ----> 2 sns.scatterplot(data=df4, x="Year", y="GF")
#       3 ax = sns.rugplot(data=df4, x="Year", y="GF", height=.1)
#       4 ax.set_ylim([0,20])
#       5 # ax.set_xlim([0,150])
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in assign_variables(self, data, variables)
#     699         else:
#     700             self.input_format = "long"
# --> 701             plot_data, variables = self._assign_variables_longform(
#     702                 data, **variables,
#     703             )
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     936
#     937                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938                 raise ValueError(err)
#     939
#     940             else:
#
# ValueError: Could not interpret value `Year` for parameter `x`

# %%
sns.set(rc={'figure.figsize':(12,6),"font.size":40,"axes.titlesize":20,"axes.labelsize":20},style="white") # font size doesn't work
sns.scatterplot(data=df4, x="Year", y="DCRS")
ax = sns.rugplot(data=df4, x="Year", y="DCRS", height=.1)
ax.set_ylim([5,13])
# ax.set_xlim([0,150])
ax.set(xlabel='Year', ylabel='Dale-Chall Reading Score')
# ax.axhline(15, color="red")
ax.axhline(10, color="red")
ax.axhline(9, color="blue")
# ax.axhline(60)
# ax.axhline(70)
# ax.axhline(80)
# plt.text(8, 50, "An annotation", horizontalalignment='left', size='medium', color='black', weight='semibold')
plt.savefig('DCRS_scatter.png')

# %%
df4['DCRS'].describe()

# %%
plt.hist(df4['DCRS'], binwidth=1)

# %%
ordered_ttr = list(df2['TTR']).sort()
ordered_ttr

# %%
a1 = df2[['N_Splits','TTR','MSTTR']]
a2 = a1.sort_values(by=['N_Splits'])
a2

# %%
df3 = df2.sort_values(by=['N_Splits'])

# %%
f = plt.figure(figsize=(10, 10))
plt.scatter(df2['N_Splits'],df2['TTR'],  label='TTR')
# plt.scatter(df2['N_Splits'],df2['LogTTR'],  label='LogTTR')
# plt.scatter(df2['N_Splits'],df2['MSTTR'],  label='MSTTR')
plt.legend()

# %% [markdown]
# Linear regression of TTR and Length

# %%
# importing the required library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# # f = plt.figure(figsize=(10, 10))
# fig, (ax1, ax2) = plt.subplots(1, 2)
# fig.suptitle('Horizontally stacked subplots')
# data
df = df2

# scatter plot with regression
# line(by default)
sns.lmplot(x ='N_Splits', y ='TTR', data = df)

# Show the plot
plt.show()

# %%
# Residual plots
sns.residplot(x ='N_Splits', y ='TTR', data = df)

# %%
sns.lmplot(x ='N_Splits', y ='MTLD', data = df)

# Show the plot
plt.show()

# %%
# Residual plots
sns.residplot(x ='N_Splits', y ='MTLD', data = df)

# %%
import statsmodels.api as sm

X = df["N_Splits"]
y = df["TTR"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

# %%
X = df["N_Splits"]
y = df["MTLD"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

# %%
Style: additionaal Boxplots 아래 하단은 추후 복사해 공부하고 적용하기
